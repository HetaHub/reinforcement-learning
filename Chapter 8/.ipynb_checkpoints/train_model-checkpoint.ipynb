# %%
#!/usr/bin/env python3
import os
import gym
import ptan
import argparse
import numpy as np

import torch
import torch.optim as optim

from lib import environ, data, models, common, validation

from tensorboardX import SummaryWriter

# %%
BATCH_SIZE = 32
BARS_COUNT = 10
TARGET_NET_SYNC = 1000
DEFAULT_STOCKS = "data/YNDX_160101_161231.csv"
DEFAULT_VAL_STOCKS = "data/YNDX_150101_151231.csv"

DEFAULT_RUN_NAME = "result"

GAMMA = 0.99

REPLAY_SIZE = 100000
REPLAY_INITIAL = 10000

REWARD_STEPS = 2

LEARNING_RATE = 0.0001

STATES_TO_EVALUATE = 1000
EVAL_EVERY_STEP = 1000

EPSILON_START = 1.0
EPSILON_STOP = 0.1
EPSILON_STEPS = 1000000

CHECKPOINT_EVERY_STEP = 1000000
VALIDATION_EVERY_STEP = 100000

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("--cuda", default=True, action="store_true", help="Enable cuda")
    parser.add_argument("--data", default=DEFAULT_STOCKS, help="Stocks file or dir to train on, default=" + DEFAULT_STOCKS)
    parser.add_argument("--year", type=int, help="Year to be used for training, if specified, overrides --data option")
    parser.add_argument("--valdata", default=DEFAULT_VAL_STOCKS, help="Stocks data for validation, default=" + DEFAULT_VAL_STOCKS)
    parser.add_argument("-r", "--run", default=DEFAULT_STOCKS, required=False, help="Run name")
    args, unknown = parser.parse_known_args()
    device = torch.device("cuda" if args.cuda else "cpu")

    saves_path = os.path.join("saves", args.run)
    os.makedirs(saves_path, exist_ok=True)

    if args.year is not None or os.path.isfile(args.data):
        if args.year is not None:
            stock_data = data.load_year_data(args.year)
        else:
            stock_data = {"YNDX": data.load_relative(args.data)}
        env = environ.StocksEnv(stock_data, bars_count=BARS_COUNT, reset_on_close=True, state_1d=False, volumes=False)
        env_tst = environ.StocksEnv(stock_data, bars_count=BARS_COUNT, reset_on_close=True, state_1d=False)
    elif os.path.isdir(args.data):
        env = environ.StocksEnv.from_dir(args.data, bars_count=BARS_COUNT, reset_on_close=True, state_1d=False)
        env_tst = environ.StocksEnv.from_dir(args.data, bars_count=BARS_COUNT, reset_on_close=True, state_1d=False)
    else:
        raise RuntimeError("No data to train on")
    env = gym.wrappers.TimeLimit(env, max_episode_steps=1000)

    val_data = {"YNDX": data.load_relative(args.valdata)}
    env_val = environ.StocksEnv(val_data, bars_count=BARS_COUNT, reset_on_close=True, state_1d=False)

    writer = SummaryWriter(comment="-simple-" + args.run)
    net = models.SimpleFFDQN(env.observation_space.shape[0], env.action_space.n).to(device)
    tgt_net = ptan.agent.TargetNet(net)
    selector = ptan.actions.EpsilonGreedyActionSelector(EPSILON_START)
    agent = ptan.agent.DQNAgent(net, selector, device=device)
    exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, GAMMA, steps_count=REWARD_STEPS)
    buffer = ptan.experience.ExperienceReplayBuffer(exp_source, REPLAY_SIZE)
    optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)

    # main training loop
    step_idx = 0
    eval_states = None
    best_mean_val = None

    with common.RewardTracker(writer, np.inf, group_rewards=100) as reward_tracker:
        while True:
            step_idx += 1
            buffer.populate(1)
            selector.epsilon = max(EPSILON_STOP, EPSILON_START - step_idx / EPSILON_STEPS)

            new_rewards = exp_source.pop_rewards_steps()
            if new_rewards:
                reward_tracker.reward(new_rewards[0], step_idx, selector.epsilon)

            if len(buffer) < REPLAY_INITIAL:
                continue

            if eval_states is None:
                print("Initial buffer populated, start training")
                eval_states = buffer.sample(STATES_TO_EVALUATE)
                eval_states = [np.array(transition.state, copy=False) for transition in eval_states]
                eval_states = np.array(eval_states, copy=False)

            if step_idx % EVAL_EVERY_STEP == 0:
                mean_val = common.calc_values_of_states(eval_states, net, device=device)
                writer.add_scalar("values_mean", mean_val, step_idx)
                if best_mean_val is None or best_mean_val < mean_val:
                    if best_mean_val is not None:
                        print("%d: Best mean value updated %.3f -> %.3f" % (step_idx, best_mean_val, mean_val))
                    best_mean_val = mean_val
                    torch.save(net.state_dict(), os.path.join(saves_path, "mean_val-%.3f.data" % mean_val))

            optimizer.zero_grad()
            batch = buffer.sample(BATCH_SIZE)
            loss_v = common.calc_loss(batch, net, tgt_net.target_model, GAMMA ** REWARD_STEPS, device=device)
            loss_v.backward()
            optimizer.step()

            if step_idx % TARGET_NET_SYNC == 0:
                tgt_net.sync()

            if step_idx % CHECKPOINT_EVERY_STEP == 0:
                idx = step_idx // CHECKPOINT_EVERY_STEP
                torch.save(net.state_dict(), os.path.join(saves_path, "checkpoint-%3d.data" % idx))

            if step_idx % VALIDATION_EVERY_STEP == 0:
                res = validation.validation_run(env_tst, net, device=device)
                for key, val in res.items():
                    writer.add_scalar(key + "_test", val, step_idx)
                res = validation.validation_run(env_val, net, device=device)
                for key, val in res.items():
                    writer.add_scalar(key + "_val", val, step_idx)
# Out:
# Reading data/YNDX_160101_161231.csv
# Read done, got 131542 rows, 99752 filtered, 0 open prices adjusted
# Reading data/YNDX_150101_151231.csv
# Read done, got 130566 rows, 104412 filtered, 0 open prices adjusted
# 682: done 100 games, mean reward -0.231, mean steps 5.94, speed 567.49 f/s, eps 1.00
# 1424: done 200 games, mean reward -0.251, mean steps 6.22, speed 709.91 f/s, eps 1.00
# 2127: done 300 games, mean reward -0.223, mean steps 6.20, speed 683.69 f/s, eps 1.00
# 2839: done 400 games, mean reward -0.230, mean steps 6.19, speed 622.95 f/s, eps 1.00
# 3618: done 500 games, mean reward -0.238, mean steps 6.33, speed 598.07 f/s, eps 1.00
# 4309: done 600 games, mean reward -0.225, mean steps 6.28, speed 673.98 f/s, eps 1.00
# 4965: done 700 games, mean reward -0.221, mean steps 6.19, speed 735.74 f/s, eps 1.00
# 5654: done 800 games, mean reward -0.225, mean steps 6.16, speed 666.84 f/s, eps 0.99
# 6350: done 900 games, mean reward -0.224, mean steps 6.15, speed 624.76 f/s, eps 0.99
# 7026: done 1000 games, mean reward -0.219, mean steps 6.13, speed 675.78 f/s, eps 0.99
# 7751: done 1100 games, mean reward -0.219, mean steps 6.15, speed 664.48 f/s, eps 0.99
# 8483: done 1200 games, mean reward -0.219, mean steps 6.17, speed 705.05 f/s, eps 0.99
# 9141: done 1300 games, mean reward -0.218, mean steps 6.13, speed 713.25 f/s, eps 0.99
# 9802: done 1400 games, mean reward -0.211, mean steps 6.10, speed 710.36 f/s, eps 0.99
# Initial buffer populated, start training
# 10523: done 1500 games, mean reward -0.208, mean steps 6.11, speed 90.45 f/s, eps 0.99
# 11170: done 1600 games, mean reward -0.208, mean steps 6.09, speed 74.07 f/s, eps 0.99
# 11921: done 1700 games, mean reward -0.207, mean steps 6.12, speed 75.50 f/s, eps 0.99
# 12584: done 1800 games, mean reward -0.208, mean steps 6.10, speed 73.70 f/s, eps 0.99
# 13283: done 1900 games, mean reward -0.206, mean steps 6.09, speed 73.70 f/s, eps 0.99
# 13946: done 2000 games, mean reward -0.205, mean steps 6.08, speed 76.16 f/s, eps 0.99
# 14654: done 2100 games, mean reward -0.205, mean steps 6.08, speed 71.83 f/s, eps 0.99
# 15342: done 2200 games, mean reward -0.204, mean steps 6.08, speed 72.93 f/s, eps 0.98
# 16013: done 2300 games, mean reward -0.204, mean steps 6.07, speed 75.12 f/s, eps 0.98
# 16733: done 2400 games, mean reward -0.204, mean steps 6.08, speed 75.59 f/s, eps 0.98
# 17422: done 2500 games, mean reward -0.201, mean steps 6.08, speed 74.77 f/s, eps 0.98
# 18100: done 2600 games, mean reward -0.203, mean steps 6.07, speed 74.61 f/s, eps 0.98
# 18781: done 2700 games, mean reward -0.200, mean steps 6.07, speed 75.74 f/s, eps 0.98
# 19520: done 2800 games, mean reward -0.200, mean steps 6.08, speed 75.39 f/s, eps 0.98
# 20258: done 2900 games, mean reward -0.199, mean steps 6.09, speed 74.29 f/s, eps 0.98
# 20981: done 3000 games, mean reward -0.202, mean steps 6.10, speed 76.15 f/s, eps 0.98
# 21639: done 3100 games, mean reward -0.200, mean steps 6.09, speed 74.14 f/s, eps 0.98
# 22341: done 3200 games, mean reward -0.199, mean steps 6.09, speed 75.02 f/s, eps 0.98
# 23038: done 3300 games, mean reward -0.199, mean steps 6.09, speed 74.64 f/s, eps 0.98
# 23697: done 3400 games, mean reward -0.198, mean steps 6.08, speed 75.71 f/s, eps 0.98
# 24414: done 3500 games, mean reward -0.197, mean steps 6.08, speed 72.42 f/s, eps 0.98
# 25128: done 3600 games, mean reward -0.197, mean steps 6.09, speed 74.58 f/s, eps 0.97
# 25847: done 3700 games, mean reward -0.198, mean steps 6.09, speed 76.17 f/s, eps 0.97
# 26565: done 3800 games, mean reward -0.199, mean steps 6.10, speed 75.09 f/s, eps 0.97
# 27239: done 3900 games, mean reward -0.199, mean steps 6.09, speed 74.67 f/s, eps 0.97
# 27967: done 4000 games, mean reward -0.199, mean steps 6.10, speed 75.73 f/s, eps 0.97
# 28638: done 4100 games, mean reward -0.198, mean steps 6.09, speed 74.33 f/s, eps 0.97
# 29339: done 4200 games, mean reward -0.196, mean steps 6.09, speed 75.81 f/s, eps 0.97
# 30032: done 4300 games, mean reward -0.196, mean steps 6.09, speed 75.95 f/s, eps 0.97
# 30743: done 4400 games, mean reward -0.197, mean steps 6.09, speed 74.46 f/s, eps 0.97
# 31414: done 4500 games, mean reward -0.197, mean steps 6.08, speed 74.29 f/s, eps 0.97
# 32211: done 4600 games, mean reward -0.196, mean steps 6.11, speed 74.50 f/s, eps 0.97
# 32914: done 4700 games, mean reward -0.195, mean steps 6.11, speed 75.66 f/s, eps 0.97
# 33632: done 4800 games, mean reward -0.194, mean steps 6.11, speed 74.78 f/s, eps 0.97
# 34397: done 4900 games, mean reward -0.193, mean steps 6.12, speed 74.78 f/s, eps 0.97
# 35118: done 5000 games, mean reward -0.192, mean steps 6.13, speed 74.82 f/s, eps 0.96
# 35825: done 5100 games, mean reward -0.192, mean steps 6.13, speed 75.29 f/s, eps 0.96
# 36590: done 5200 games, mean reward -0.192, mean steps 6.14, speed 74.46 f/s, eps 0.96
# 37331: done 5300 games, mean reward -0.191, mean steps 6.15, speed 74.41 f/s, eps 0.96
# 38073: done 5400 games, mean reward -0.191, mean steps 6.15, speed 72.84 f/s, eps 0.96
# 38730: done 5500 games, mean reward -0.191, mean steps 6.15, speed 74.04 f/s, eps 0.96
# 39454: done 5600 games, mean reward -0.190, mean steps 6.15, speed 71.02 f/s, eps 0.96
# 40194: done 5700 games, mean reward -0.191, mean steps 6.16, speed 71.09 f/s, eps 0.96
# 40861: done 5800 games, mean reward -0.191, mean steps 6.15, speed 75.37 f/s, eps 0.96
# 41640: done 5900 games, mean reward -0.191, mean steps 6.16, speed 74.17 f/s, eps 0.96
# 42337: done 6000 games, mean reward -0.191, mean steps 6.16, speed 74.17 f/s, eps 0.96
# 43042: done 6100 games, mean reward -0.192, mean steps 6.16, speed 73.70 f/s, eps 0.96
# 43746: done 6200 games, mean reward -0.192, mean steps 6.16, speed 74.69 f/s, eps 0.96
# 44556: done 6300 games, mean reward -0.192, mean steps 6.18, speed 74.78 f/s, eps 0.96
# 45258: done 6400 games, mean reward -0.192, mean steps 6.17, speed 74.42 f/s, eps 0.95
# 45955: done 6500 games, mean reward -0.191, mean steps 6.17, speed 74.91 f/s, eps 0.95
# 46635: done 6600 games, mean reward -0.191, mean steps 6.17, speed 75.21 f/s, eps 0.95
# 47351: done 6700 games, mean reward -0.190, mean steps 6.17, speed 74.68 f/s, eps 0.95
# 48035: done 6800 games, mean reward -0.190, mean steps 6.17, speed 74.41 f/s, eps 0.95
# 48755: done 6900 games, mean reward -0.190, mean steps 6.17, speed 74.84 f/s, eps 0.95
# 49579: done 7000 games, mean reward -0.190, mean steps 6.19, speed 74.33 f/s, eps 0.95
# 50231: done 7100 games, mean reward -0.189, mean steps 6.18, speed 74.20 f/s, eps 0.95
# 50923: done 7200 games, mean reward -0.189, mean steps 6.18, speed 73.87 f/s, eps 0.95
# 51602: done 7300 games, mean reward -0.189, mean steps 6.17, speed 75.28 f/s, eps 0.95
# 52365: done 7400 games, mean reward -0.189, mean steps 6.18, speed 74.08 f/s, eps 0.95
# 53090: done 7500 games, mean reward -0.190, mean steps 6.18, speed 75.70 f/s, eps 0.95
# 53788: done 7600 games, mean reward -0.190, mean steps 6.18, speed 76.73 f/s, eps 0.95
# 54583: done 7700 games, mean reward -0.190, mean steps 6.19, speed 74.28 f/s, eps 0.95
# 55329: done 7800 games, mean reward -0.191, mean steps 6.20, speed 75.51 f/s, eps 0.94
# 235563: done 30600 games, mean reward -0.191, mean steps 7.37, speed 75.24 f/s, eps 0.76
# 236433: done 30700 games, mean reward -0.191, mean steps 7.38, speed 74.60 f/s, eps 0.76
# 237285: done 30800 games, mean reward -0.191, mean steps 7.39, speed 72.39 f/s, eps 0.76
# 238164: done 30900 games, mean reward -0.192, mean steps 7.40, speed 75.41 f/s, eps 0.76
# 238941: done 31000 games, mean reward -0.192, mean steps 7.40, speed 75.79 f/s, eps 0.76
# 239823: done 31100 games, mean reward -0.192, mean steps 7.41, speed 74.62 f/s, eps 0.76
# 240672: done 31200 games, mean reward -0.192, mean steps 7.42, speed 73.93 f/s, eps 0.76
# 241559: done 31300 games, mean reward -0.192, mean steps 7.42, speed 74.98 f/s, eps 0.76
# 242517: done 31400 games, mean reward -0.192, mean steps 7.43, speed 75.69 f/s, eps 0.76
# 243467: done 31500 games, mean reward -0.191, mean steps 7.44, speed 74.19 f/s, eps 0.76
# 244352: done 31600 games, mean reward -0.191, mean steps 7.46, speed 75.01 f/s, eps 0.76
# 245193: done 31700 games, mean reward -0.193, mean steps 7.46, speed 75.30 f/s, eps 0.75
# 246125: done 31800 games, mean reward -0.193, mean steps 7.48, speed 73.94 f/s, eps 0.75
# 247052: done 31900 games, mean reward -0.193, mean steps 7.49, speed 75.35 f/s, eps 0.75
# 247970: done 32000 games, mean reward -0.194, mean steps 7.50, speed 75.84 f/s, eps 0.75
# 248874: done 32100 games, mean reward -0.194, mean steps 7.51, speed 74.73 f/s, eps 0.75
# 249863: done 32200 games, mean reward -0.195, mean steps 7.53, speed 75.22 f/s, eps 0.75
# 250761: done 32300 games, mean reward -0.195, mean steps 7.53, speed 74.15 f/s, eps 0.75
# 251668: done 32400 games, mean reward -0.195, mean steps 7.54, speed 71.31 f/s, eps 0.75
# 252490: done 32500 games, mean reward -0.194, mean steps 7.54, speed 75.05 f/s, eps 0.75
# 253427: done 32600 games, mean reward -0.195, mean steps 7.55, speed 74.41 f/s, eps 0.75
# 254328: done 32700 games, mean reward -0.194, mean steps 7.56, speed 74.67 f/s, eps 0.75
# 255182: done 32800 games, mean reward -0.194, mean steps 7.57, speed 74.92 f/s, eps 0.74
# 256069: done 32900 games, mean reward -0.194, mean steps 7.58, speed 75.19 f/s, eps 0.74
# 257045: done 33000 games, mean reward -0.193, mean steps 7.60, speed 74.87 f/s, eps 0.74
# 257946: done 33100 games, mean reward -0.194, mean steps 7.61, speed 76.75 f/s, eps 0.74
# 258831: done 33200 games, mean reward -0.194, mean steps 7.62, speed 74.77 f/s, eps 0.74
# 259642: done 33300 games, mean reward -0.193, mean steps 7.62, speed 75.53 f/s, eps 0.74
# 260531: done 33400 games, mean reward -0.193, mean steps 7.62, speed 74.15 f/s, eps 0.74
# 261352: done 33500 games, mean reward -0.193, mean steps 7.62, speed 74.54 f/s, eps 0.74
# 262180: done 33600 games, mean reward -0.194, mean steps 7.61, speed 74.24 f/s, eps 0.74
# 263100: done 33700 games, mean reward -0.194, mean steps 7.62, speed 74.99 f/s, eps 0.74
# 264004: done 33800 games, mean reward -0.194, mean steps 7.64, speed 75.41 f/s, eps 0.74
# 264964: done 33900 games, mean reward -0.195, mean steps 7.65, speed 74.96 f/s, eps 0.74
# 265882: done 34000 games, mean reward -0.195, mean steps 7.66, speed 74.93 f/s, eps 0.73
# 266854: done 34100 games, mean reward -0.195, mean steps 7.68, speed 75.33 f/s, eps 0.73
# 267810: done 34200 games, mean reward -0.196, mean steps 7.69, speed 74.71 f/s, eps 0.73
# 268721: done 34300 games, mean reward -0.197, mean steps 7.71, speed 75.06 f/s, eps 0.73
# 269551: done 34400 games, mean reward -0.197, mean steps 7.71, speed 74.48 f/s, eps 0.73
# 270432: done 34500 games, mean reward -0.196, mean steps 7.71, speed 76.17 f/s, eps 0.73
# 271416: done 34600 games, mean reward -0.196, mean steps 7.73, speed 75.05 f/s, eps 0.73
# 272444: done 34700 games, mean reward -0.196, mean steps 7.75, speed 73.70 f/s, eps 0.73
# 273370: done 34800 games, mean reward -0.197, mean steps 7.76, speed 73.83 f/s, eps 0.73
# 274261: done 34900 games, mean reward -0.197, mean steps 7.77, speed 75.07 f/s, eps 0.73
# 275146: done 35000 games, mean reward -0.197, mean steps 7.77, speed 75.00 f/s, eps 0.72
# 276019: done 35100 games, mean reward -0.196, mean steps 7.77, speed 75.67 f/s, eps 0.72
# 277002: done 35200 games, mean reward -0.198, mean steps 7.79, speed 74.59 f/s, eps 0.72
# 277865: done 35300 games, mean reward -0.198, mean steps 7.79, speed 76.21 f/s, eps 0.72
# 278780: done 35400 games, mean reward -0.198, mean steps 7.80, speed 73.47 f/s, eps 0.72
# 279687: done 35500 games, mean reward -0.198, mean steps 7.82, speed 73.88 f/s, eps 0.72
# 280640: done 35600 games, mean reward -0.198, mean steps 7.83, speed 73.05 f/s, eps 0.72
# 281674: done 35700 games, mean reward -0.198, mean steps 7.85, speed 72.93 f/s, eps 0.72
# 282536: done 35800 games, mean reward -0.199, mean steps 7.86, speed 73.63 f/s, eps 0.72
# 283430: done 35900 games, mean reward -0.199, mean steps 7.87, speed 74.93 f/s, eps 0.72
# 284236: done 36000 games, mean reward -0.199, mean steps 7.87, speed 76.07 f/s, eps 0.72
# 285140: done 36100 games, mean reward -0.199, mean steps 7.88, speed 72.88 f/s, eps 0.71
# 286055: done 36200 games, mean reward -0.199, mean steps 7.88, speed 73.40 f/s, eps 0.71
# 286976: done 36300 games, mean reward -0.198, mean steps 7.89, speed 75.67 f/s, eps 0.71
# 288006: done 36400 games, mean reward -0.198, mean steps 7.90, speed 73.30 f/s, eps 0.71
# 288877: done 36500 games, mean reward -0.199, mean steps 7.90, speed 73.54 f/s, eps 0.71
# 289842: done 36600 games, mean reward -0.200, mean steps 7.91, speed 74.14 f/s, eps 0.71
# 290763: done 36700 games, mean reward -0.201, mean steps 7.91, speed 74.24 f/s, eps 0.71
# 291646: done 36800 games, mean reward -0.201, mean steps 7.92, speed 74.08 f/s, eps 0.71
# 292598: done 36900 games, mean reward -0.201, mean steps 7.94, speed 75.52 f/s, eps 0.71
# 293492: done 37000 games, mean reward -0.201, mean steps 7.94, speed 75.73 f/s, eps 0.71
# 294389: done 37100 games, mean reward -0.201, mean steps 7.94, speed 75.11 f/s, eps 0.71
# 295316: done 37200 games, mean reward -0.200, mean steps 7.96, speed 74.02 f/s, eps 0.70
# 296272: done 37300 games, mean reward -0.201, mean steps 7.96, speed 74.95 f/s, eps 0.70
# 297283: done 37400 games, mean reward -0.201, mean steps 7.97, speed 75.07 f/s, eps 0.70
# 298332: done 37500 games, mean reward -0.201, mean steps 7.99, speed 74.89 f/s, eps 0.70
# 299226: done 37600 games, mean reward -0.200, mean steps 8.00, speed 75.78 f/s, eps 0.70
# 300117: done 37700 games, mean reward -0.199, mean steps 8.00, speed 8.76 f/s, eps 0.70
# 301065: done 37800 games, mean reward -0.199, mean steps 8.00, speed 74.85 f/s, eps 0.70
# 302013: done 37900 games, mean reward -0.200, mean steps 8.02, speed 73.95 f/s, eps 0.70
# 302954: done 38000 games, mean reward -0.200, mean steps 8.02, speed 75.96 f/s, eps 0.70
# 303948: done 38100 games, mean reward -0.199, mean steps 8.03, speed 74.57 f/s, eps 0.70
# 304895: done 38200 games, mean reward -0.198, mean steps 8.04, speed 75.62 f/s, eps 0.70
# 305870: done 38300 games, mean reward -0.198, mean steps 8.05, speed 75.53 f/s, eps 0.69
# 306760: done 38400 games, mean reward -0.198, mean steps 8.06, speed 74.16 f/s, eps 0.69
# 307632: done 38500 games, mean reward -0.198, mean steps 8.06, speed 74.24 f/s, eps 0.69
# 308608: done 38600 games, mean reward -0.198, mean steps 8.07, speed 75.56 f/s, eps 0.69
# 309715: done 38700 games, mean reward -0.198, mean steps 8.09, speed 74.66 f/s, eps 0.69
# 310715: done 38800 games, mean reward -0.198, mean steps 8.12, speed 74.85 f/s, eps 0.69
# 311777: done 38900 games, mean reward -0.198, mean steps 8.14, speed 75.60 f/s, eps 0.69
# 312841: done 39000 games, mean reward -0.197, mean steps 8.15, speed 75.46 f/s, eps 0.69
# 313824: done 39100 games, mean reward -0.197, mean steps 8.17, speed 75.59 f/s, eps 0.69
# 314725: done 39200 games, mean reward -0.198, mean steps 8.17, speed 74.43 f/s, eps 0.69
# 315645: done 39300 games, mean reward -0.198, mean steps 8.18, speed 75.68 f/s, eps 0.68
# 316676: done 39400 games, mean reward -0.198, mean steps 8.20, speed 75.80 f/s, eps 0.68
# 317648: done 39500 games, mean reward -0.198, mean steps 8.22, speed 75.47 f/s, eps 0.68
# 318601: done 39600 games, mean reward -0.197, mean steps 8.23, speed 72.85 f/s, eps 0.68
# 319586: done 39700 games, mean reward -0.197, mean steps 8.24, speed 75.41 f/s, eps 0.68
# 320588: done 39800 games, mean reward -0.197, mean steps 8.25, speed 74.04 f/s, eps 0.68
# 321542: done 39900 games, mean reward -0.198, mean steps 8.26, speed 74.14 f/s, eps 0.68
# 322603: done 40000 games, mean reward -0.198, mean steps 8.28, speed 74.61 f/s, eps 0.68
# 323470: done 40100 games, mean reward -0.198, mean steps 8.28, speed 75.63 f/s, eps 0.68
# 324527: done 40200 games, mean reward -0.198, mean steps 8.30, speed 74.76 f/s, eps 0.68
# 325548: done 40300 games, mean reward -0.197, mean steps 8.32, speed 75.09 f/s, eps 0.67
# 326504: done 40400 games, mean reward -0.198, mean steps 8.33, speed 74.64 f/s, eps 0.67
# 327498: done 40500 games, mean reward -0.198, mean steps 8.34, speed 75.16 f/s, eps 0.67
# 328438: done 40600 games, mean reward -0.199, mean steps 8.35, speed 75.59 f/s, eps 0.67
# 329435: done 40700 games, mean reward -0.198, mean steps 8.36, speed 74.65 f/s, eps 0.67
# 330433: done 40800 games, mean reward -0.198, mean steps 8.37, speed 74.78 f/s, eps 0.67
# 331419: done 40900 games, mean reward -0.197, mean steps 8.38, speed 75.93 f/s, eps 0.67
# 332302: done 41000 games, mean reward -0.197, mean steps 8.39, speed 76.21 f/s, eps 0.67
# 333257: done 41100 games, mean reward -0.197, mean steps 8.40, speed 75.51 f/s, eps 0.67
# 334260: done 41200 games, mean reward -0.196, mean steps 8.42, speed 74.88 f/s, eps 0.67
# 335220: done 41300 games, mean reward -0.196, mean steps 8.42, speed 74.90 f/s, eps 0.66
# 336230: done 41400 games, mean reward -0.196, mean steps 8.43, speed 76.71 f/s, eps 0.66
# 337311: done 41500 games, mean reward -0.197, mean steps 8.44, speed 75.38 f/s, eps 0.66
# 338288: done 41600 games, mean reward -0.197, mean steps 8.45, speed 75.13 f/s, eps 0.66
# 339352: done 41700 games, mean reward -0.197, mean steps 8.47, speed 74.74 f/s, eps 0.66
# 340332: done 41800 games, mean reward -0.198, mean steps 8.48, speed 75.38 f/s, eps 0.66
# 341306: done 41900 games, mean reward -0.198, mean steps 8.48, speed 74.78 f/s, eps 0.66
# 342371: done 42000 games, mean reward -0.197, mean steps 8.50, speed 75.80 f/s, eps 0.66
# 343324: done 42100 games, mean reward -0.197, mean steps 8.50, speed 75.32 f/s, eps 0.66
# 344333: done 42200 games, mean reward -0.195, mean steps 8.50, speed 75.64 f/s, eps 0.66
# 345346: done 42300 games, mean reward -0.194, mean steps 8.51, speed 74.89 f/s, eps 0.65
# 346367: done 42400 games, mean reward -0.195, mean steps 8.53, speed 75.48 f/s, eps 0.65
# 347532: done 42500 games, mean reward -0.194, mean steps 8.56, speed 74.98 f/s, eps 0.65
# 348507: done 42600 games, mean reward -0.194, mean steps 8.56, speed 75.57 f/s, eps 0.65
# 349431: done 42700 games, mean reward -0.195, mean steps 8.57, speed 75.28 f/s, eps 0.65
# 350439: done 42800 games, mean reward -0.195, mean steps 8.58, speed 74.92 f/s, eps 0.65
# 351483: done 42900 games, mean reward -0.195, mean steps 8.60, speed 74.97 f/s, eps 0.65
# 352471: done 43000 games, mean reward -0.194, mean steps 8.60, speed 74.52 f/s, eps 0.65
# 353557: done 43100 games, mean reward -0.194, mean steps 8.61, speed 75.03 f/s, eps 0.65
# 354604: done 43200 games, mean reward -0.194, mean steps 8.63, speed 75.41 f/s, eps 0.65
# 355585: done 43300 games, mean reward -0.194, mean steps 8.65, speed 74.89 f/s, eps 0.64
# 356659: done 43400 games, mean reward -0.194, mean steps 8.66, speed 75.79 f/s, eps 0.64
# 465511: done 53200 games, mean reward -0.196, mean steps 10.13, speed 75.72 f/s, eps 0.53
# 466911: done 53300 games, mean reward -0.197, mean steps 10.17, speed 74.71 f/s, eps 0.53
# 468162: done 53400 games, mean reward -0.197, mean steps 10.19, speed 74.22 f/s, eps 0.53
# 469496: done 53500 games, mean reward -0.197, mean steps 10.22, speed 74.52 f/s, eps 0.53
# 470635: done 53600 games, mean reward -0.197, mean steps 10.23, speed 73.98 f/s, eps 0.53
# 471758: done 53700 games, mean reward -0.198, mean steps 10.24, speed 74.75 f/s, eps 0.53
# 472927: done 53800 games, mean reward -0.198, mean steps 10.26, speed 75.33 f/s, eps 0.53
# 474190: done 53900 games, mean reward -0.198, mean steps 10.29, speed 74.02 f/s, eps 0.53
# ...
# 1252019: done 80600 games, mean reward -0.186, mean steps 49.31, speed 148.26 f/s, eps 0.10
# 1257495: done 80700 games, mean reward -0.185, mean steps 49.61, speed 148.42 f/s, eps 0.10
# 1263960: done 80800 games, mean reward -0.184, mean steps 50.00, speed 147.74 f/s, eps 0.10
# 1270054: done 80900 games, mean reward -0.185, mean steps 50.34, speed 148.07 f/s, eps 0.10
# 1276163: done 81000 games, mean reward -0.184, mean steps 50.70, speed 148.30 f/s, eps 0.10
# 1282232: done 81100 games, mean reward -0.186, mean steps 51.04, speed 147.94 f/s, eps 0.10
# 1288425: done 81200 games, mean reward -0.186, mean steps 51.40, speed 148.13 f/s, eps 0.10
# 1295099: done 81300 games, mean reward -0.187, mean steps 51.77, speed 148.15 f/s, eps 0.10
# 1300983: done 81400 games, mean reward -0.187, mean steps 52.07, speed 72.28 f/s, eps 0.10
# 1307190: done 81500 games, mean reward -0.186, mean steps 52.44, speed 147.56 f/s, eps 0.10
# 1313011: done 81600 games, mean reward -0.186, mean steps 52.72, speed 146.86 f/s, eps 0.10
# 1319511: done 81700 games, mean reward -0.186, mean steps 53.10, speed 146.07 f/s, eps 0.10
# 1325147: done 81800 games, mean reward -0.188, mean steps 53.38, speed 147.37 f/s, eps 0.10
# 1330656: done 81900 games, mean reward -0.187, mean steps 53.62, speed 148.19 f/s, eps 0.10
# 1336041: done 82000 games, mean reward -0.187, mean steps 53.85, speed 147.84 f/s, eps 0.10
# 1341558: done 82100 games, mean reward -0.186, mean steps 54.07, speed 148.05 f/s, eps 0.10
# 1347591: done 82200 games, mean reward -0.186, mean steps 54.38, speed 147.83 f/s, eps 0.10
# 1353772: done 82300 games, mean reward -0.184, mean steps 54.69, speed 147.97 f/s, eps 0.10
# 1359245: done 82400 games, mean reward -0.184, mean steps 54.94, speed 147.73 f/s, eps 0.10
# 1365209: done 82500 games, mean reward -0.184, mean steps 55.24, speed 148.01 f/s, eps 0.10
# 1370852: done 82600 games, mean reward -0.182, mean steps 55.50, speed 148.08 f/s, eps 0.10
# 1376779: done 82700 games, mean reward -0.183, mean steps 55.78, speed 147.92 f/s, eps 0.10
# 1382647: done 82800 games, mean reward -0.183, mean steps 56.03, speed 147.90 f/s, eps 0.10
# 1388506: done 82900 games, mean reward -0.185, mean steps 56.31, speed 147.57 f/s, eps 0.10
# 1394267: done 83000 games, mean reward -0.183, mean steps 56.57, speed 147.64 f/s, eps 0.10
# 1400488: done 83100 games, mean reward -0.182, mean steps 56.82, speed 63.31 f/s, eps 0.10
# 1406639: done 83200 games, mean reward -0.183, mean steps 57.09, speed 147.27 f/s, eps 0.10
# 1412975: done 83300 games, mean reward -0.181, mean steps 57.36, speed 146.33 f/s, eps 0.10
# 1419502: done 83400 games, mean reward -0.180, mean steps 57.63, speed 145.60 f/s, eps 0.10
# 1425050: done 83500 games, mean reward -0.179, mean steps 57.82, speed 145.98 f/s, eps 0.10
# 1430551: done 83600 games, mean reward -0.182, mean steps 58.01, speed 147.36 f/s, eps 0.10
# 1436958: done 83700 games, mean reward -0.184, mean steps 58.31, speed 144.61 f/s, eps 0.10
# 1443174: done 83800 games, mean reward -0.185, mean steps 58.50, speed 147.39 f/s, eps 0.10
# 1448661: done 83900 games, mean reward -0.186, mean steps 58.63, speed 147.63 f/s, eps 0.10
# 1454700: done 84000 games, mean reward -0.187, mean steps 58.79, speed 147.44 f/s, eps 0.10
# 1460987: done 84100 games, mean reward -0.187, mean steps 58.99, speed 147.27 f/s, eps 0.10
# 1467107: done 84200 games, mean reward -0.186, mean steps 59.16, speed 147.39 f/s, eps 0.10
# 1473370: done 84300 games, mean reward -0.187, mean steps 59.32, speed 147.45 f/s, eps 0.10
# 1479599: done 84400 games, mean reward -0.187, mean steps 59.47, speed 147.39 f/s, eps 0.10
# 1486115: done 84500 games, mean reward -0.187, mean steps 59.56, speed 146.49 f/s, eps 0.10
# 1492037: done 84600 games, mean reward -0.189, mean steps 59.64, speed 144.87 f/s, eps 0.10
# 1498192: done 84700 games, mean reward -0.189, mean steps 59.68, speed 145.29 f/s, eps 0.10
# 1504309: done 84800 games, mean reward -0.190, mean steps 59.64, speed 72.31 f/s, eps 0.10
# 1510263: done 84900 games, mean reward -0.188, mean steps 59.58, speed 147.61 f/s, eps 0.10
# 1516597: done 85000 games, mean reward -0.188, mean steps 59.64, speed 146.69 f/s, eps 0.10
# 1523165: done 85100 games, mean reward -0.187, mean steps 59.70, speed 146.99 f/s, eps 0.10
# 1528828: done 85200 games, mean reward -0.187, mean steps 59.65, speed 147.32 f/s, eps 0.10
# 1535234: done 85300 games, mean reward -0.189, mean steps 59.68, speed 146.58 f/s, eps 0.10
# 1540669: done 85400 games, mean reward -0.190, mean steps 59.64, speed 147.12 f/s, eps 0.10
# 1546273: done 85500 games, mean reward -0.192, mean steps 59.66, speed 146.47 f/s, eps 0.10
# 1553176: done 85600 games, mean reward -0.191, mean steps 59.72, speed 146.89 f/s, eps 0.10
# 1558975: done 85700 games, mean reward -0.192, mean steps 59.73, speed 146.16 f/s, eps 0.10
# 1565101: done 85800 games, mean reward -0.191, mean steps 59.80, speed 136.09 f/s, eps 0.10
# 1570902: done 85900 games, mean reward -0.192, mean steps 59.82, speed 138.60 f/s, eps 0.10
# 1576990: done 86000 games, mean reward -0.193, mean steps 59.85, speed 138.64 f/s, eps 0.10
# 1583048: done 86100 games, mean reward -0.194, mean steps 59.89, speed 138.50 f/s, eps 0.10
# 1589030: done 86200 games, mean reward -0.193, mean steps 59.77, speed 140.79 f/s, eps 0.10
# 1595120: done 86300 games, mean reward -0.194, mean steps 59.72, speed 139.56 f/s, eps 0.10
# 1600860: done 86400 games, mean reward -0.189, mean steps 59.67, speed 65.54 f/s, eps 0.10
# 1606703: done 86500 games, mean reward -0.186, mean steps 59.57, speed 141.68 f/s, eps 0.10
# 1612518: done 86600 games, mean reward -0.186, mean steps 59.54, speed 138.27 f/s, eps 0.10
# 1618822: done 86700 games, mean reward -0.186, mean steps 59.54, speed 133.25 f/s, eps 0.10
# 1624519: done 86800 games, mean reward -0.188, mean steps 59.51, speed 138.83 f/s, eps 0.10
# 1631115: done 86900 games, mean reward -0.185, mean steps 59.54, speed 140.71 f/s, eps 0.10
# 1637262: done 87000 games, mean reward -0.186, mean steps 59.53, speed 141.24 f/s, eps 0.10
# 1643416: done 87100 games, mean reward -0.184, mean steps 59.56, speed 140.55 f/s, eps 0.10
# 1649142: done 87200 games, mean reward -0.185, mean steps 59.54, speed 140.18 f/s, eps 0.10
# 1655682: done 87300 games, mean reward -0.184, mean steps 59.59, speed 147.03 f/s, eps 0.10
# 1661461: done 87400 games, mean reward -0.183, mean steps 59.58, speed 147.36 f/s, eps 0.10
# 1667395: done 87500 games, mean reward -0.180, mean steps 59.60, speed 146.90 f/s, eps 0.10
# 1673201: done 87600 games, mean reward -0.178, mean steps 59.59, speed 147.01 f/s, eps 0.10
# 1678492: done 87700 games, mean reward -0.180, mean steps 59.53, speed 146.88 f/s, eps 0.10
# 1685321: done 87800 games, mean reward -0.177, mean steps 59.63, speed 145.36 f/s, eps 0.10
# 1690701: done 87900 games, mean reward -0.181, mean steps 59.51, speed 147.19 f/s, eps 0.10
# 1696242: done 88000 games, mean reward -0.181, mean steps 59.48, speed 147.44 f/s, eps 0.10
# 1702788: done 88100 games, mean reward -0.182, mean steps 59.49, speed 69.61 f/s, eps 0.10
# 1709105: done 88200 games, mean reward -0.182, mean steps 59.42, speed 148.14 f/s, eps 0.10
# 1715596: done 88300 games, mean reward -0.179, mean steps 59.51, speed 148.48 f/s, eps 0.10
# 1721712: done 88400 games, mean reward -0.181, mean steps 59.45, speed 144.93 f/s, eps 0.10
# 1727864: done 88500 games, mean reward -0.182, mean steps 59.41, speed 147.31 f/s, eps 0.10
# 1734438: done 88600 games, mean reward -0.182, mean steps 59.45, speed 130.30 f/s, eps 0.10
# 1740718: done 88700 games, mean reward -0.187, mean steps 59.46, speed 139.70 f/s, eps 0.10
# 1747373: done 88800 games, mean reward -0.186, mean steps 59.45, speed 141.86 f/s, eps 0.10
# 1753492: done 88900 games, mean reward -0.187, mean steps 59.40, speed 139.18 f/s, eps 0.10
# 1759913: done 89000 games, mean reward -0.188, mean steps 59.41, speed 139.09 f/s, eps 0.10
# 1766616: done 89100 games, mean reward -0.190, mean steps 59.47, speed 141.08 f/s, eps 0.10
# 1772614: done 89200 games, mean reward -0.191, mean steps 59.48, speed 145.06 f/s, eps 0.10
# 1779454: done 89300 games, mean reward -0.188, mean steps 59.56, speed 141.03 f/s, eps 0.10
# 1980492: done 92600 games, mean reward -0.187, mean steps 59.97, speed 145.67 f/s, eps 0.10
# 1987069: done 92700 games, mean reward -0.185, mean steps 60.03, speed 145.86 f/s, eps 0.10
# 1993669: done 92800 games, mean reward -0.187, mean steps 60.10, speed 147.23 f/s, eps 0.10
# 1999662: done 92900 games, mean reward -0.186, mean steps 60.12, speed 144.25 f/s, eps 0.10
# 2005052: done 93000 games, mean reward -0.187, mean steps 60.08, speed 67.43 f/s, eps 0.10
# 2010978: done 93100 games, mean reward -0.186, mean steps 60.05, speed 143.06 f/s, eps 0.10
# 2016578: done 93200 games, mean reward -0.186, mean steps 60.00, speed 146.97 f/s, eps 0.10
# 2022209: done 93300 games, mean reward -0.187, mean steps 59.92, speed 147.05 f/s, eps 0.10
# 2027744: done 93400 games, mean reward -0.186, mean steps 59.83, speed 146.39 f/s, eps 0.10
# 2034368: done 93500 games, mean reward -0.188, mean steps 59.93, speed 146.95 f/s, eps 0.10
# 2040278: done 93600 games, mean reward -0.186, mean steps 59.97, speed 146.41 f/s, eps 0.10
# 2046669: done 93700 games, mean reward -0.185, mean steps 59.97, speed 145.61 f/s, eps 0.10
# 2052253: done 93800 games, mean reward -0.184, mean steps 59.91, speed 147.14 f/s, eps 0.10
# 2058083: done 93900 games, mean reward -0.185, mean steps 59.94, speed 145.03 f/s, eps 0.10
# 2065195: done 94000 games, mean reward -0.185, mean steps 60.05, speed 146.20 f/s, eps 0.10
# 2071343: done 94100 games, mean reward -0.185, mean steps 60.04, speed 139.51 f/s, eps 0.10
# 2077535: done 94200 games, mean reward -0.187, mean steps 60.04, speed 141.86 f/s, eps 0.10
# 2083976: done 94300 games, mean reward -0.186, mean steps 60.06, speed 139.17 f/s, eps 0.10
# 2090127: done 94400 games, mean reward -0.185, mean steps 60.05, speed 146.33 f/s, eps 0.10
# 2096935: done 94500 games, mean reward -0.187, mean steps 60.08, speed 142.08 f/s, eps 0.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9746179af54a> in <module>
#      88                 for key, val in res.items():
#      89                     writer.add_scalar(key + "_test", val, step_idx)
# ---> 90                 res = validation.validation_run(env_val, net, device=device)
#      91                 for key, val in res.items():
#      92                     writer.add_scalar(key + "_val", val, step_idx)
#
# ~\Desktop\reinforcement learning\Chapter 8\lib\validation.py in validation_run(env, net, episodes, device, epsilon, comission)
#      24         while True:
#      25             obs_v = torch.tensor([obs]).to(device)
# ---> 26             out_v = net(obs_v)
#      27
#      28             action_idx = out_v.max(dim=1)[1].item()
#
# ~\reinforcement\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~\Desktop\reinforcement learning\Chapter 8\lib\models.py in forward(self, x)
#      32     def forward(self, x):
#      33         val = self.fc_val(x)
# ---> 34         adv = self.fc_adv(x)
#      35         return val + adv - adv.mean(dim=1, keepdim=True)
#      36
#
# ~\reinforcement\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~\reinforcement\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~\reinforcement\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~\reinforcement\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~\reinforcement\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1367     if input.dim() == 2 and bias is not None:
#    1368         # fused op is marginally faster
# -> 1369         ret = torch.addmm(bias, input, weight.t())
#    1370     else:
#    1371         output = input.matmul(weight.t())
#
# KeyboardInterrupt:
