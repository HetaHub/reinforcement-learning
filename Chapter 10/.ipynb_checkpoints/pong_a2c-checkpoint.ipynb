# %%
#!/usr/bin/env python3
import gym
import ptan
import numpy as np
import argparse
from tensorboardX import SummaryWriter

import torch
import torch.nn as nn
import torch.nn.utils as nn_utils
import torch.nn.functional as F
import torch.optim as optim

from lib import common

# %%
GAMMA = 0.99
LEARNING_RATE = 0.001
#Entropy beta is the resize ratio of entropy bonus
ENTROPY_BETA = 0.01
BATCH_SIZE = 128
NUM_ENVS = 50

#Reward steps define how many steps for each action to approximate the discounted total reward, because we can use value
#approximation for the state value in further steps, we can use less steps.
REWARD_STEPS = 4
#Clip_grad used for gradient clipping, it can prevent the gradient becomes too big and push the policy too further in
#optimization
CLIP_GRAD = 0.1

# %%
class AtariA2C(nn.Module):
    #we have a common convolution and 2 sequential network, one return policy with action probability distribution,
    #2nd will return a value, which is approximated as state value.
    def __init__(self, input_shape, n_actions):
        super(AtariA2C, self).__init__()
        
        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )
        
        conv_out_size = self._get_conv_out(input_shape)
        self.policy = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )
        
        self.value = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )
        
    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))
    
    def forward(self, x):
        fx = x.float() / 256
        conv_out = self.conv(fx).view(fx.size()[0], -1)
        return self.policy(conv_out), self.value(conv_out)

# %%
#we get batch environment, return 3 tensor: batch state, batch action and batch q-value, the q-value will be used to
#calculate MSE loss and optimize value approximation, which is similar to DQN, another is to calculate action advantage.
"""	
Convert batch into training tensors	
:param batch:	
:param net:	
:return: states variable, actions tensor, reference values variable	
"""
def unpack_batch(batch, net, device='cpu'):
    #we get the batch transfer and copy to array, reward value included discounted reward from reward_steps, if episode not
    #done, we remember the batch index.
    states = []
    actions = []
    rewards = []
    
    not_done_idx = []
    last_states = []
    for idx, exp in enumerate(batch):
        states.append(np.array(exp.state, copy=False))
        actions.append(int(exp.action))
        rewards.append(exp.reward)
        if exp.last_state is not None:
            not_done_idx.append(idx)
            last_states.append(np.array(exp.last_state, copy=False))
    
    #convert states, actions to PyTorch Tensor and copy to GPU.
    states_v = torch.FloatTensor(np.array(states, copy=False)).to(device)
    actions_t = torch.LongTensor(actions).to(device)
    
    #get the last state value and multiply with discount factor to add to discounted reward
    rewards_np = np.array(rewards, dtype=np.float32)
    if not_done_idx:
        last_states_v = torch.FloatTensor(last_states).to(device)
        last_vals_v = net(last_states_v)[1]
        last_vals_np = last_vals_v.data.cpu().numpy()[:, 0]
        rewards_np[not_done_idx] += GAMMA ** REWARD_STEPS * last_vals_np
    
    #pack up q-value and return
    ref_vals_v = torch.FloatTensor(rewards_np).to(device)
    return states_v, actions_t, ref_vals_v

# %%
if __name__ == "__main__":
    #training code nearly same as before, but now we use multiple environment to collect experience,instead of 1 environment
    parser = argparse.ArgumentParser()
    parser.add_argument("--cuda", default=True, action="store_true", help="Enable cuda")
    parser.add_argument("-n", "--name", default="t2", required=False, help="Name of the run")
    args, unknown = parser.parse_known_args()
    device = torch.device("cuda" if args.cuda else "cpu")
    
    make_env = lambda: ptan.common.wrappers.wrap_dqn(gym.make("PongNoFrameskip-v4"))
    envs = [make_env() for _ in range(NUM_ENVS)]
    writer = SummaryWriter(comment="-pong-a2c_" + args.name)
    
    net = AtariA2C(envs[0].observation_space.shape, envs[0].action_space.n).to(device)
    print(net)
    
    agent = ptan.agent.PolicyAgent(lambda x: net(x)[0], apply_softmax=True, device=device)
    exp_source = ptan.experience.ExperienceSourceFirstLast(envs, agent, gamma=GAMMA, steps_count=REWARD_STEPS)
    
    #mostly epsilon will set to a very small number to prevent zero division, such as 1e-8, 1e-10, but here if using 
    #such small value, it won't converge, using 1e-8 will make the gradient becomes too big
    optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE, eps=1e-3)
    
    batch = []
    
    #we use 2 wrappers: common.RewardTracker, which will calculate the mean reward of 100 episodes, and tell use when will
    #it exceed the boundary. Another is from ptan TBMeanTracker, it output the mean value of last 10 steps to TensorBoard,
    #we will output a smoothed value for every 10 steps instead of writing all steps into the TensorBoard
    with common.RewardTracker(writer, stop_reward=18) as tracker:
        with ptan.common.utils.TBMeanTracker(writer, batch_size=10) as tb_tracker:
            for step_idx, exp in enumerate(exp_source):
                batch.append(exp)
                
                #handle new rewards
                new_rewards = exp_source.pop_total_rewards()
                if new_rewards:
                    if tracker.reward(new_rewards[0], step_idx):
                        break
                        
                if len(batch) < BATCH_SIZE:
                    continue
                
                #we use the unpack batch process to unpack data, then put into the network to return the policy and value.
                states_v, actions_t, vals_ref_v = unpack_batch(batch, net, device=device)
                batch.clear()
                
                optimizer.zero_grad()
                logits_v, value_v = net(states_v)
                
                #we calculated value loss with the MSE between network return value and 4 step Bellman equation
                #approximation value
                loss_value_v = F.mse_loss(value_v.squeeze(-1), vals_ref_v)
                
                #we calculate policy loss to get policy gradient, we will get the log probability of policy and calculate
                #action advantage: A(s,a) = Q(s,a) - V(s), we don't want the policy gradient go to value loss network, so we
                #use detach(), then we get the probability of our chosen action. The policy gradient loss will be 
                #negative mean of resized log policy, because policy should be maximize and loss should be minimize.
                #we use log_softmax to return probability distribution
                log_prob_v = F.log_softmax(logits_v, dim=1)
                adv_v = vals_ref_v - value_v.squeeze(-1).detach()
                log_prob_actions_v = adv_v * log_prob_v[range(BATCH_SIZE), actions_t]
                loss_policy_v = -log_prob_actions_v.mean()
                
                prob_v = F.softmax(logits_v, dim=1)
                #we calculate entropy loss here, it equals to our resized policy with negative value.
                entropy_loss_v = ENTROPY_BETA * (prob_v * log_prob_v).sum(dim=1).mean()
                
                #we get the policy gradient to track the max gradient, gradient variance and l2 norm value.
                loss_policy_v.backward(retain_graph=True)
                grads = np.concatenate([p.grad.data.cpu().numpy().flatten()
                                        for p in net.parameters()
                                        if p.grad is not None])
                
                #we back propagate entropy loss, loss value and clip the gradient, then renew the network
                loss_v = entropy_loss_v + loss_value_v
                loss_v.backward()
                nn_utils.clip_grad_norm_(net.parameters(), CLIP_GRAD)
                optimizer.step()
                loss_v += loss_policy_v
                
                tb_tracker.track("advantage", adv_v.cpu().numpy(), step_idx)
                tb_tracker.track("values", value_v.cpu().detach().numpy(), step_idx)
                tb_tracker.track("batch_rewards", vals_ref_v.cpu().numpy(), step_idx)
                tb_tracker.track("loss_entropy",entropy_loss_v.cpu().detach().numpy(), step_idx)
                tb_tracker.track("loss_policy",loss_policy_v.cpu().detach().numpy(), step_idx)
                tb_tracker.track("loss_value", loss_value_v.cpu().detach().numpy(), step_idx)
                tb_tracker.track("loss_total", loss_v.cpu().detach().numpy(), step_idx)
                tb_tracker.track("grad_l2", np.sqrt(np.mean(np.square(grads))), step_idx)
                tb_tracker.track("grad_max", np.max(np.abs(grads)), step_idx)
                tb_tracker.track("grad_var", np.var(grads), step_idx)
# Out:
# AtariA2C(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (policy): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
#   (value): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# 37660: done 1 games, mean reward -21.000, speed 107.00 f/s
# 37868: done 2 games, mean reward -21.000, speed 123.54 f/s
# 39037: done 3 games, mean reward -21.000, speed 103.49 f/s
# 39469: done 4 games, mean reward -21.000, speed 93.07 f/s
# 39903: done 5 games, mean reward -21.000, speed 112.26 f/s
# 40051: done 6 games, mean reward -21.000, speed 114.75 f/s
# 40607: done 7 games, mean reward -21.000, speed 98.62 f/s
# 40689: done 8 games, mean reward -21.000, speed 204.99 f/s
# 40746: done 9 games, mean reward -21.000, speed 66.57 f/s
# 40797: done 10 games, mean reward -21.000, speed 190.09 f/s
# 40893: done 11 games, mean reward -21.000, speed 83.46 f/s
# 40909: done 12 games, mean reward -21.000, speed 177.09 f/s
# 41501: done 13 games, mean reward -21.000, speed 99.39 f/s
# 41622: done 14 games, mean reward -20.929, speed 103.85 f/s
# 42038: done 15 games, mean reward -20.933, speed 102.65 f/s
# 42064: done 16 games, mean reward -20.938, speed 205.19 f/s
# 42878: done 17 games, mean reward -20.882, speed 109.38 f/s
# 42976: done 18 games, mean reward -20.889, speed 93.83 f/s
# 43108: done 19 games, mean reward -20.842, speed 109.04 f/s
# 43193: done 20 games, mean reward -20.800, speed 79.26 f/s
# 43657: done 21 games, mean reward -20.810, speed 98.14 f/s
# 43726: done 22 games, mean reward -20.818, speed 222.13 f/s
# 43774: done 23 games, mean reward -20.826, speed 210.63 f/s
# 43851: done 24 games, mean reward -20.833, speed 68.89 f/s
# 44007: done 25 games, mean reward -20.800, speed 106.85 f/s
# 44609: done 26 games, mean reward -20.769, speed 95.86 f/s
# 44946: done 27 games, mean reward -20.778, speed 100.68 f/s
# 45719: done 28 games, mean reward -20.750, speed 107.01 f/s
# 45902: done 29 games, mean reward -20.759, speed 126.52 f/s
# 46243: done 30 games, mean reward -20.733, speed 101.95 f/s
# 46784: done 31 games, mean reward -20.742, speed 106.93 f/s
# 46796: done 32 games, mean reward -20.750, speed 125.29 f/s
# 47279: done 33 games, mean reward -20.727, speed 102.83 f/s
# 48158: done 34 games, mean reward -20.676, speed 108.09 f/s
# 48344: done 35 games, mean reward -20.686, speed 128.76 f/s
# 48585: done 36 games, mean reward -20.694, speed 107.67 f/s
# 48889: done 37 games, mean reward -20.676, speed 119.12 f/s
# 49430: done 38 games, mean reward -20.632, speed 93.58 f/s
# 49604: done 39 games, mean reward -20.590, speed 120.79 f/s
# 49759: done 40 games, mean reward -20.600, speed 108.30 f/s
# 50030: done 41 games, mean reward -20.585, speed 108.46 f/s
# 50169: done 42 games, mean reward -20.548, speed 114.38 f/s
# 50292: done 43 games, mean reward -20.535, speed 105.14 f/s
# 50317: done 44 games, mean reward -20.500, speed 33.22 f/s
# 50722: done 45 games, mean reward -20.489, speed 112.18 f/s
# 50762: done 46 games, mean reward -20.478, speed 226.20 f/s
# 50904: done 47 games, mean reward -20.447, speed 105.81 f/s
# 51983: done 48 games, mean reward -20.438, speed 106.85 f/s
# 57756: done 49 games, mean reward -20.367, speed 110.08 f/s
# 62179: done 50 games, mean reward -20.340, speed 110.54 f/s
# 78681: done 51 games, mean reward -20.353, speed 109.64 f/s
# 79875: done 52 games, mean reward -20.365, speed 104.97 f/s
# 80097: done 53 games, mean reward -20.377, speed 144.66 f/s
# 81338: done 54 games, mean reward -20.389, speed 106.05 f/s
# 81349: done 55 games, mean reward -20.400, speed 174.43 f/s
# 81523: done 56 games, mean reward -20.393, speed 122.81 f/s
# 81709: done 57 games, mean reward -20.404, speed 94.92 f/s
# 81755: done 58 games, mean reward -20.414, speed 203.76 f/s
# 82497: done 59 games, mean reward -20.424, speed 110.13 f/s
# 82730: done 60 games, mean reward -20.433, speed 100.37 f/s
# 82943: done 61 games, mean reward -20.443, speed 147.00 f/s
# 83371: done 62 games, mean reward -20.435, speed 94.63 f/s
# 83400: done 63 games, mean reward -20.444, speed 203.12 f/s
# 83591: done 64 games, mean reward -20.453, speed 92.88 f/s
# 84631: done 65 games, mean reward -20.431, speed 109.92 f/s
# 84897: done 66 games, mean reward -20.439, speed 111.12 f/s
# 85378: done 67 games, mean reward -20.448, speed 109.65 f/s
# 85666: done 68 games, mean reward -20.441, speed 97.53 f/s
# 85888: done 69 games, mean reward -20.449, speed 85.87 f/s
# 86970: done 70 games, mean reward -20.443, speed 113.56 f/s
# 87624: done 71 games, mean reward -20.451, speed 110.74 f/s
# 90463: done 72 games, mean reward -20.444, speed 108.23 f/s
# 90550: done 73 games, mean reward -20.452, speed 86.81 f/s
# 91069: done 74 games, mean reward -20.446, speed 109.63 f/s
# 91538: done 75 games, mean reward -20.453, speed 99.74 f/s
# 91558: done 76 games, mean reward -20.434, speed 177.33 f/s
# 91619: done 77 games, mean reward -20.429, speed 242.88 f/s
# 92434: done 78 games, mean reward -20.436, speed 103.99 f/s
# 92488: done 79 games, mean reward -20.418, speed 172.66 f/s
# 92788: done 80 games, mean reward -20.413, speed 116.89 f/s
# 93577: done 81 games, mean reward -20.407, speed 103.71 f/s
# 93884: done 82 games, mean reward -20.402, speed 121.39 f/s
# 94318: done 83 games, mean reward -20.410, speed 116.18 f/s
# 95356: done 84 games, mean reward -20.405, speed 111.17 f/s
# 95415: done 85 games, mean reward -20.400, speed 59.92 f/s
# 95757: done 86 games, mean reward -20.384, speed 92.98 f/s
# 95778: done 87 games, mean reward -20.368, speed 205.00 f/s
# 95977: done 88 games, mean reward -20.364, speed 137.76 f/s
# 96536: done 89 games, mean reward -20.360, speed 101.68 f/s
# 96641: done 90 games, mean reward -20.356, speed 107.40 f/s
# 97255: done 91 games, mean reward -20.352, speed 120.83 f/s
# 97411: done 92 games, mean reward -20.348, speed 80.95 f/s
# 97611: done 93 games, mean reward -20.344, speed 134.26 f/s
# 99748: done 94 games, mean reward -20.330, speed 106.63 f/s
# 101120: done 95 games, mean reward -20.326, speed 111.44 f/s
# 101338: done 96 games, mean reward -20.323, speed 149.13 f/s
# 101957: done 97 games, mean reward -20.320, speed 108.93 f/s
# 101964: done 98 games, mean reward -20.327, speed 83.41 f/s
# 104556: done 99 games, mean reward -20.323, speed 111.81 f/s
# 106279: done 100 games, mean reward -20.330, speed 106.28 f/s
# 121152: done 101 games, mean reward -20.330, speed 104.73 f/s
# 121263: done 102 games, mean reward -20.330, speed 87.13 f/s
# 121793: done 103 games, mean reward -20.330, speed 104.00 f/s
# 122287: done 104 games, mean reward -20.330, speed 99.93 f/s
# 122570: done 105 games, mean reward -20.330, speed 115.86 f/s
# 122836: done 106 games, mean reward -20.320, speed 111.10 f/s
# 124201: done 107 games, mean reward -20.320, speed 106.33 f/s
# 124819: done 108 games, mean reward -20.320, speed 111.92 f/s
# 125207: done 109 games, mean reward -20.320, speed 106.79 f/s
# 125791: done 110 games, mean reward -20.320, speed 117.84 f/s
# 126364: done 111 games, mean reward -20.320, speed 102.12 f/s
# 126896: done 112 games, mean reward -20.320, speed 111.65 f/s
# 127456: done 113 games, mean reward -20.310, speed 118.32 f/s
# 127787: done 114 games, mean reward -20.310, speed 105.36 f/s
# 128131: done 115 games, mean reward -20.300, speed 102.45 f/s
# 129490: done 116 games, mean reward -20.300, speed 113.24 f/s
# 129699: done 117 games, mean reward -20.310, speed 96.50 f/s
# 131963: done 118 games, mean reward -20.310, speed 114.47 f/s
# 132445: done 119 games, mean reward -20.310, speed 102.48 f/s
# 132607: done 120 games, mean reward -20.320, speed 119.47 f/s
# 133409: done 121 games, mean reward -20.320, speed 103.08 f/s
# 133446: done 122 games, mean reward -20.310, speed 178.34 f/s
# 133507: done 123 games, mean reward -20.300, speed 69.46 f/s
# 135024: done 124 games, mean reward -20.290, speed 115.53 f/s
# 135050: done 125 games, mean reward -20.300, speed 33.39 f/s
# 135931: done 126 games, mean reward -20.310, speed 118.00 f/s
# 136254: done 127 games, mean reward -20.310, speed 98.93 f/s
# 136791: done 128 games, mean reward -20.320, speed 111.55 f/s
# 137401: done 129 games, mean reward -20.310, speed 109.32 f/s
# 137679: done 130 games, mean reward -20.320, speed 116.17 f/s
# 138328: done 131 games, mean reward -20.310, speed 110.71 f/s
# 139169: done 132 games, mean reward -20.300, speed 105.07 f/s
# 139401: done 133 games, mean reward -20.300, speed 101.79 f/s
# 140436: done 134 games, mean reward -20.310, speed 110.15 f/s
# 140534: done 135 games, mean reward -20.310, speed 224.44 f/s
# 140657: done 136 games, mean reward -20.290, speed 110.75 f/s
# 142376: done 137 games, mean reward -20.290, speed 106.70 f/s
# 143544: done 138 games, mean reward -20.300, speed 108.71 f/s
# 144256: done 139 games, mean reward -20.320, speed 106.20 f/s
# 144318: done 140 games, mean reward -20.320, speed 215.28 f/s
# 144339: done 141 games, mean reward -20.320, speed 192.60 f/s
# 145256: done 142 games, mean reward -20.340, speed 112.02 f/s
# 145753: done 143 games, mean reward -20.350, speed 94.76 f/s
# 147029: done 144 games, mean reward -20.350, speed 109.00 f/s
# 147903: done 145 games, mean reward -20.340, speed 104.54 f/s
# 148059: done 146 games, mean reward -20.340, speed 124.82 f/s
# 155051: done 147 games, mean reward -20.350, speed 107.22 f/s
# 156290: done 148 games, mean reward -20.330, speed 111.51 f/s
# 160756: done 149 games, mean reward -20.360, speed 110.83 f/s
# 160930: done 150 games, mean reward -20.380, speed 80.65 f/s
# 164141: done 151 games, mean reward -20.380, speed 108.91 f/s
# 164467: done 152 games, mean reward -20.380, speed 123.43 f/s
# 164634: done 153 games, mean reward -20.380, speed 78.89 f/s
# 166987: done 154 games, mean reward -20.370, speed 110.66 f/s
# 167216: done 155 games, mean reward -20.370, speed 102.06 f/s
# 167339: done 156 games, mean reward -20.370, speed 105.71 f/s
# 167600: done 157 games, mean reward -20.370, speed 111.24 f/s
# 167742: done 158 games, mean reward -20.370, speed 111.46 f/s
# 168762: done 159 games, mean reward -20.370, speed 109.59 f/s
# 169704: done 160 games, mean reward -20.370, speed 114.53 f/s
# 171034: done 161 games, mean reward -20.370, speed 108.46 f/s
# 172063: done 162 games, mean reward -20.360, speed 111.84 f/s
# 172672: done 163 games, mean reward -20.340, speed 105.18 f/s
# 173398: done 164 games, mean reward -20.340, speed 116.99 f/s
# 173660: done 165 games, mean reward -20.360, speed 114.39 f/s
# 173690: done 166 games, mean reward -20.360, speed 130.57 f/s
# 173938: done 167 games, mean reward -20.360, speed 111.17 f/s
# 175442: done 168 games, mean reward -20.360, speed 106.56 f/s
# 176645: done 169 games, mean reward -20.350, speed 102.44 f/s
# 177236: done 170 games, mean reward -20.360, speed 118.99 f/s
# 178248: done 171 games, mean reward -20.360, speed 108.57 f/s
# 178263: done 172 games, mean reward -20.370, speed 156.43 f/s
# 178621: done 173 games, mean reward -20.350, speed 110.12 f/s
# 179960: done 174 games, mean reward -20.350, speed 112.54 f/s
# 180030: done 175 games, mean reward -20.350, speed 72.88 f/s
# 181695: done 176 games, mean reward -20.370, speed 111.61 f/s
# 182199: done 177 games, mean reward -20.380, speed 108.75 f/s
# 182491: done 178 games, mean reward -20.370, speed 107.65 f/s
# 182581: done 179 games, mean reward -20.380, speed 92.31 f/s
# 183018: done 180 games, mean reward -20.380, speed 118.16 f/s
# 183328: done 181 games, mean reward -20.380, speed 95.81 f/s
# 184778: done 182 games, mean reward -20.390, speed 109.59 f/s
# 186274: done 183 games, mean reward -20.390, speed 105.26 f/s
# 186990: done 184 games, mean reward -20.400, speed 114.66 f/s
# 187290: done 185 games, mean reward -20.410, speed 96.54 f/s
# 188804: done 186 games, mean reward -20.420, speed 112.22 f/s
# 191751: done 187 games, mean reward -20.430, speed 110.71 f/s
# 192023: done 188 games, mean reward -20.440, speed 113.95 f/s
# 192043: done 189 games, mean reward -20.430, speed 215.35 f/s
# 192818: done 190 games, mean reward -20.430, speed 112.24 f/s
# 193858: done 191 games, mean reward -20.430, speed 110.25 f/s
# 194202: done 192 games, mean reward -20.430, speed 102.52 f/s
# 194547: done 193 games, mean reward -20.440, speed 126.81 f/s
# 194707: done 194 games, mean reward -20.450, speed 69.39 f/s
# 195334: done 195 games, mean reward -20.460, speed 108.34 f/s
# 198821: done 196 games, mean reward -20.430, speed 109.24 f/s
# 202354: done 197 games, mean reward -20.430, speed 106.68 f/s
# 203488: done 198 games, mean reward -20.430, speed 103.44 f/s
# 206591: done 199 games, mean reward -20.420, speed 108.64 f/s
# 207661: done 200 games, mean reward -20.420, speed 104.63 f/s
# 208080: done 201 games, mean reward -20.400, speed 114.83 f/s
# 208710: done 202 games, mean reward -20.360, speed 105.15 f/s
# 208986: done 203 games, mean reward -20.360, speed 111.55 f/s
# 209269: done 204 games, mean reward -20.350, speed 113.84 f/s
# 209436: done 205 games, mean reward -20.340, speed 82.80 f/s
# 209539: done 206 games, mean reward -20.350, speed 91.22 f/s
# 210751: done 207 games, mean reward -20.350, speed 111.00 f/s
# 210861: done 208 games, mean reward -20.350, speed 101.55 f/s
# 211902: done 209 games, mean reward -20.350, speed 109.81 f/s
# 214331: done 210 games, mean reward -20.350, speed 106.08 f/s
# 214620: done 211 games, mean reward -20.340, speed 115.49 f/s
# 216794: done 212 games, mean reward -20.340, speed 108.26 f/s
# 218099: done 213 games, mean reward -20.350, speed 112.30 f/s
# 219134: done 214 games, mean reward -20.350, speed 105.90 f/s
# 219270: done 215 games, mean reward -20.350, speed 74.57 f/s
# 219811: done 216 games, mean reward -20.340, speed 113.29 f/s
# 222033: done 217 games, mean reward -20.330, speed 108.48 f/s
# 222420: done 218 games, mean reward -20.330, speed 107.08 f/s
# 224232: done 219 games, mean reward -20.340, speed 103.98 f/s
# 224345: done 220 games, mean reward -20.320, speed 103.38 f/s
# 225570: done 221 games, mean reward -20.310, speed 105.49 f/s
# 225698: done 222 games, mean reward -20.300, speed 93.71 f/s
# 225862: done 223 games, mean reward -20.300, speed 123.68 f/s
# 227046: done 224 games, mean reward -20.310, speed 109.53 f/s
# 228262: done 225 games, mean reward -20.290, speed 102.83 f/s
# 229273: done 226 games, mean reward -20.280, speed 105.28 f/s
# 229447: done 227 games, mean reward -20.270, speed 122.46 f/s
# 229527: done 228 games, mean reward -20.260, speed 85.18 f/s
# 229630: done 229 games, mean reward -20.250, speed 215.07 f/s
# 229718: done 230 games, mean reward -20.220, speed 88.31 f/s
# 230508: done 231 games, mean reward -20.210, speed 111.02 f/s
# 232450: done 232 games, mean reward -20.210, speed 105.16 f/s
# 234324: done 233 games, mean reward -20.200, speed 110.06 f/s
# 235119: done 234 games, mean reward -20.210, speed 108.10 f/s
# 235395: done 235 games, mean reward -20.210, speed 90.29 f/s
# 235853: done 236 games, mean reward -20.220, speed 118.93 f/s
# 236176: done 237 games, mean reward -20.230, speed 95.42 f/s
# 236743: done 238 games, mean reward -20.230, speed 110.92 f/s
# 237465: done 239 games, mean reward -20.210, speed 103.50 f/s
# 237543: done 240 games, mean reward -20.200, speed 238.38 f/s
# 240455: done 241 games, mean reward -20.200, speed 107.27 f/s
# 241120: done 242 games, mean reward -20.200, speed 111.94 f/s
# 242999: done 243 games, mean reward -20.170, speed 107.94 f/s
# 245569: done 244 games, mean reward -20.180, speed 108.07 f/s
# 247202: done 245 games, mean reward -20.190, speed 105.49 f/s
# 247261: done 246 games, mean reward -20.190, speed 184.41 f/s
# 249151: done 247 games, mean reward -20.180, speed 106.64 f/s
# 250428: done 248 games, mean reward -20.210, speed 106.74 f/s
# 250482: done 249 games, mean reward -20.220, speed 221.41 f/s
# 250595: done 250 games, mean reward -20.220, speed 97.95 f/s
# 251032: done 251 games, mean reward -20.210, speed 100.97 f/s
# 254542: done 252 games, mean reward -20.200, speed 110.74 f/s
# 256497: done 253 games, mean reward -20.190, speed 110.16 f/s
# 257865: done 254 games, mean reward -20.190, speed 109.12 f/s
# 259998: done 255 games, mean reward -20.180, speed 108.16 f/s
# 260864: done 256 games, mean reward -20.190, speed 104.53 f/s
# 261023: done 257 games, mean reward -20.170, speed 122.09 f/s
# 263278: done 258 games, mean reward -20.170, speed 110.30 f/s
# 263541: done 259 games, mean reward -20.170, speed 112.64 f/s
# 265763: done 260 games, mean reward -20.170, speed 107.29 f/s
# 266744: done 261 games, mean reward -20.150, speed 116.30 f/s
# 266761: done 262 games, mean reward -20.170, speed 24.53 f/s
# 266876: done 263 games, mean reward -20.180, speed 218.72 f/s
# 267116: done 264 games, mean reward -20.180, speed 105.48 f/s
# 267351: done 265 games, mean reward -20.180, speed 103.66 f/s
# 267803: done 266 games, mean reward -20.180, speed 96.50 f/s
# 268533: done 267 games, mean reward -20.180, speed 107.52 f/s
# 271369: done 268 games, mean reward -20.150, speed 106.48 f/s
# 271569: done 269 games, mean reward -20.150, speed 138.54 f/s
# 271744: done 270 games, mean reward -20.140, speed 85.26 f/s
# 272317: done 271 games, mean reward -20.140, speed 113.72 f/s
# 272353: done 272 games, mean reward -20.130, speed 177.33 f/s
# 272795: done 273 games, mean reward -20.150, speed 100.82 f/s
# 273221: done 274 games, mean reward -20.160, speed 115.94 f/s
# 275046: done 275 games, mean reward -20.140, speed 110.37 f/s
# 276067: done 276 games, mean reward -20.130, speed 112.93 f/s
# 276390: done 277 games, mean reward -20.110, speed 98.70 f/s
# 276963: done 278 games, mean reward -20.120, speed 115.75 f/s
# 277767: done 279 games, mean reward -20.110, speed 96.75 f/s
# 278690: done 280 games, mean reward -20.110, speed 110.72 f/s
# 278979: done 281 games, mean reward -20.110, speed 119.28 f/s
# 280006: done 282 games, mean reward -20.090, speed 109.27 f/s
# 281347: done 283 games, mean reward -20.090, speed 104.77 f/s
# 283053: done 284 games, mean reward -20.060, speed 110.84 f/s
# 283911: done 285 games, mean reward -20.050, speed 104.65 f/s
# 284975: done 286 games, mean reward -20.050, speed 107.47 f/s
# 285057: done 287 games, mean reward -20.060, speed 83.43 f/s
# 287166: done 288 games, mean reward -20.050, speed 112.19 f/s
# 289364: done 289 games, mean reward -20.070, speed 107.40 f/s
# 289448: done 290 games, mean reward -20.080, speed 70.55 f/s
# 289991: done 291 games, mean reward -20.080, speed 112.75 f/s
# 292149: done 292 games, mean reward -20.080, speed 108.87 f/s
# 292230: done 293 games, mean reward -20.050, speed 79.86 f/s
# 293100: done 294 games, mean reward -20.050, speed 113.76 f/s
# 293925: done 295 games, mean reward -20.050, speed 104.69 f/s
# 295508: done 296 games, mean reward -20.090, speed 111.24 f/s
# 296778: done 297 games, mean reward -20.090, speed 108.82 f/s
# 297777: done 298 games, mean reward -20.090, speed 105.62 f/s
# 298893: done 299 games, mean reward -20.110, speed 100.92 f/s
# 299592: done 300 games, mean reward -20.090, speed 111.91 f/s
# 299969: done 301 games, mean reward -20.080, speed 103.13 f/s
# 301492: done 302 games, mean reward -20.110, speed 107.38 f/s
# 302414: done 303 games, mean reward -20.100, speed 108.96 f/s
# 302462: done 304 games, mean reward -20.100, speed 199.98 f/s
# 304387: done 305 games, mean reward -20.110, speed 103.70 f/s
# 307243: done 306 games, mean reward -20.110, speed 108.80 f/s
# 307643: done 307 games, mean reward -20.110, speed 111.95 f/s
# 308101: done 308 games, mean reward -20.090, speed 105.92 f/s
# 308917: done 309 games, mean reward -20.090, speed 110.79 f/s
# 309070: done 310 games, mean reward -20.090, speed 119.63 f/s
# 309726: done 311 games, mean reward -20.080, speed 111.51 f/s
# 310195: done 312 games, mean reward -20.070, speed 103.07 f/s
# 312758: done 313 games, mean reward -20.060, speed 110.27 f/s
# 313484: done 314 games, mean reward -20.060, speed 102.86 f/s
# 314217: done 315 games, mean reward -20.060, speed 117.36 f/s
# 314512: done 316 games, mean reward -20.070, speed 94.31 f/s
# 316066: done 317 games, mean reward -20.070, speed 107.41 f/s
# 317389: done 318 games, mean reward -20.070, speed 108.96 f/s
# 319941: done 319 games, mean reward -20.060, speed 108.60 f/s
# 320284: done 320 games, mean reward -20.080, speed 101.69 f/s
# 320945: done 321 games, mean reward -20.090, speed 111.43 f/s
# 321223: done 322 games, mean reward -20.110, speed 115.57 f/s
# 321521: done 323 games, mean reward -20.120, speed 116.89 f/s
# 321747: done 324 games, mean reward -20.110, speed 102.38 f/s
# 321952: done 325 games, mean reward -20.120, speed 95.84 f/s
# 322329: done 326 games, mean reward -20.120, speed 109.15 f/s
# 323968: done 327 games, mean reward -20.120, speed 110.46 f/s
# 324344: done 328 games, mean reward -20.110, speed 129.74 f/s
# 324380: done 329 games, mean reward -20.130, speed 51.27 f/s
# 326047: done 330 games, mean reward -20.160, speed 106.88 f/s
# 328066: done 331 games, mean reward -20.180, speed 107.38 f/s
# 329942: done 332 games, mean reward -20.160, speed 110.98 f/s
# 330696: done 333 games, mean reward -20.180, speed 108.56 f/s
# 331060: done 334 games, mean reward -20.170, speed 105.11 f/s
# 331423: done 335 games, mean reward -20.160, speed 101.66 f/s
# 332791: done 336 games, mean reward -20.160, speed 109.64 f/s
# 334943: done 337 games, mean reward -20.160, speed 107.15 f/s
# 337616: done 338 games, mean reward -20.150, speed 105.72 f/s
# 337721: done 339 games, mean reward -20.160, speed 88.20 f/s
# 337842: done 340 games, mean reward -20.160, speed 94.20 f/s
# 338260: done 341 games, mean reward -20.150, speed 101.46 f/s
# 339717: done 342 games, mean reward -20.140, speed 100.74 f/s
# 340132: done 343 games, mean reward -20.160, speed 114.74 f/s
# 341836: done 344 games, mean reward -20.170, speed 108.57 f/s
# 343002: done 345 games, mean reward -20.170, speed 109.27 f/s
# 344257: done 346 games, mean reward -20.170, speed 104.84 f/s
# 346309: done 347 games, mean reward -20.190, speed 113.45 f/s
# 347832: done 348 games, mean reward -20.170, speed 114.66 f/s
# 348528: done 349 games, mean reward -20.150, speed 117.65 f/s
# 348612: done 350 games, mean reward -20.150, speed 85.33 f/s
# 348941: done 351 games, mean reward -20.150, speed 99.25 f/s
# 349085: done 352 games, mean reward -20.150, speed 117.98 f/s
# 349297: done 353 games, mean reward -20.140, speed 141.49 f/s
# 349990: done 354 games, mean reward -20.150, speed 110.89 f/s
# 352042: done 355 games, mean reward -20.150, speed 113.54 f/s
# 352260: done 356 games, mean reward -20.150, speed 105.01 f/s
# 352441: done 357 games, mean reward -20.170, speed 133.61 f/s
# 352851: done 358 games, mean reward -20.160, speed 120.01 f/s
# 353858: done 359 games, mean reward -20.160, speed 120.96 f/s
# 355262: done 360 games, mean reward -20.160, speed 112.20 f/s
# 355395: done 361 games, mean reward -20.160, speed 109.91 f/s
# 355483: done 362 games, mean reward -20.150, speed 87.24 f/s
# 356571: done 363 games, mean reward -20.150, speed 117.13 f/s
# 357860: done 364 games, mean reward -20.140, speed 117.51 f/s
# 358987: done 365 games, mean reward -20.140, speed 111.52 f/s
# 360061: done 366 games, mean reward -20.120, speed 118.70 f/s
# 363187: done 367 games, mean reward -20.120, speed 109.20 f/s
# 364245: done 368 games, mean reward -20.160, speed 113.38 f/s
# 365090: done 369 games, mean reward -20.160, speed 107.55 f/s
# 366021: done 370 games, mean reward -20.160, speed 113.35 f/s
# 366444: done 371 games, mean reward -20.150, speed 123.40 f/s
# 367869: done 372 games, mean reward -20.160, speed 109.97 f/s
# 368371: done 373 games, mean reward -20.160, speed 110.61 f/s
# 370377: done 374 games, mean reward -20.150, speed 107.23 f/s
# 370899: done 375 games, mean reward -20.170, speed 112.83 f/s
# 372002: done 376 games, mean reward -20.180, speed 109.12 f/s
# 372292: done 377 games, mean reward -20.180, speed 114.47 f/s
# 373469: done 378 games, mean reward -20.160, speed 112.61 f/s
# 373644: done 379 games, mean reward -20.150, speed 87.73 f/s
# 373788: done 380 games, mean reward -20.160, speed 114.36 f/s
# 374536: done 381 games, mean reward -20.170, speed 107.64 f/s
# 375148: done 382 games, mean reward -20.170, speed 121.37 f/s
# 377850: done 383 games, mean reward -20.160, speed 109.20 f/s
# 378694: done 384 games, mean reward -20.170, speed 106.51 f/s
# 380063: done 385 games, mean reward -20.180, speed 107.28 f/s
# 380424: done 386 games, mean reward -20.170, speed 106.17 f/s
# 381329: done 387 games, mean reward -20.170, speed 110.06 f/s
# 381613: done 388 games, mean reward -20.180, speed 115.70 f/s
# 382402: done 389 games, mean reward -20.160, speed 110.67 f/s
# 382840: done 390 games, mean reward -20.160, speed 113.57 f/s
# 382929: done 391 games, mean reward -20.150, speed 86.64 f/s
# 384011: done 392 games, mean reward -20.150, speed 105.24 f/s
# 384523: done 393 games, mean reward -20.180, speed 105.51 f/s
# 386883: done 394 games, mean reward -20.180, speed 111.54 f/s
# 387457: done 395 games, mean reward -20.180, speed 105.34 f/s
# 390253: done 396 games, mean reward -20.170, speed 112.36 f/s
# 391334: done 397 games, mean reward -20.180, speed 107.68 f/s
# 392032: done 398 games, mean reward -20.180, speed 115.27 f/s
# 392229: done 399 games, mean reward -20.180, speed 84.77 f/s
# 395761: done 400 games, mean reward -20.180, speed 110.46 f/s
# 396100: done 401 games, mean reward -20.210, speed 103.39 f/s
# 398383: done 402 games, mean reward -20.200, speed 108.68 f/s
# 399062: done 403 games, mean reward -20.180, speed 112.78 f/s
# 399237: done 404 games, mean reward -20.190, speed 85.70 f/s
# 400295: done 405 games, mean reward -20.180, speed 108.04 f/s
# 401289: done 406 games, mean reward -20.170, speed 109.03 f/s
# 402211: done 407 games, mean reward -20.170, speed 111.24 f/s
# 404266: done 408 games, mean reward -20.180, speed 109.02 f/s
# 404777: done 409 games, mean reward -20.180, speed 105.62 f/s
# 405280: done 410 games, mean reward -20.180, speed 112.87 f/s
# 405555: done 411 games, mean reward -20.170, speed 114.35 f/s
# 406805: done 412 games, mean reward -20.170, speed 107.86 f/s
# 407135: done 413 games, mean reward -20.160, speed 124.23 f/s
# 407203: done 414 games, mean reward -20.150, speed 74.20 f/s
# 407362: done 415 games, mean reward -20.150, speed 122.31 f/s
# 409043: done 416 games, mean reward -20.140, speed 110.72 f/s
# 409840: done 417 games, mean reward -20.150, speed 109.89 f/s
# 410920: done 418 games, mean reward -20.140, speed 105.59 f/s
# 411066: done 419 games, mean reward -20.140, speed 116.47 f/s
# 411844: done 420 games, mean reward -20.140, speed 110.19 f/s
# 413847: done 421 games, mean reward -20.130, speed 109.56 f/s
# 413874: done 422 games, mean reward -20.130, speed 223.76 f/s
# 416189: done 423 games, mean reward -20.130, speed 109.58 f/s
# 416589: done 424 games, mean reward -20.130, speed 111.02 f/s
# 416981: done 425 games, mean reward -20.130, speed 112.07 f/s
# 417076: done 426 games, mean reward -20.130, speed 89.99 f/s
# 417145: done 427 games, mean reward -20.140, speed 214.86 f/s
# 418931: done 428 games, mean reward -20.150, speed 108.18 f/s
# 419270: done 429 games, mean reward -20.150, speed 102.51 f/s
# 420581: done 430 games, mean reward -20.130, speed 109.71 f/s
# 421009: done 431 games, mean reward -20.130, speed 97.40 f/s
# 421287: done 432 games, mean reward -20.160, speed 113.78 f/s
# 421671: done 433 games, mean reward -20.160, speed 109.07 f/s
# 424026: done 434 games, mean reward -20.160, speed 110.75 f/s
# 424620: done 435 games, mean reward -20.160, speed 104.11 f/s
# 424657: done 436 games, mean reward -20.170, speed 191.75 f/s
# 424956: done 437 games, mean reward -20.170, speed 118.00 f/s
# 425061: done 438 games, mean reward -20.170, speed 94.08 f/s
# 425619: done 439 games, mean reward -20.180, speed 94.81 f/s
# 427865: done 440 games, mean reward -20.180, speed 111.86 f/s
# 428341: done 441 games, mean reward -20.200, speed 105.91 f/s
# 428902: done 442 games, mean reward -20.200, speed 114.20 f/s
# 429356: done 443 games, mean reward -20.210, speed 101.56 f/s
# 430078: done 444 games, mean reward -20.210, speed 117.29 f/s
# 432984: done 445 games, mean reward -20.210, speed 106.49 f/s
# 434908: done 446 games, mean reward -20.210, speed 108.37 f/s
# 435007: done 447 games, mean reward -20.210, speed 91.32 f/s
# 436127: done 448 games, mean reward -20.230, speed 107.83 f/s
# 437898: done 449 games, mean reward -20.240, speed 106.37 f/s
# 439537: done 450 games, mean reward -20.220, speed 108.82 f/s
# 441562: done 451 games, mean reward -20.220, speed 107.98 f/s
# 443584: done 452 games, mean reward -20.220, speed 109.48 f/s
# 443861: done 453 games, mean reward -20.240, speed 108.01 f/s
# 446735: done 454 games, mean reward -20.240, speed 106.43 f/s
# 446742: done 455 games, mean reward -20.250, speed 113.21 f/s
# 447978: done 456 games, mean reward -20.250, speed 110.37 f/s
# 448477: done 457 games, mean reward -20.250, speed 107.22 f/s
# 449867: done 458 games, mean reward -20.250, speed 106.12 f/s
# 453611: done 459 games, mean reward -20.240, speed 110.29 f/s
# 453934: done 460 games, mean reward -20.240, speed 99.18 f/s
# 454687: done 461 games, mean reward -20.260, speed 107.80 f/s
# 454857: done 462 games, mean reward -20.260, speed 124.63 f/s
# 455167: done 463 games, mean reward -20.250, speed 121.23 f/s
# 455312: done 464 games, mean reward -20.260, speed 77.88 f/s
# 455444: done 465 games, mean reward -20.250, speed 112.14 f/s
# 456264: done 466 games, mean reward -20.270, speed 107.78 f/s
# 457260: done 467 games, mean reward -20.250, speed 109.52 f/s
# 458041: done 468 games, mean reward -20.250, speed 105.89 f/s
# 458166: done 469 games, mean reward -20.260, speed 106.29 f/s
# 458308: done 470 games, mean reward -20.250, speed 117.56 f/s
# 458392: done 471 games, mean reward -20.250, speed 83.29 f/s
# 459012: done 472 games, mean reward -20.220, speed 109.91 f/s
# 459738: done 473 games, mean reward -20.210, speed 114.14 f/s
# 460965: done 474 games, mean reward -20.210, speed 106.97 f/s
# 461872: done 475 games, mean reward -20.200, speed 107.41 f/s
# 462411: done 476 games, mean reward -20.200, speed 109.57 f/s
# 462746: done 477 games, mean reward -20.220, speed 94.20 f/s
# 463779: done 478 games, mean reward -20.230, speed 110.34 f/s
# 463837: done 479 games, mean reward -20.260, speed 204.15 f/s
# 465447: done 480 games, mean reward -20.260, speed 108.50 f/s
# 465987: done 481 games, mean reward -20.250, speed 112.71 f/s
# 466000: done 482 games, mean reward -20.260, speed 114.24 f/s
# 466521: done 483 games, mean reward -20.260, speed 108.13 f/s
# 466726: done 484 games, mean reward -20.280, speed 89.73 f/s
# 466769: done 485 games, mean reward -20.280, speed 205.99 f/s
# 467402: done 486 games, mean reward -20.290, speed 102.81 f/s
# 469712: done 487 games, mean reward -20.280, speed 109.26 f/s
# 473088: done 488 games, mean reward -20.270, speed 105.69 f/s
# 476499: done 489 games, mean reward -20.280, speed 110.20 f/s
# 476968: done 490 games, mean reward -20.250, speed 100.75 f/s
# 477503: done 491 games, mean reward -20.270, speed 103.39 f/s
# 479841: done 492 games, mean reward -20.280, speed 110.71 f/s
# 480146: done 493 games, mean reward -20.280, speed 93.92 f/s
# 480481: done 494 games, mean reward -20.290, speed 124.21 f/s
# 480635: done 495 games, mean reward -20.280, speed 116.23 f/s
# 481067: done 496 games, mean reward -20.270, speed 93.08 f/s
# 481114: done 497 games, mean reward -20.270, speed 212.73 f/s
# 482032: done 498 games, mean reward -20.260, speed 106.47 f/s
# 484656: done 499 games, mean reward -20.240, speed 103.68 f/s
# 485979: done 500 games, mean reward -20.240, speed 109.96 f/s
# 488383: done 501 games, mean reward -20.240, speed 110.78 f/s
# 488633: done 502 games, mean reward -20.260, speed 109.12 f/s
# 489125: done 503 games, mean reward -20.290, speed 107.19 f/s
# 489887: done 504 games, mean reward -20.280, speed 104.14 f/s
# 490716: done 505 games, mean reward -20.280, speed 111.26 f/s
# 491714: done 506 games, mean reward -20.280, speed 105.51 f/s
# 493433: done 507 games, mean reward -20.280, speed 103.46 f/s
# 493488: done 508 games, mean reward -20.290, speed 47.94 f/s
# 494013: done 509 games, mean reward -20.290, speed 104.98 f/s
# 494330: done 510 games, mean reward -20.280, speed 119.48 f/s
# 497197: done 511 games, mean reward -20.310, speed 106.77 f/s
# 497836: done 512 games, mean reward -20.320, speed 108.54 f/s
# 500172: done 513 games, mean reward -20.340, speed 109.96 f/s
# 500261: done 514 games, mean reward -20.360, speed 93.41 f/s
# 502988: done 515 games, mean reward -20.370, speed 108.26 f/s
# 504061: done 516 games, mean reward -20.370, speed 111.05 f/s
# 504171: done 517 games, mean reward -20.360, speed 97.53 f/s
# 504240: done 518 games, mean reward -20.360, speed 75.09 f/s
# 504636: done 519 games, mean reward -20.370, speed 111.59 f/s
# 504769: done 520 games, mean reward -20.370, speed 112.17 f/s
# 505119: done 521 games, mean reward -20.380, speed 104.39 f/s
# 506068: done 522 games, mean reward -20.380, speed 110.26 f/s
# 507639: done 523 games, mean reward -20.380, speed 110.19 f/s
# 507756: done 524 games, mean reward -20.390, speed 101.94 f/s
# 508576: done 525 games, mean reward -20.390, speed 98.80 f/s
# 508891: done 526 games, mean reward -20.390, speed 119.60 f/s
# 509096: done 527 games, mean reward -20.380, speed 96.11 f/s
# 510313: done 528 games, mean reward -20.380, speed 103.13 f/s
# 510719: done 529 games, mean reward -20.370, speed 112.72 f/s
# 511235: done 530 games, mean reward -20.390, speed 96.30 f/s
# 511606: done 531 games, mean reward -20.380, speed 132.67 f/s
# 512988: done 532 games, mean reward -20.380, speed 105.34 f/s
# 513371: done 533 games, mean reward -20.380, speed 103.04 f/s
# 515027: done 534 games, mean reward -20.350, speed 109.49 f/s
# 517935: done 535 games, mean reward -20.360, speed 104.59 f/s
# 518178: done 536 games, mean reward -20.350, speed 105.37 f/s
# 518715: done 537 games, mean reward -20.340, speed 108.07 f/s
# 519202: done 538 games, mean reward -20.340, speed 102.40 f/s
# 522923: done 539 games, mean reward -20.340, speed 110.53 f/s
# 523331: done 540 games, mean reward -20.320, speed 108.31 f/s
# 524212: done 541 games, mean reward -20.320, speed 107.91 f/s
# 525202: done 542 games, mean reward -20.320, speed 105.39 f/s
# 525982: done 543 games, mean reward -20.320, speed 107.79 f/s
# 526606: done 544 games, mean reward -20.310, speed 107.29 f/s
# 527148: done 545 games, mean reward -20.320, speed 113.89 f/s
# 527553: done 546 games, mean reward -20.320, speed 110.12 f/s
# 528334: done 547 games, mean reward -20.310, speed 106.14 f/s
# 528351: done 548 games, mean reward -20.310, speed 177.49 f/s
# 530262: done 549 games, mean reward -20.310, speed 108.02 f/s
# 531581: done 550 games, mean reward -20.320, speed 107.49 f/s
# 533933: done 551 games, mean reward -20.330, speed 108.08 f/s
# 535556: done 552 games, mean reward -20.330, speed 104.46 f/s
# 537232: done 553 games, mean reward -20.320, speed 110.99 f/s
# 538380: done 554 games, mean reward -20.310, speed 107.42 f/s
# 538979: done 555 games, mean reward -20.310, speed 117.76 f/s
# 539143: done 556 games, mean reward -20.300, speed 85.23 f/s
# 539335: done 557 games, mean reward -20.290, speed 135.52 f/s
# 540528: done 558 games, mean reward -20.290, speed 112.99 f/s
# 541017: done 559 games, mean reward -20.290, speed 106.42 f/s
# 541096: done 560 games, mean reward -20.270, speed 82.75 f/s
# 542733: done 561 games, mean reward -20.250, speed 108.15 f/s
# 544871: done 562 games, mean reward -20.250, speed 111.71 f/s
# 544976: done 563 games, mean reward -20.250, speed 99.08 f/s
# 545731: done 564 games, mean reward -20.250, speed 106.10 f/s
# 547061: done 565 games, mean reward -20.260, speed 113.56 f/s
# 547067: done 566 games, mean reward -20.260, speed 105.61 f/s
# 548615: done 567 games, mean reward -20.280, speed 101.15 f/s
# 548898: done 568 games, mean reward -20.280, speed 109.31 f/s
# 548990: done 569 games, mean reward -20.270, speed 202.17 f/s
# 550315: done 570 games, mean reward -20.280, speed 106.49 f/s
# 550615: done 571 games, mean reward -20.280, speed 117.61 f/s
# 550841: done 572 games, mean reward -20.300, speed 99.83 f/s
# 552248: done 573 games, mean reward -20.310, speed 103.09 f/s
# 553512: done 574 games, mean reward -20.320, speed 106.65 f/s
# 554098: done 575 games, mean reward -20.310, speed 117.89 f/s
# 554278: done 576 games, mean reward -20.310, speed 88.40 f/s
# 554592: done 577 games, mean reward -20.300, speed 119.46 f/s
# 555963: done 578 games, mean reward -20.300, speed 108.06 f/s
# 556984: done 579 games, mean reward -20.290, speed 108.64 f/s
# 557236: done 580 games, mean reward -20.280, speed 109.63 f/s
# 557287: done 581 games, mean reward -20.280, speed 233.49 f/s
# 561974: done 582 games, mean reward -20.280, speed 109.18 f/s
# 563433: done 583 games, mean reward -20.290, speed 110.98 f/s
# 564612: done 584 games, mean reward -20.280, speed 104.48 f/s
# 565001: done 585 games, mean reward -20.260, speed 110.08 f/s
# 567100: done 586 games, mean reward -20.270, speed 111.85 f/s
# 568080: done 587 games, mean reward -20.270, speed 106.51 f/s
# 568472: done 588 games, mean reward -20.280, speed 110.42 f/s
# 568729: done 589 games, mean reward -20.280, speed 109.51 f/s
# 569111: done 590 games, mean reward -20.300, speed 103.90 f/s
# 571044: done 591 games, mean reward -20.300, speed 107.77 f/s
# 571126: done 592 games, mean reward -20.300, speed 210.41 f/s
# 572250: done 593 games, mean reward -20.290, speed 109.89 f/s
# 574957: done 594 games, mean reward -20.280, speed 109.81 f/s
# 575344: done 595 games, mean reward -20.280, speed 113.61 f/s
# 576406: done 596 games, mean reward -20.280, speed 104.46 f/s
# 576929: done 597 games, mean reward -20.270, speed 110.67 f/s
# 577687: done 598 games, mean reward -20.250, speed 108.62 f/s
# 578086: done 599 games, mean reward -20.250, speed 106.55 f/s
# 580024: done 600 games, mean reward -20.270, speed 113.23 f/s
# 580178: done 601 games, mean reward -20.270, speed 113.85 f/s
# 580281: done 602 games, mean reward -20.270, speed 85.80 f/s
# 581961: done 603 games, mean reward -20.270, speed 106.15 f/s
# 583266: done 604 games, mean reward -20.260, speed 110.82 f/s
# 584166: done 605 games, mean reward -20.270, speed 111.81 f/s
# 584773: done 606 games, mean reward -20.280, speed 105.99 f/s
# 585598: done 607 games, mean reward -20.270, speed 113.78 f/s
# 586091: done 608 games, mean reward -20.260, speed 106.61 f/s
# 586731: done 609 games, mean reward -20.260, speed 109.53 f/s
# 588007: done 610 games, mean reward -20.270, speed 109.12 f/s
# 588291: done 611 games, mean reward -20.270, speed 90.53 f/s
# 590371: done 612 games, mean reward -20.270, speed 110.26 f/s
# 592008: done 613 games, mean reward -20.270, speed 105.98 f/s
# 592700: done 614 games, mean reward -20.250, speed 113.77 f/s
# 592787: done 615 games, mean reward -20.240, speed 86.74 f/s
# 592940: done 616 games, mean reward -20.250, speed 118.17 f/s
# 593168: done 617 games, mean reward -20.260, speed 103.64 f/s
# 593397: done 618 games, mean reward -20.240, speed 142.23 f/s
# 594573: done 619 games, mean reward -20.220, speed 102.73 f/s
# 594840: done 620 games, mean reward -20.200, speed 111.45 f/s
# 595809: done 621 games, mean reward -20.200, speed 113.11 f/s
# 598018: done 622 games, mean reward -20.190, speed 105.36 f/s
# 598779: done 623 games, mean reward -20.180, speed 119.41 f/s
# 600272: done 624 games, mean reward -20.180, speed 106.72 f/s
# 601200: done 625 games, mean reward -20.170, speed 110.58 f/s
# 602831: done 626 games, mean reward -20.170, speed 107.04 f/s
# 602849: done 627 games, mean reward -20.170, speed 164.08 f/s
# 605070: done 628 games, mean reward -20.170, speed 104.86 f/s
# 606363: done 629 games, mean reward -20.180, speed 109.80 f/s
# 607474: done 630 games, mean reward -20.160, speed 113.97 f/s
# 608746: done 631 games, mean reward -20.160, speed 107.60 f/s
# 609210: done 632 games, mean reward -20.150, speed 103.27 f/s
# 610014: done 633 games, mean reward -20.150, speed 111.73 f/s
# 610400: done 634 games, mean reward -20.190, speed 110.54 f/s
# 610491: done 635 games, mean reward -20.190, speed 84.41 f/s
# 613293: done 636 games, mean reward -20.200, speed 107.02 f/s
# 613375: done 637 games, mean reward -20.170, speed 225.90 f/s
# 615238: done 638 games, mean reward -20.180, speed 104.72 f/s
# 615541: done 639 games, mean reward -20.170, speed 119.34 f/s
# 617089: done 640 games, mean reward -20.190, speed 104.55 f/s
# 617723: done 641 games, mean reward -20.190, speed 115.13 f/s
# 618456: done 642 games, mean reward -20.200, speed 107.00 f/s
# 618833: done 643 games, mean reward -20.180, speed 113.51 f/s
# 619220: done 644 games, mean reward -20.190, speed 109.09 f/s
# 619982: done 645 games, mean reward -20.190, speed 109.64 f/s
# 620573: done 646 games, mean reward -20.200, speed 100.44 f/s
# 622418: done 647 games, mean reward -20.190, speed 108.92 f/s
# 623841: done 648 games, mean reward -20.160, speed 108.64 f/s
# 625362: done 649 games, mean reward -20.170, speed 105.89 f/s
# 625817: done 650 games, mean reward -20.180, speed 98.70 f/s
# 626662: done 651 games, mean reward -20.180, speed 112.63 f/s
# 626714: done 652 games, mean reward -20.180, speed 60.85 f/s
# 627092: done 653 games, mean reward -20.160, speed 103.30 f/s
# 628864: done 654 games, mean reward -20.150, speed 107.37 f/s
# 629030: done 655 games, mean reward -20.140, speed 127.26 f/s
# 630675: done 656 games, mean reward -20.150, speed 108.57 f/s
# 634679: done 657 games, mean reward -20.160, speed 109.21 f/s
# 634685: done 658 games, mean reward -20.170, speed 96.96 f/s
# 634892: done 659 games, mean reward -20.170, speed 98.36 f/s
# 635664: done 660 games, mean reward -20.190, speed 109.80 f/s
# 635677: done 661 games, mean reward -20.200, speed 125.33 f/s
# 635892: done 662 games, mean reward -20.210, speed 141.99 f/s
# 637054: done 663 games, mean reward -20.230, speed 110.38 f/s
# 637069: done 664 games, mean reward -20.230, speed 20.57 f/s
# 637274: done 665 games, mean reward -20.230, speed 133.11 f/s
# 638763: done 666 games, mean reward -20.210, speed 106.76 f/s
# 639505: done 667 games, mean reward -20.210, speed 104.17 f/s
# 639954: done 668 games, mean reward -20.210, speed 119.47 f/s
# 640265: done 669 games, mean reward -20.220, speed 96.22 f/s
# 640466: done 670 games, mean reward -20.210, speed 136.73 f/s
# 640727: done 671 games, mean reward -20.210, speed 102.74 f/s
# 642651: done 672 games, mean reward -20.210, speed 109.29 f/s
# 643443: done 673 games, mean reward -20.210, speed 111.62 f/s
# 644022: done 674 games, mean reward -20.210, speed 102.83 f/s
# 647769: done 675 games, mean reward -20.230, speed 108.34 f/s
# 648151: done 676 games, mean reward -20.230, speed 107.48 f/s
# 649655: done 677 games, mean reward -20.240, speed 108.16 f/s
# 650470: done 678 games, mean reward -20.250, speed 105.88 f/s
# 652094: done 679 games, mean reward -20.260, speed 107.83 f/s
# 652235: done 680 games, mean reward -20.270, speed 115.47 f/s
# 652949: done 681 games, mean reward -20.260, speed 104.52 f/s
# 654566: done 682 games, mean reward -20.260, speed 112.51 f/s
# 657418: done 683 games, mean reward -20.250, speed 107.97 f/s
# 659239: done 684 games, mean reward -20.250, speed 111.35 f/s
# 661151: done 685 games, mean reward -20.270, speed 111.00 f/s
# 661667: done 686 games, mean reward -20.260, speed 122.73 f/s
# 661740: done 687 games, mean reward -20.270, speed 224.50 f/s
# 663290: done 688 games, mean reward -20.260, speed 109.09 f/s
# 663726: done 689 games, mean reward -20.260, speed 99.05 f/s
# 664517: done 690 games, mean reward -20.270, speed 110.81 f/s
# 664931: done 691 games, mean reward -20.260, speed 114.80 f/s
# 665724: done 692 games, mean reward -20.260, speed 111.02 f/s
# 667560: done 693 games, mean reward -20.260, speed 103.28 f/s
# 667658: done 694 games, mean reward -20.270, speed 95.25 f/s
# 667725: done 695 games, mean reward -20.260, speed 227.88 f/s
# 669117: done 696 games, mean reward -20.280, speed 108.70 f/s
# 669390: done 697 games, mean reward -20.290, speed 115.57 f/s
# 670122: done 698 games, mean reward -20.320, speed 106.17 f/s
# 672863: done 699 games, mean reward -20.320, speed 110.32 f/s
# 672960: done 700 games, mean reward -20.290, speed 90.02 f/s
# 673764: done 701 games, mean reward -20.280, speed 112.98 f/s
# 673816: done 702 games, mean reward -20.280, speed 56.92 f/s
# 674702: done 703 games, mean reward -20.260, speed 109.26 f/s
# 675637: done 704 games, mean reward -20.280, speed 114.00 f/s
# 676528: done 705 games, mean reward -20.280, speed 104.50 f/s
# 676647: done 706 games, mean reward -20.260, speed 102.88 f/s
# 677076: done 707 games, mean reward -20.260, speed 115.98 f/s
# 678659: done 708 games, mean reward -20.260, speed 105.10 f/s
# 678701: done 709 games, mean reward -20.260, speed 222.07 f/s
# 679582: done 710 games, mean reward -20.250, speed 111.20 f/s
# 682708: done 711 games, mean reward -20.250, speed 109.05 f/s
# 683460: done 712 games, mean reward -20.250, speed 107.77 f/s
# 683949: done 713 games, mean reward -20.250, speed 109.70 f/s
# 684443: done 714 games, mean reward -20.260, speed 107.99 f/s
# 684498: done 715 games, mean reward -20.250, speed 196.43 f/s
# 684527: done 716 games, mean reward -20.240, speed 213.80 f/s
# 685387: done 717 games, mean reward -20.230, speed 104.95 f/s
# 686224: done 718 games, mean reward -20.260, speed 103.16 f/s
# 686560: done 719 games, mean reward -20.270, speed 123.56 f/s
# 687366: done 720 games, mean reward -20.280, speed 103.82 f/s
# 688679: done 721 games, mean reward -20.260, speed 107.40 f/s
# 689431: done 722 games, mean reward -20.270, speed 108.37 f/s
# 689471: done 723 games, mean reward -20.270, speed 224.42 f/s
# 692716: done 724 games, mean reward -20.270, speed 112.05 f/s
# 692855: done 725 games, mean reward -20.280, speed 117.38 f/s
# 696610: done 726 games, mean reward -20.280, speed 109.56 f/s
# 697280: done 727 games, mean reward -20.280, speed 112.48 f/s
# 697346: done 728 games, mean reward -20.290, speed 67.52 f/s
# 697477: done 729 games, mean reward -20.280, speed 111.43 f/s
# 697892: done 730 games, mean reward -20.270, speed 114.62 f/s
# 698349: done 731 games, mean reward -20.280, speed 124.88 f/s
# 699157: done 732 games, mean reward -20.280, speed 101.00 f/s
# 703049: done 733 games, mean reward -20.270, speed 108.87 f/s
# 703586: done 734 games, mean reward -20.270, speed 110.83 f/s
# 704220: done 735 games, mean reward -20.270, speed 103.87 f/s
# 704636: done 736 games, mean reward -20.260, speed 110.72 f/s
# 706292: done 737 games, mean reward -20.300, speed 103.97 f/s
# 709269: done 738 games, mean reward -20.300, speed 105.61 f/s
# 710626: done 739 games, mean reward -20.310, speed 110.98 f/s
# 710901: done 740 games, mean reward -20.320, speed 113.51 f/s
# 711408: done 741 games, mean reward -20.320, speed 110.14 f/s
# 711768: done 742 games, mean reward -20.320, speed 105.55 f/s
# 712433: done 743 games, mean reward -20.320, speed 110.97 f/s
# 713965: done 744 games, mean reward -20.310, speed 107.56 f/s
# 714927: done 745 games, mean reward -20.310, speed 104.05 f/s
# 715223: done 746 games, mean reward -20.300, speed 117.83 f/s
# 715571: done 747 games, mean reward -20.320, speed 102.01 f/s
# 715713: done 748 games, mean reward -20.340, speed 119.07 f/s
# 716592: done 749 games, mean reward -20.340, speed 105.73 f/s
# 717401: done 750 games, mean reward -20.340, speed 110.49 f/s
# 718561: done 751 games, mean reward -20.330, speed 108.90 f/s
# 720225: done 752 games, mean reward -20.340, speed 109.73 f/s
# 720467: done 753 games, mean reward -20.360, speed 106.54 f/s
# 722873: done 754 games, mean reward -20.370, speed 109.39 f/s
# 723484: done 755 games, mean reward -20.380, speed 106.47 f/s
# 724339: done 756 games, mean reward -20.380, speed 115.71 f/s
# 725445: done 757 games, mean reward -20.360, speed 108.61 f/s
# 725510: done 758 games, mean reward -20.340, speed 69.11 f/s
# 725966: done 759 games, mean reward -20.340, speed 119.96 f/s
# 726699: done 760 games, mean reward -20.320, speed 112.38 f/s
# 727508: done 761 games, mean reward -20.320, speed 112.09 f/s
# 729358: done 762 games, mean reward -20.310, speed 107.08 f/s
# 730443: done 763 games, mean reward -20.300, speed 112.47 f/s
# 730900: done 764 games, mean reward -20.300, speed 102.92 f/s
# 731209: done 765 games, mean reward -20.290, speed 120.82 f/s
# 732036: done 766 games, mean reward -20.310, speed 99.96 f/s
# 732675: done 767 games, mean reward -20.300, speed 93.27 f/s
# 732720: done 768 games, mean reward -20.290, speed 247.22 f/s
# 732844: done 769 games, mean reward -20.290, speed 103.78 f/s
# ...
# 6008585: done 3856 games, mean reward 12.220, speed 94.12 f/s
# 6009361: done 3857 games, mean reward 12.230, speed 105.26 f/s
# 6012200: done 3858 games, mean reward 12.220, speed 117.41 f/s
# 6016128: done 3859 games, mean reward 12.270, speed 114.31 f/s
# 6018518: done 3860 games, mean reward 12.220, speed 121.05 f/s
# 6021064: done 3861 games, mean reward 12.220, speed 117.42 f/s
# 6021088: done 3862 games, mean reward 12.250, speed 170.71 f/s
# 6024468: done 3863 games, mean reward 12.200, speed 116.02 f/s
# 6027487: done 3864 games, mean reward 12.170, speed 119.74 f/s
# 6028796: done 3865 games, mean reward 12.190, speed 119.20 f/s
# 6029745: done 3866 games, mean reward 12.330, speed 110.44 f/s
# 6039933: done 3867 games, mean reward 12.520, speed 116.37 f/s
# 6043870: done 3868 games, mean reward 12.520, speed 111.12 f/s
# 6044079: done 3869 games, mean reward 12.500, speed 94.90 f/s
# 6055432: done 3870 games, mean reward 12.480, speed 114.15 f/s
# 6056727: done 3871 games, mean reward 12.500, speed 113.07 f/s
# 6057307: done 3872 games, mean reward 12.740, speed 121.67 f/s
# 6059387: done 3873 games, mean reward 12.730, speed 115.15 f/s
# 6060433: done 3874 games, mean reward 12.730, speed 110.42 f/s
# 6061108: done 3875 games, mean reward 12.800, speed 117.20 f/s
# 6061714: done 3876 games, mean reward 12.840, speed 112.56 f/s
# 6066571: done 3877 games, mean reward 12.800, speed 115.16 f/s
# 6067185: done 3878 games, mean reward 12.780, speed 125.04 f/s
# 6068354: done 3879 games, mean reward 12.700, speed 106.78 f/s
# 6071578: done 3880 games, mean reward 13.010, speed 117.15 f/s
# 6074149: done 3881 games, mean reward 12.970, speed 116.95 f/s
# 6076610: done 3882 games, mean reward 12.970, speed 119.19 f/s
# 6076650: done 3883 games, mean reward 12.810, speed 212.89 f/s
# 6076824: done 3884 games, mean reward 12.740, speed 94.12 f/s
# 6078562: done 3885 games, mean reward 12.770, speed 112.79 f/s
# 6086806: done 3886 games, mean reward 12.750, speed 117.44 f/s
# 6087088: done 3887 games, mean reward 12.660, speed 120.38 f/s
# 6087434: done 3888 games, mean reward 12.700, speed 111.49 f/s
# 6089300: done 3889 games, mean reward 12.710, speed 117.79 f/s
# 6090057: done 3890 games, mean reward 12.700, speed 114.05 f/s
# 6090415: done 3891 games, mean reward 12.830, speed 109.33 f/s
# 6092032: done 3892 games, mean reward 12.720, speed 115.12 f/s
# 6095929: done 3893 games, mean reward 12.670, speed 118.72 f/s
# 6097228: done 3894 games, mean reward 12.670, speed 116.51 f/s
# 6097342: done 3895 games, mean reward 12.680, speed 105.63 f/s
# 6099533: done 3896 games, mean reward 12.640, speed 116.59 f/s
# 6099746: done 3897 games, mean reward 12.770, speed 106.50 f/s
# 6099816: done 3898 games, mean reward 12.720, speed 248.98 f/s
# 6100046: done 3899 games, mean reward 12.720, speed 109.70 f/s
# 6101354: done 3900 games, mean reward 12.700, speed 118.86 f/s
# 6102743: done 3901 games, mean reward 12.780, speed 115.10 f/s
# 6106007: done 3902 games, mean reward 12.810, speed 116.10 f/s
# 6114376: done 3903 games, mean reward 12.820, speed 115.71 f/s
# 6114945: done 3904 games, mean reward 12.760, speed 111.59 f/s
# 6116684: done 3905 games, mean reward 12.910, speed 117.56 f/s
# 6117749: done 3906 games, mean reward 12.800, speed 119.45 f/s
# 6118276: done 3907 games, mean reward 12.870, speed 106.82 f/s
# 6121311: done 3908 games, mean reward 12.870, speed 116.60 f/s
# 6128235: done 3909 games, mean reward 12.890, speed 115.40 f/s
# 6129441: done 3910 games, mean reward 12.940, speed 113.55 f/s
# 6130511: done 3911 games, mean reward 13.000, speed 120.90 f/s
# 6131584: done 3912 games, mean reward 13.140, speed 109.31 f/s
# 6136875: done 3913 games, mean reward 13.320, speed 115.44 f/s
# 6140072: done 3914 games, mean reward 13.260, speed 118.60 f/s
# 6142986: done 3915 games, mean reward 13.160, speed 115.11 f/s
# 6143100: done 3916 games, mean reward 13.000, speed 260.53 f/s
# 6150233: done 3917 games, mean reward 13.110, speed 114.46 f/s
# 6150309: done 3918 games, mean reward 13.110, speed 80.40 f/s
# 6151404: done 3919 games, mean reward 13.210, speed 112.90 f/s
# 6152745: done 3920 games, mean reward 13.260, speed 106.64 f/s
# 6153054: done 3921 games, mean reward 13.370, speed 125.73 f/s
# 6156070: done 3922 games, mean reward 13.530, speed 113.21 f/s
# 6157180: done 3923 games, mean reward 13.690, speed 122.89 f/s
# 6159913: done 3924 games, mean reward 13.700, speed 113.68 f/s
# 6163385: done 3925 games, mean reward 13.920, speed 119.20 f/s
# 6167706: done 3926 games, mean reward 13.930, speed 113.63 f/s
# 6170621: done 3927 games, mean reward 14.010, speed 118.23 f/s
# 6172780: done 3928 games, mean reward 13.970, speed 113.49 f/s
# 6175103: done 3929 games, mean reward 14.110, speed 116.15 f/s
# 6178857: done 3930 games, mean reward 14.060, speed 113.79 f/s
# 6180242: done 3931 games, mean reward 14.120, speed 105.53 f/s
# 6181049: done 3932 games, mean reward 14.190, speed 118.10 f/s
# 6181889: done 3933 games, mean reward 14.240, speed 111.50 f/s
# 6181933: done 3934 games, mean reward 14.240, speed 312.96 f/s
# 6186194: done 3935 games, mean reward 14.200, speed 114.83 f/s
# 6186835: done 3936 games, mean reward 14.210, speed 116.63 f/s
# 6187502: done 3937 games, mean reward 14.360, speed 121.32 f/s
# 6190266: done 3938 games, mean reward 14.440, speed 114.89 f/s
# 6191109: done 3939 games, mean reward 14.580, speed 107.36 f/s
# 6191682: done 3940 games, mean reward 14.740, speed 120.69 f/s
# 6191896: done 3941 games, mean reward 14.860, speed 103.08 f/s
# 6196078: done 3942 games, mean reward 14.850, speed 116.81 f/s
# 6199644: done 3943 games, mean reward 14.910, speed 115.09 f/s
# 6201523: done 3944 games, mean reward 15.020, speed 113.23 f/s
# 6204249: done 3945 games, mean reward 14.990, speed 115.50 f/s
# 6204290: done 3946 games, mean reward 14.940, speed 49.19 f/s
# 6207660: done 3947 games, mean reward 14.950, speed 117.10 f/s
# 6208817: done 3948 games, mean reward 15.030, speed 116.70 f/s
# 6212717: done 3949 games, mean reward 15.110, speed 115.79 f/s
# 6213253: done 3950 games, mean reward 15.100, speed 104.14 f/s
# 6215827: done 3951 games, mean reward 15.200, speed 114.58 f/s
# 6216483: done 3952 games, mean reward 15.280, speed 110.42 f/s
# 6217017: done 3953 games, mean reward 15.170, speed 116.04 f/s
# 6218138: done 3954 games, mean reward 15.160, speed 113.47 f/s
# 6223227: done 3955 games, mean reward 15.210, speed 117.64 f/s
# 6225049: done 3956 games, mean reward 15.400, speed 113.78 f/s
# 6231303: done 3957 games, mean reward 15.380, speed 115.80 f/s
# 6232029: done 3958 games, mean reward 15.400, speed 125.18 f/s
# 6234800: done 3959 games, mean reward 15.470, speed 114.90 f/s
# 6235718: done 3960 games, mean reward 15.530, speed 115.60 f/s
# 6237894: done 3961 games, mean reward 15.540, speed 112.89 f/s
# 6238086: done 3962 games, mean reward 15.640, speed 92.60 f/s
# 6238848: done 3963 games, mean reward 15.690, speed 113.79 f/s
# 6241202: done 3964 games, mean reward 15.840, speed 117.20 f/s
# 6244512: done 3965 games, mean reward 15.730, speed 115.86 f/s
# 6244692: done 3966 games, mean reward 15.710, speed 131.87 f/s
# 6253247: done 3967 games, mean reward 15.780, speed 118.07 f/s
# 6256720: done 3968 games, mean reward 15.920, speed 118.69 f/s
# 6258163: done 3969 games, mean reward 16.050, speed 119.77 f/s
# 6259282: done 3970 games, mean reward 16.010, speed 112.75 f/s
# 6259810: done 3971 games, mean reward 15.980, speed 114.05 f/s
# 6260409: done 3972 games, mean reward 15.830, speed 112.71 f/s
# 6263234: done 3973 games, mean reward 15.860, speed 119.44 f/s
# 6268134: done 3974 games, mean reward 15.810, speed 118.64 f/s
# 6270642: done 3975 games, mean reward 15.810, speed 116.39 f/s
# 6272274: done 3976 games, mean reward 15.750, speed 122.86 f/s
# 6274677: done 3977 games, mean reward 15.720, speed 129.26 f/s
# 6278148: done 3978 games, mean reward 15.730, speed 121.47 f/s
# 6278761: done 3979 games, mean reward 15.740, speed 130.71 f/s
# 6279737: done 3980 games, mean reward 15.700, speed 121.28 f/s
# 6281036: done 3981 games, mean reward 15.790, speed 124.25 f/s
# 6282306: done 3982 games, mean reward 16.000, speed 123.10 f/s
# 6283078: done 3983 games, mean reward 16.160, speed 124.90 f/s
# 6283290: done 3984 games, mean reward 16.200, speed 103.97 f/s
# 6284614: done 3985 games, mean reward 16.200, speed 127.39 f/s
# 6286837: done 3986 games, mean reward 16.210, speed 123.11 f/s
# 6287277: done 3987 games, mean reward 16.300, speed 107.90 f/s
# 6288966: done 3988 games, mean reward 16.260, speed 123.54 f/s
# 6289854: done 3989 games, mean reward 16.240, speed 123.48 f/s
# 6296117: done 3990 games, mean reward 16.250, speed 123.21 f/s
# 6298600: done 3991 games, mean reward 16.210, speed 125.42 f/s
# 6301406: done 3992 games, mean reward 16.340, speed 125.41 f/s
# 6302159: done 3993 games, mean reward 16.290, speed 122.36 f/s
# 6302407: done 3994 games, mean reward 16.280, speed 114.66 f/s
# 6302829: done 3995 games, mean reward 16.410, speed 127.36 f/s
# 6307150: done 3996 games, mean reward 16.410, speed 123.33 f/s
# 6310433: done 3997 games, mean reward 16.430, speed 121.92 f/s
# 6310920: done 3998 games, mean reward 16.470, speed 118.11 f/s
# 6313525: done 3999 games, mean reward 16.530, speed 124.52 f/s
# 6314496: done 4000 games, mean reward 16.550, speed 118.11 f/s
# 6317094: done 4001 games, mean reward 16.540, speed 124.60 f/s
# 6318144: done 4002 games, mean reward 16.460, speed 124.15 f/s
# 6318974: done 4003 games, mean reward 16.470, speed 127.56 f/s
# 6323245: done 4004 games, mean reward 16.550, speed 121.56 f/s
# 6323978: done 4005 games, mean reward 16.540, speed 117.11 f/s
# 6324187: done 4006 games, mean reward 16.590, speed 147.20 f/s
# 6326490: done 4007 games, mean reward 16.590, speed 122.77 f/s
# 6331826: done 4008 games, mean reward 16.560, speed 120.66 f/s
# 6332817: done 4009 games, mean reward 16.620, speed 121.95 f/s
# 6333507: done 4010 games, mean reward 16.660, speed 124.86 f/s
# 6334286: done 4011 games, mean reward 16.720, speed 119.05 f/s
# 6338042: done 4012 games, mean reward 16.760, speed 123.51 f/s
# 6343052: done 4013 games, mean reward 16.750, speed 121.26 f/s
# 6345399: done 4014 games, mean reward 16.770, speed 126.40 f/s
# 6346109: done 4015 games, mean reward 16.860, speed 134.48 f/s
# 6347553: done 4016 games, mean reward 17.020, speed 118.26 f/s
# 6348020: done 4017 games, mean reward 16.960, speed 141.80 f/s
# 6351680: done 4018 games, mean reward 16.950, speed 122.66 f/s
# 6354868: done 4019 games, mean reward 16.800, speed 121.81 f/s
# 6356489: done 4020 games, mean reward 16.660, speed 119.21 f/s
# 6357959: done 4021 games, mean reward 16.640, speed 124.45 f/s
# 6360970: done 4022 games, mean reward 16.630, speed 121.92 f/s
# 6363043: done 4023 games, mean reward 16.640, speed 123.13 f/s
# 6363207: done 4024 games, mean reward 16.650, speed 145.55 f/s
# 6364432: done 4025 games, mean reward 16.720, speed 122.41 f/s
# 6365931: done 4026 games, mean reward 16.820, speed 129.39 f/s
# 6366477: done 4027 games, mean reward 16.850, speed 110.03 f/s
# 6368034: done 4028 games, mean reward 16.920, speed 121.41 f/s
# 6372039: done 4029 games, mean reward 16.870, speed 121.44 f/s
# 6372675: done 4030 games, mean reward 16.910, speed 124.22 f/s
# 6373492: done 4031 games, mean reward 16.870, speed 124.07 f/s
# 6374406: done 4032 games, mean reward 16.860, speed 110.87 f/s
# 6375412: done 4033 games, mean reward 16.920, speed 129.45 f/s
# 6377274: done 4034 games, mean reward 16.900, speed 121.37 f/s
# 6377353: done 4035 games, mean reward 16.950, speed 90.85 f/s
# 6378738: done 4036 games, mean reward 16.870, speed 128.51 f/s
# 6380415: done 4037 games, mean reward 16.860, speed 121.83 f/s
# 6390355: done 4038 games, mean reward 16.840, speed 122.96 f/s
# 6391202: done 4039 games, mean reward 16.860, speed 120.82 f/s
# 6391441: done 4040 games, mean reward 16.820, speed 123.18 f/s
# 6392695: done 4041 games, mean reward 16.830, speed 130.71 f/s
# 6393126: done 4042 games, mean reward 16.850, speed 102.94 f/s
# 6393620: done 4043 games, mean reward 16.840, speed 120.27 f/s
# 6395830: done 4044 games, mean reward 16.850, speed 122.22 f/s
# 6397259: done 4045 games, mean reward 16.840, speed 120.18 f/s
# 6399162: done 4046 games, mean reward 16.880, speed 122.30 f/s
# 6407868: done 4047 games, mean reward 16.960, speed 122.09 f/s
# 6411731: done 4048 games, mean reward 16.980, speed 124.52 f/s
# 6412691: done 4049 games, mean reward 17.050, speed 119.85 f/s
# 6414841: done 4050 games, mean reward 17.060, speed 125.84 f/s
# 6415473: done 4051 games, mean reward 17.040, speed 122.45 f/s
# 6415898: done 4052 games, mean reward 16.990, speed 114.74 f/s
# 6416072: done 4053 games, mean reward 17.100, speed 142.35 f/s
# 6416797: done 4054 games, mean reward 17.170, speed 120.98 f/s
# 6416930: done 4055 games, mean reward 17.160, speed 110.81 f/s
# 6419532: done 4056 games, mean reward 17.180, speed 124.47 f/s
# 6422737: done 4057 games, mean reward 17.300, speed 124.04 f/s
# 6424647: done 4058 games, mean reward 17.310, speed 124.65 f/s
# 6424660: done 4059 games, mean reward 17.330, speed 155.67 f/s
# 6426741: done 4060 games, mean reward 17.330, speed 126.28 f/s
# 6426937: done 4061 games, mean reward 17.320, speed 99.84 f/s
# 6431070: done 4062 games, mean reward 17.360, speed 124.74 f/s
# 6431076: done 4063 games, mean reward 17.270, speed 73.76 f/s
# 6433399: done 4064 games, mean reward 17.280, speed 122.80 f/s
# 6438159: done 4065 games, mean reward 17.380, speed 120.11 f/s
# 6442219: done 4066 games, mean reward 17.390, speed 125.01 f/s
# 6442629: done 4067 games, mean reward 17.390, speed 107.49 f/s
# 6444237: done 4068 games, mean reward 17.380, speed 125.58 f/s
# 6444457: done 4069 games, mean reward 17.380, speed 104.60 f/s
# 6449240: done 4070 games, mean reward 17.450, speed 122.27 f/s
# 6450158: done 4071 games, mean reward 17.460, speed 125.86 f/s
# 6450620: done 4072 games, mean reward 17.620, speed 110.54 f/s
# 6455255: done 4073 games, mean reward 17.610, speed 121.73 f/s
# 6457553: done 4074 games, mean reward 17.680, speed 121.99 f/s
# 6458499: done 4075 games, mean reward 17.690, speed 115.74 f/s
# 6460581: done 4076 games, mean reward 17.740, speed 127.27 f/s
# 6466926: done 4077 games, mean reward 17.790, speed 125.37 f/s
# 6468768: done 4078 games, mean reward 17.790, speed 117.96 f/s
# 6469136: done 4079 games, mean reward 17.830, speed 116.68 f/s
# 6469858: done 4080 games, mean reward 17.880, speed 128.19 f/s
# 6470741: done 4081 games, mean reward 17.860, speed 117.59 f/s
# 6471777: done 4082 games, mean reward 17.840, speed 118.81 f/s
# 6473439: done 4083 games, mean reward 17.810, speed 122.27 f/s
# 6476501: done 4084 games, mean reward 17.850, speed 122.83 f/s
# 6477712: done 4085 games, mean reward 17.850, speed 120.16 f/s
# 6478849: done 4086 games, mean reward 17.850, speed 123.61 f/s
# 6480471: done 4087 games, mean reward 17.840, speed 129.78 f/s
# 6481852: done 4088 games, mean reward 17.880, speed 118.82 f/s
# 6484390: done 4089 games, mean reward 17.900, speed 123.97 f/s
# 6485592: done 4090 games, mean reward 17.880, speed 127.19 f/s
# 6486127: done 4091 games, mean reward 17.910, speed 120.86 f/s
# 6494853: done 4092 games, mean reward 17.850, speed 123.90 f/s
# 6495064: done 4093 games, mean reward 17.950, speed 160.70 f/s
# 6497198: done 4094 games, mean reward 17.920, speed 120.51 f/s
# 6497347: done 4095 games, mean reward 17.840, speed 136.04 f/s
# 6500512: done 4096 games, mean reward 17.830, speed 122.56 f/s
# 6501069: done 4097 games, mean reward 17.910, speed 127.64 f/s
# 6503074: done 4098 games, mean reward 17.930, speed 124.80 f/s
# 6503764: done 4099 games, mean reward 17.900, speed 128.00 f/s
# 6503996: done 4100 games, mean reward 17.890, speed 112.03 f/s
# 6504444: done 4101 games, mean reward 17.900, speed 126.67 f/s
# 6506085: done 4102 games, mean reward 17.950, speed 121.53 f/s
# 6508271: done 4103 games, mean reward 17.950, speed 116.51 f/s
# 6508398: done 4104 games, mean reward 17.930, speed 103.89 f/s
# 6510385: done 4105 games, mean reward 17.930, speed 113.52 f/s
# 6512095: done 4106 games, mean reward 17.970, speed 117.08 f/s
# 6513182: done 4107 games, mean reward 17.970, speed 113.24 f/s
# 6517299: done 4108 games, mean reward 18.010, speed 120.33 f/s
# Solved in 6517299 frames!
