# %%
import gym
import ptan
import argparse
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

from tensorboardX import SummaryWriter

from lib import dqn_model_noise, common_dqn_distrib

# %%
# n-step
REWARD_STEPS = 2

#priority replay
PRIO_REPLAY_ALPHA = 0.6
BETA_START = 0.4
BETA_FRAMES = 100000

#C51
Vmax = 10
Vmin = -10
N_ATOMS = 51
DELTA_Z = (Vmax - Vmin) / (N_ATOMS - 1)

# %%
class RainbowDQN(nn.Module):
    #we combine dueling DQN, noisy network and distribution DQN to the same structure, value network predict the 
    #input state distribution, then give each sample a N_ATOMS tensor. Action advantage is the action distribution
    #we made in game
    def __init__(self, input_shape, n_actions):
        super(RainbowDQN, self).__init__()
        
        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )
        
        conv_out_size = self._get_conv_out(input_shape)
        self.fc_val = nn.Sequential(
            dqn_model_noise.NoisyLinear(conv_out_size, 256),
            nn.ReLU(),
            dqn_model_noise.NoisyLinear(256, N_ATOMS)
        )
        
        self.fc_adv = nn.Sequential(
            dqn_model_noise.NoisyLinear(conv_out_size, 256),
            nn.ReLU(),
            dqn_model_noise.NoisyLinear(256, n_actions * N_ATOMS)
        )
        
        self.register_buffer("supports", torch.arange(Vmin, Vmax + DELTA_Z, DELTA_Z))
        self.softmax = nn.Softmax(dim=1)
        
    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))
    
    #forward will get the action value distribution, similar to the q-value in distribution DQN, by formulating the 
    #value path and advantage action path, our return expression become simplier, this is by the broadcasting function in
    #pytorch, it automatically implemented the unsequeeze and expand function for dimension expansion
    
    #we want to let all values that should be summed up having the same dimension, such as value path will be changed as 
    #(batch_size, 1, N_ATOMS), 2nd dimension will broadcast to all actions in action advantage path, we need to minus
    #the baseline advantage, it is the mean advantage for the atom to perform all actions, keepdim=True call mean() to store
    #2nd dimension, the shape is the tensor of (batch_size, 1, N_ATOMS). Baseline advantage will also be broadcasted.
    def forward(self, x):
        batch_size = x.size()[0]
        fx = x.float() / 256
        conv_out = self.conv(fx).view(batch_size, -1)
        val_out = self.fc_val(conv_out).view(batch_size, 1, N_ATOMS)
        adv_out = self.fc_adv(conv_out).view(batch_size, -1, N_ATOMS)
        adv_mean = adv_out.mean(dim=1, keepdim=True)
        return val_out + (adv_out - adv_mean)
    
    #the function change probability distribution to q-values without calling the network multiple times
    def both(self, x):
        cat_out = self(x)
        probs = self.apply_softmax(cat_out)
        weights = probs * self.supports
        res = weights.sum(dim=2)
        return cat_out, res
    
    def qvals(self, x):
        return self.both(x)[1]
    
    #we put softmax function on the output distribution probabilities
    def apply_softmax(self, t):
        return self.softmax(t.view(-1, N_ATOMS)).view(t.size())

# %%
def calc_loss(batch, batch_weights, net, tgt_net, gamma, device="cpu"):
    states, actions, rewards, dones, next_states = common_dqn_distrib.unpack_batch(batch)
    batch_size = len(batch)
    
    #we send batch weightings to each sample(priority replay buffer)
    states_v = torch.tensor(states).to(device)
    actions_v = torch.tensor(actions).to(device)
    next_states_v = torch.tensor(next_states).to(device)
    batch_weights_v = torch.tensor(batch_weights).to(device)
    
    #double DQN here requires online network to choose action and target network to get the action value, we need to pass
    #the current state and the next state to our online network, if we call the function twice as before, the efficiency is
    #low, therefore, we combine current state and next state as a tensor, transfer and calculate the result, then we will 
    #separate the result. We need to calculate the q-value and the original state distribution, because we use greedy policy
    #as the action method with largest q-value.
    distr_v, qvals_v = net.both(torch.cat((states_v, next_states_v)))
    next_qvals_v = qvals_v[batch_size:]
    distr_v = distr_v[:batch_size]
    
    #we decide the action should be performed in the next state, and use our target network to get the action value
    #distribution, therefore here implemented Double DQN. Then we put softmax above the distribution to get the best action
    #and copy the data to cpu to perform Bellman equation projection.
    next_actions_v = next_qvals_v.max(1)[1]
    next_distr_v = tgt_net(next_states_v)
    next_best_distr_v = next_distr_v[range(batch_size), next_actions_v.data]
    next_best_distr_v = tgt_net.apply_softmax(next_best_distr_v)
    next_best_distr = next_best_distr_v.data.cpu().numpy()
    
    #we use Bellman equation to calculate projection distribution, the result will be used as Kullback Leibler divergence
    #target
    dones = dones.astype(np.bool)
    proj_distr = common_dqn_distrib.distr_projection(next_best_distr, rewards, dones, Vmin, Vmax, N_ATOMS, gamma)
    
    #We get the action chosen distribution, and use log_softmax to calculate loss
    state_action_values = distr_v[range(batch_size), actions_v.data]
    state_log_sm_v = F.log_softmax(state_action_values, dim=1)
    
    #we calculate Kullback Leibler loss here, and multiply the weightings and return 2 number: the mean loss in optimization
    #and the loss for a batch, these will be used as the value for priority replay buffer.
    proj_distr_v = torch.tensor(proj_distr).to(device)
    loss_v = -state_log_sm_v * proj_distr_v
    loss_v = batch_weights_v * loss_v.sum(dim=1)
    return loss_v.mean(), loss_v + 1e-5

# %%
if __name__ == "__main__":
    #construct training objects, custom network, experience source, prioritized replay buffer and optimizer
    params = common_dqn_distrib.HYPERPARAMS['pong']
    params['epsilon_frames'] *= 2
    parser = argparse.ArgumentParser()
    parser.add_argument("--cuda", default=True, action="store_true", help="Enable cuda")
    args, unknown = parser.parse_known_args()
    device = torch.device("cuda" if args.cuda else "cpu")
    
    env = gym.make(params['env_name'])
    env = ptan.common.wrappers.wrap_dqn(env)
    
    writer = SummaryWriter(comment="-" + params['run_name'] + "-rainbow")
    net = RainbowDQN(env.observation_space.shape, env.action_space.n).to(device)
    tgt_net = ptan.agent.TargetNet(net)
    agent = ptan.agent.DQNAgent(lambda x: net.qvals(x), ptan.actions.ArgmaxActionSelector(), device=device)
    
    exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, gamma=params['gamma'], steps_count=REWARD_STEPS)
    buffer = ptan.experience.PrioritizedReplayBuffer(exp_source, params['replay_size'], PRIO_REPLAY_ALPHA)
    optimizer = optim.Adam(net.parameters(), lr=params['learning_rate'])
    
    frame_idx = 0
    beta = BETA_START
    
    with common_dqn_distrib.RewardTracker(writer, params['stop_reward']) as reward_tracker:
        while True:
            frame_idx += 1
            buffer.populate(1)
            beta = min(1.0, BETA_START + frame_idx * (1.0 - BETA_START) / BETA_FRAMES)
            
            new_rewards = exp_source.pop_total_rewards()
            if new_rewards:
                if reward_tracker.reward(new_rewards[0], frame_idx):
                    break
                    
            if len(buffer) < params['replay_initial']:
                continue
                
            optimizer.zero_grad()
            batch, batch_indices, batch_weights = buffer.sample(params['batch_size'], beta)
            loss_v, sample_prios_v = calc_loss(batch, batch_weights, net, tgt_net.target_model,\
                                               params['gamma'] ** REWARD_STEPS, device=device)
            loss_v.backward()
            optimizer.step()
            buffer.update_priorities(batch_indices, sample_prios_v.data.cpu().numpy())
            
            if frame_idx % params['target_net_sync'] == 0:
                tgt_net.sync()
# Out:
# 761: done 1 games, mean reward -21.000, speed 155.05 f/s
# 1517: done 2 games, mean reward -21.000, speed 177.77 f/s
# 2277: done 3 games, mean reward -21.000, speed 161.44 f/s
# 3035: done 4 games, mean reward -21.000, speed 160.70 f/s
# 3792: done 5 games, mean reward -21.000, speed 162.52 f/s
# 4554: done 6 games, mean reward -21.000, speed 155.61 f/s
# 5314: done 7 games, mean reward -21.000, speed 161.34 f/s
# 6074: done 8 games, mean reward -21.000, speed 165.64 f/s
# 6830: done 9 games, mean reward -21.000, speed 164.52 f/s
# 7590: done 10 games, mean reward -21.000, speed 162.30 f/s
# 8348: done 11 games, mean reward -21.000, speed 163.33 f/s
# 9107: done 12 games, mean reward -21.000, speed 169.52 f/s
# 9867: done 13 games, mean reward -21.000, speed 166.31 f/s
# 10835: done 14 games, mean reward -20.857, speed 34.16 f/s
# 11672: done 15 games, mean reward -20.800, speed 29.84 f/s
# 12434: done 16 games, mean reward -20.812, speed 29.92 f/s
# 13195: done 17 games, mean reward -20.824, speed 30.34 f/s
# 13957: done 18 games, mean reward -20.833, speed 30.09 f/s
# 14714: done 19 games, mean reward -20.842, speed 27.97 f/s
# 15474: done 20 games, mean reward -20.850, speed 26.33 f/s
# 16231: done 21 games, mean reward -20.857, speed 27.64 f/s
# 16994: done 22 games, mean reward -20.864, speed 28.13 f/s
# 17826: done 23 games, mean reward -20.826, speed 27.33 f/s
# 18614: done 24 games, mean reward -20.833, speed 29.93 f/s
# 19404: done 25 games, mean reward -20.840, speed 30.09 f/s
# 20162: done 26 games, mean reward -20.846, speed 30.01 f/s
# 21030: done 27 games, mean reward -20.815, speed 30.05 f/s
# 21816: done 28 games, mean reward -20.821, speed 30.12 f/s
# 22650: done 29 games, mean reward -20.793, speed 30.04 f/s
# 23440: done 30 games, mean reward -20.800, speed 29.76 f/s
# 24229: done 31 games, mean reward -20.806, speed 29.94 f/s
# 25087: done 32 games, mean reward -20.781, speed 29.69 f/s
# 25921: done 33 games, mean reward -20.758, speed 28.62 f/s
# 26709: done 34 games, mean reward -20.765, speed 28.83 f/s
# 27499: done 35 games, mean reward -20.771, speed 29.59 f/s
# 28290: done 36 games, mean reward -20.778, speed 29.12 f/s
# 29075: done 37 games, mean reward -20.784, speed 27.36 f/s
# 29884: done 38 games, mean reward -20.789, speed 24.72 f/s
# 30819: done 39 games, mean reward -20.744, speed 26.97 f/s
# 31610: done 40 games, mean reward -20.750, speed 23.38 f/s
# 32428: done 41 games, mean reward -20.756, speed 23.45 f/s
# 33269: done 42 games, mean reward -20.738, speed 23.67 f/s
# 34119: done 43 games, mean reward -20.744, speed 23.98 f/s
# 34956: done 44 games, mean reward -20.727, speed 25.31 f/s
# 35968: done 45 games, mean reward -20.711, speed 27.71 f/s
# 36756: done 46 games, mean reward -20.717, speed 26.74 f/s
# 37542: done 47 games, mean reward -20.723, speed 21.81 f/s
# 38330: done 48 games, mean reward -20.729, speed 23.90 f/s
# 39164: done 49 games, mean reward -20.735, speed 23.76 f/s
# 39983: done 50 games, mean reward -20.740, speed 26.08 f/s
# 40813: done 51 games, mean reward -20.725, speed 26.40 f/s
# 41641: done 52 games, mean reward -20.731, speed 28.34 f/s
# 42601: done 53 games, mean reward -20.698, speed 28.33 f/s
# 43460: done 54 games, mean reward -20.685, speed 28.67 f/s
# 44425: done 55 games, mean reward -20.655, speed 28.85 f/s
# 45323: done 56 games, mean reward -20.643, speed 27.44 f/s
# 46112: done 57 games, mean reward -20.649, speed 24.62 f/s
# 46917: done 58 games, mean reward -20.655, speed 23.49 f/s
# 47694: done 59 games, mean reward -20.661, speed 22.94 f/s
# 48530: done 60 games, mean reward -20.650, speed 23.52 f/s
# 49350: done 61 games, mean reward -20.656, speed 23.46 f/s
# 50253: done 62 games, mean reward -20.645, speed 23.28 f/s
# 51033: done 63 games, mean reward -20.651, speed 23.61 f/s
# 51809: done 64 games, mean reward -20.656, speed 23.38 f/s
# 52644: done 65 games, mean reward -20.646, speed 22.55 f/s
# 53403: done 66 games, mean reward -20.652, speed 23.63 f/s
# 54240: done 67 games, mean reward -20.642, speed 23.25 f/s
# 55074: done 68 games, mean reward -20.632, speed 23.48 f/s
# 55913: done 69 games, mean reward -20.623, speed 23.50 f/s
# 56745: done 70 games, mean reward -20.614, speed 23.14 f/s
# 57582: done 71 games, mean reward -20.606, speed 23.75 f/s
# 58371: done 72 games, mean reward -20.611, speed 23.41 f/s
# 59147: done 73 games, mean reward -20.616, speed 23.53 f/s
# 59978: done 74 games, mean reward -20.608, speed 23.64 f/s
# 60769: done 75 games, mean reward -20.613, speed 23.02 f/s
# 61603: done 76 games, mean reward -20.605, speed 23.34 f/s
# 62447: done 77 games, mean reward -20.610, speed 23.79 f/s
# 63263: done 78 games, mean reward -20.615, speed 23.40 f/s
# 64044: done 79 games, mean reward -20.620, speed 23.18 f/s
# 64856: done 80 games, mean reward -20.625, speed 23.31 f/s
# 65724: done 81 games, mean reward -20.617, speed 23.42 f/s
# 66512: done 82 games, mean reward -20.622, speed 23.44 f/s
# 67357: done 83 games, mean reward -20.627, speed 23.54 f/s
# 68116: done 84 games, mean reward -20.631, speed 23.48 f/s
# 68906: done 85 games, mean reward -20.635, speed 23.46 f/s
# 69665: done 86 games, mean reward -20.640, speed 23.46 f/s
# 70425: done 87 games, mean reward -20.644, speed 23.14 f/s
# 71282: done 88 games, mean reward -20.636, speed 23.29 f/s
# 72068: done 89 games, mean reward -20.640, speed 23.48 f/s
# 72858: done 90 games, mean reward -20.644, speed 23.25 f/s
# 73642: done 91 games, mean reward -20.648, speed 22.98 f/s
# 74417: done 92 games, mean reward -20.652, speed 23.49 f/s
# 75237: done 93 games, mean reward -20.656, speed 23.13 f/s
# 75997: done 94 games, mean reward -20.660, speed 23.25 f/s
# 76756: done 95 games, mean reward -20.663, speed 23.35 f/s
# 77518: done 96 games, mean reward -20.667, speed 23.09 f/s
# 78275: done 97 games, mean reward -20.670, speed 23.25 f/s
# 79031: done 98 games, mean reward -20.673, speed 23.43 f/s
# 79789: done 99 games, mean reward -20.677, speed 23.37 f/s
# 80547: done 100 games, mean reward -20.680, speed 22.99 f/s
# 81308: done 101 games, mean reward -20.680, speed 23.26 f/s
# 82086: done 102 games, mean reward -20.680, speed 23.19 f/s
# 82877: done 103 games, mean reward -20.680, speed 23.26 f/s
# 83818: done 104 games, mean reward -20.660, speed 23.37 f/s
# 84576: done 105 games, mean reward -20.660, speed 23.05 f/s
# 85335: done 106 games, mean reward -20.660, speed 23.58 f/s
# 86091: done 107 games, mean reward -20.660, speed 23.36 f/s
# 86925: done 108 games, mean reward -20.650, speed 23.25 f/s
# 87711: done 109 games, mean reward -20.650, speed 23.26 f/s
# 88471: done 110 games, mean reward -20.650, speed 23.47 f/s
# 89232: done 111 games, mean reward -20.650, speed 22.93 f/s
# 89995: done 112 games, mean reward -20.650, speed 23.30 f/s
# 90758: done 113 games, mean reward -20.650, speed 23.26 f/s
# 91520: done 114 games, mean reward -20.670, speed 23.10 f/s
# 92282: done 115 games, mean reward -20.680, speed 23.21 f/s
# 93043: done 116 games, mean reward -20.680, speed 23.06 f/s
# 93873: done 117 games, mean reward -20.670, speed 23.28 f/s
# 94663: done 118 games, mean reward -20.670, speed 23.40 f/s
# 95451: done 119 games, mean reward -20.670, speed 23.01 f/s
# 96235: done 120 games, mean reward -20.670, speed 22.41 f/s
# 97101: done 121 games, mean reward -20.660, speed 23.17 f/s
# 97860: done 122 games, mean reward -20.660, speed 23.00 f/s
# 98619: done 123 games, mean reward -20.670, speed 23.24 f/s
# 99376: done 124 games, mean reward -20.670, speed 23.01 f/s
# 100132: done 125 games, mean reward -20.670, speed 22.61 f/s
# 100889: done 126 games, mean reward -20.670, speed 22.38 f/s
# 101647: done 127 games, mean reward -20.680, speed 22.47 f/s
# 102407: done 128 games, mean reward -20.680, speed 22.20 f/s
# 103168: done 129 games, mean reward -20.690, speed 22.15 f/s
# 103927: done 130 games, mean reward -20.690, speed 22.30 f/s
# 104686: done 131 games, mean reward -20.690, speed 22.31 f/s
# 105442: done 132 games, mean reward -20.700, speed 22.27 f/s
# 106277: done 133 games, mean reward -20.700, speed 22.29 f/s
# 107038: done 134 games, mean reward -20.700, speed 22.58 f/s
# 107871: done 135 games, mean reward -20.700, speed 22.41 f/s
# 108658: done 136 games, mean reward -20.700, speed 21.98 f/s
# 109433: done 137 games, mean reward -20.700, speed 22.40 f/s
# 110299: done 138 games, mean reward -20.690, speed 22.08 f/s
# 111135: done 139 games, mean reward -20.700, speed 22.35 f/s
# 112002: done 140 games, mean reward -20.690, speed 22.09 f/s
# 112763: done 141 games, mean reward -20.690, speed 22.24 f/s
# 113604: done 142 games, mean reward -20.690, speed 22.58 f/s
# 114365: done 143 games, mean reward -20.690, speed 22.21 f/s
# 115123: done 144 games, mean reward -20.700, speed 22.53 f/s
# 115909: done 145 games, mean reward -20.710, speed 22.52 f/s
# 116684: done 146 games, mean reward -20.710, speed 22.31 f/s
# 117553: done 147 games, mean reward -20.700, speed 22.20 f/s
# 118388: done 148 games, mean reward -20.690, speed 21.93 f/s
# 119179: done 149 games, mean reward -20.690, speed 22.04 f/s
# 119942: done 150 games, mean reward -20.690, speed 21.93 f/s
# 120782: done 151 games, mean reward -20.690, speed 21.90 f/s
# 121614: done 152 games, mean reward -20.680, speed 22.24 f/s
# 122377: done 153 games, mean reward -20.700, speed 22.10 f/s
# 123311: done 154 games, mean reward -20.690, speed 28.55 f/s
# 124090: done 155 games, mean reward -20.710, speed 28.10 f/s
# 124853: done 156 games, mean reward -20.720, speed 28.44 f/s
# 125614: done 157 games, mean reward -20.720, speed 28.63 f/s
# 126485: done 158 games, mean reward -20.710, speed 28.63 f/s
# 127321: done 159 games, mean reward -20.700, speed 28.61 f/s
# 128137: done 160 games, mean reward -20.710, speed 28.45 f/s
# 128895: done 161 games, mean reward -20.710, speed 28.42 f/s
# 129653: done 162 games, mean reward -20.720, speed 28.72 f/s
# 130443: done 163 games, mean reward -20.720, speed 28.80 f/s
# 131356: done 164 games, mean reward -20.710, speed 28.70 f/s
# 132133: done 165 games, mean reward -20.720, speed 28.38 f/s
# 132969: done 166 games, mean reward -20.710, speed 28.82 f/s
# 133831: done 167 games, mean reward -20.710, speed 28.59 f/s
# 134619: done 168 games, mean reward -20.720, speed 26.90 f/s
# 135375: done 169 games, mean reward -20.730, speed 28.11 f/s
# 136153: done 170 games, mean reward -20.740, speed 28.54 f/s
# 136988: done 171 games, mean reward -20.740, speed 28.43 f/s
# 137852: done 172 games, mean reward -20.730, speed 28.80 f/s
# 138610: done 173 games, mean reward -20.730, speed 28.83 f/s
# 139389: done 174 games, mean reward -20.740, speed 28.41 f/s
# 140152: done 175 games, mean reward -20.740, speed 28.55 f/s
# 140909: done 176 games, mean reward -20.750, speed 28.67 f/s
# 141667: done 177 games, mean reward -20.750, speed 28.60 f/s
# 142501: done 178 games, mean reward -20.740, speed 28.27 f/s
# 143264: done 179 games, mean reward -20.740, speed 28.19 f/s
# 144024: done 180 games, mean reward -20.740, speed 28.59 f/s
# 144787: done 181 games, mean reward -20.750, speed 28.40 f/s
# 145623: done 182 games, mean reward -20.740, speed 28.79 f/s
# 146460: done 183 games, mean reward -20.730, speed 28.54 f/s
# 147278: done 184 games, mean reward -20.730, speed 28.71 f/s
# 148109: done 185 games, mean reward -20.720, speed 28.65 f/s
# 148950: done 186 games, mean reward -20.710, speed 28.42 f/s
# 149706: done 187 games, mean reward -20.710, speed 28.74 f/s
# 150552: done 188 games, mean reward -20.720, speed 28.71 f/s
# 151394: done 189 games, mean reward -20.710, speed 28.75 f/s
# 152280: done 190 games, mean reward -20.700, speed 28.63 f/s
# 153039: done 191 games, mean reward -20.700, speed 28.82 f/s
# 153795: done 192 games, mean reward -20.700, speed 28.80 f/s
# 154554: done 193 games, mean reward -20.700, speed 27.73 f/s
# 155384: done 194 games, mean reward -20.690, speed 28.84 f/s
# 156188: done 195 games, mean reward -20.690, speed 28.44 f/s
# 157023: done 196 games, mean reward -20.680, speed 28.57 f/s
# 157855: done 197 games, mean reward -20.670, speed 28.70 f/s
# 158686: done 198 games, mean reward -20.660, speed 28.60 f/s
# 159525: done 199 games, mean reward -20.650, speed 28.60 f/s
# 160299: done 200 games, mean reward -20.650, speed 28.57 f/s
# 161057: done 201 games, mean reward -20.650, speed 28.44 f/s
# 161816: done 202 games, mean reward -20.650, speed 28.80 f/s
# 162650: done 203 games, mean reward -20.640, speed 28.79 f/s
# 163413: done 204 games, mean reward -20.660, speed 28.73 f/s
# 164217: done 205 games, mean reward -20.660, speed 28.53 f/s
# 165058: done 206 games, mean reward -20.650, speed 28.44 f/s
# 165891: done 207 games, mean reward -20.640, speed 28.67 f/s
# 166723: done 208 games, mean reward -20.640, speed 28.52 f/s
# 167485: done 209 games, mean reward -20.640, speed 28.61 f/s
# 168241: done 210 games, mean reward -20.640, speed 28.54 f/s
# 168998: done 211 games, mean reward -20.640, speed 28.30 f/s
# 169832: done 212 games, mean reward -20.630, speed 28.69 f/s
# 170666: done 213 games, mean reward -20.620, speed 28.77 f/s
# 171504: done 214 games, mean reward -20.610, speed 28.51 f/s
# 172266: done 215 games, mean reward -20.610, speed 28.63 f/s
# 173101: done 216 games, mean reward -20.600, speed 28.45 f/s
# 173940: done 217 games, mean reward -20.600, speed 28.61 f/s
# 174701: done 218 games, mean reward -20.600, speed 28.42 f/s
# 175536: done 219 games, mean reward -20.590, speed 28.52 f/s
# 176398: done 220 games, mean reward -20.580, speed 28.56 f/s
# 177156: done 221 games, mean reward -20.590, speed 28.25 f/s
# 177942: done 222 games, mean reward -20.590, speed 28.83 f/s
# 178776: done 223 games, mean reward -20.580, speed 28.45 f/s
# 179563: done 224 games, mean reward -20.580, speed 28.65 f/s
# 180421: done 225 games, mean reward -20.570, speed 28.64 f/s
# 181179: done 226 games, mean reward -20.570, speed 28.67 f/s
# 182018: done 227 games, mean reward -20.560, speed 28.59 f/s
# 182857: done 228 games, mean reward -20.550, speed 28.49 f/s
# 183694: done 229 games, mean reward -20.540, speed 28.31 f/s
# 184635: done 230 games, mean reward -20.520, speed 28.55 f/s
# 185441: done 231 games, mean reward -20.520, speed 28.48 f/s
# 186225: done 232 games, mean reward -20.520, speed 28.31 f/s
# 187059: done 233 games, mean reward -20.520, speed 28.58 f/s
# 187820: done 234 games, mean reward -20.520, speed 28.44 f/s
# 188736: done 235 games, mean reward -20.510, speed 28.48 f/s
# 189493: done 236 games, mean reward -20.510, speed 28.69 f/s
# 190405: done 237 games, mean reward -20.490, speed 28.43 f/s
# 191354: done 238 games, mean reward -20.480, speed 28.46 f/s
# 192143: done 239 games, mean reward -20.490, speed 28.65 f/s
# 192904: done 240 games, mean reward -20.500, speed 28.64 f/s
# 193666: done 241 games, mean reward -20.500, speed 28.48 f/s
# 194427: done 242 games, mean reward -20.510, speed 28.13 f/s
# 195186: done 243 games, mean reward -20.510, speed 28.16 f/s
# 196020: done 244 games, mean reward -20.500, speed 28.39 f/s
# 196776: done 245 games, mean reward -20.500, speed 28.42 f/s
# 197612: done 246 games, mean reward -20.490, speed 28.49 f/s
# 198375: done 247 games, mean reward -20.500, speed 28.50 f/s
# 199205: done 248 games, mean reward -20.510, speed 28.44 f/s
# 199965: done 249 games, mean reward -20.510, speed 28.44 f/s
# 200724: done 250 games, mean reward -20.510, speed 28.47 f/s
# 201562: done 251 games, mean reward -20.510, speed 28.43 f/s
# 202319: done 252 games, mean reward -20.520, speed 28.20 f/s
# 203151: done 253 games, mean reward -20.510, speed 28.59 f/s
# 203985: done 254 games, mean reward -20.520, speed 28.47 f/s
# 204746: done 255 games, mean reward -20.520, speed 28.27 f/s
# 205509: done 256 games, mean reward -20.520, speed 28.47 f/s
# 206293: done 257 games, mean reward -20.520, speed 28.35 f/s
# 207129: done 258 games, mean reward -20.520, speed 28.56 f/s
# 207891: done 259 games, mean reward -20.530, speed 28.67 f/s
# 208647: done 260 games, mean reward -20.530, speed 28.68 f/s
# 209403: done 261 games, mean reward -20.530, speed 28.27 f/s
# 210159: done 262 games, mean reward -20.530, speed 28.52 f/s
# 210916: done 263 games, mean reward -20.530, speed 28.46 f/s
# 211700: done 264 games, mean reward -20.540, speed 28.32 f/s
# 212462: done 265 games, mean reward -20.540, speed 28.37 f/s
# 213223: done 266 games, mean reward -20.550, speed 28.44 f/s
# 213999: done 267 games, mean reward -20.560, speed 28.41 f/s
# 214758: done 268 games, mean reward -20.560, speed 28.39 f/s
# 215519: done 269 games, mean reward -20.560, speed 27.77 f/s
# 216294: done 270 games, mean reward -20.560, speed 27.89 f/s
# 217126: done 271 games, mean reward -20.560, speed 28.26 f/s
# 217912: done 272 games, mean reward -20.570, speed 28.17 f/s
# 218669: done 273 games, mean reward -20.570, speed 28.33 f/s
# 219586: done 274 games, mean reward -20.550, speed 28.26 f/s
# 220344: done 275 games, mean reward -20.550, speed 28.55 f/s
# 221106: done 276 games, mean reward -20.550, speed 28.38 f/s
# 221865: done 277 games, mean reward -20.550, speed 28.73 f/s
# 222697: done 278 games, mean reward -20.550, speed 28.53 f/s
# 223458: done 279 games, mean reward -20.550, speed 28.53 f/s
# 224237: done 280 games, mean reward -20.550, speed 28.25 f/s
# 225076: done 281 games, mean reward -20.540, speed 28.36 f/s
# 225864: done 282 games, mean reward -20.550, speed 28.52 f/s
# 226697: done 283 games, mean reward -20.550, speed 28.27 f/s
# 227566: done 284 games, mean reward -20.540, speed 28.59 f/s
# 228399: done 285 games, mean reward -20.540, speed 28.54 f/s
# 229261: done 286 games, mean reward -20.540, speed 28.37 f/s
# 230125: done 287 games, mean reward -20.530, speed 28.23 f/s
# 230960: done 288 games, mean reward -20.520, speed 28.27 f/s
# 231746: done 289 games, mean reward -20.530, speed 28.61 f/s
# 232552: done 290 games, mean reward -20.540, speed 28.59 f/s
# 233308: done 291 games, mean reward -20.540, speed 28.41 f/s
# 234175: done 292 games, mean reward -20.530, speed 28.60 f/s
# 234960: done 293 games, mean reward -20.530, speed 28.14 f/s
# 235859: done 294 games, mean reward -20.530, speed 28.11 f/s
# 236695: done 295 games, mean reward -20.520, speed 28.52 f/s
# 237470: done 296 games, mean reward -20.530, speed 28.52 f/s
# 238227: done 297 games, mean reward -20.540, speed 28.38 f/s
# 238984: done 298 games, mean reward -20.550, speed 28.38 f/s
# 239741: done 299 games, mean reward -20.560, speed 28.39 f/s
# 240522: done 300 games, mean reward -20.560, speed 28.63 f/s
# 241324: done 301 games, mean reward -20.560, speed 28.75 f/s
# 242291: done 302 games, mean reward -20.550, speed 28.35 f/s
# 243050: done 303 games, mean reward -20.560, speed 28.24 f/s
# 243810: done 304 games, mean reward -20.560, speed 28.38 f/s
# 244567: done 305 games, mean reward -20.560, speed 28.21 f/s
# 245327: done 306 games, mean reward -20.570, speed 28.56 f/s
# 246132: done 307 games, mean reward -20.580, speed 28.59 f/s
# 246971: done 308 games, mean reward -20.580, speed 28.30 f/s
# 247734: done 309 games, mean reward -20.580, speed 28.65 f/s
# 248497: done 310 games, mean reward -20.580, speed 28.48 f/s
# 249285: done 311 games, mean reward -20.580, speed 28.71 f/s
# 250124: done 312 games, mean reward -20.580, speed 28.53 f/s
# 250886: done 313 games, mean reward -20.590, speed 28.47 f/s
# 251646: done 314 games, mean reward -20.600, speed 28.28 f/s
# 252465: done 315 games, mean reward -20.600, speed 28.30 f/s
# 253303: done 316 games, mean reward -20.600, speed 28.40 f/s
# 254060: done 317 games, mean reward -20.610, speed 28.43 f/s
# 254817: done 318 games, mean reward -20.610, speed 28.33 f/s
# 255651: done 319 games, mean reward -20.610, speed 28.33 f/s
# 256488: done 320 games, mean reward -20.610, speed 28.29 f/s
# 257277: done 321 games, mean reward -20.610, speed 28.79 f/s
# 258115: done 322 games, mean reward -20.600, speed 28.55 f/s
# 258897: done 323 games, mean reward -20.610, speed 28.58 f/s
# 259658: done 324 games, mean reward -20.610, speed 28.37 f/s
# 260493: done 325 games, mean reward -20.610, speed 28.13 f/s
# 261277: done 326 games, mean reward -20.610, speed 28.22 f/s
# 262112: done 327 games, mean reward -20.610, speed 28.19 f/s
# 262873: done 328 games, mean reward -20.620, speed 28.39 f/s
# 263630: done 329 games, mean reward -20.630, speed 28.24 f/s
# 264412: done 330 games, mean reward -20.650, speed 28.45 f/s
# 265279: done 331 games, mean reward -20.640, speed 28.33 f/s
# 266116: done 332 games, mean reward -20.630, speed 28.18 f/s
# 266878: done 333 games, mean reward -20.640, speed 28.55 f/s
# 267636: done 334 games, mean reward -20.640, speed 28.53 f/s
# 268395: done 335 games, mean reward -20.650, speed 28.46 f/s
# 269151: done 336 games, mean reward -20.650, speed 28.31 f/s
# 270061: done 337 games, mean reward -20.650, speed 28.13 f/s
# 270818: done 338 games, mean reward -20.670, speed 27.81 f/s
# 271656: done 339 games, mean reward -20.660, speed 28.50 f/s
# 272419: done 340 games, mean reward -20.660, speed 28.41 f/s
# 273176: done 341 games, mean reward -20.660, speed 28.09 f/s
# 274005: done 342 games, mean reward -20.650, speed 28.35 f/s
# 274795: done 343 games, mean reward -20.650, speed 28.56 f/s
# 275631: done 344 games, mean reward -20.650, speed 28.60 f/s
# 276417: done 345 games, mean reward -20.650, speed 28.38 f/s
# 277252: done 346 games, mean reward -20.650, speed 28.65 f/s
# 278015: done 347 games, mean reward -20.650, speed 28.33 f/s
# 278772: done 348 games, mean reward -20.650, speed 28.32 f/s
# 279559: done 349 games, mean reward -20.650, speed 28.44 f/s
# 280315: done 350 games, mean reward -20.650, speed 28.26 f/s
# 281074: done 351 games, mean reward -20.660, speed 28.33 f/s
# 281833: done 352 games, mean reward -20.660, speed 28.35 f/s
# 282592: done 353 games, mean reward -20.670, speed 28.34 f/s
# 283454: done 354 games, mean reward -20.670, speed 28.38 f/s
# 284294: done 355 games, mean reward -20.660, speed 28.49 f/s
# 285072: done 356 games, mean reward -20.660, speed 28.44 f/s
# 285828: done 357 games, mean reward -20.660, speed 27.91 f/s
# 286591: done 358 games, mean reward -20.670, speed 28.34 f/s
# 287347: done 359 games, mean reward -20.670, speed 28.01 f/s
# 288105: done 360 games, mean reward -20.670, speed 28.54 f/s
# 288865: done 361 games, mean reward -20.670, speed 28.34 f/s
# 289626: done 362 games, mean reward -20.670, speed 28.56 f/s
# 290388: done 363 games, mean reward -20.670, speed 28.64 f/s
# 291150: done 364 games, mean reward -20.670, speed 28.19 f/s
# 291928: done 365 games, mean reward -20.670, speed 28.32 f/s
# 292875: done 366 games, mean reward -20.650, speed 28.56 f/s
# 293705: done 367 games, mean reward -20.640, speed 28.32 f/s
# 294648: done 368 games, mean reward -20.620, speed 28.37 f/s
# 295408: done 369 games, mean reward -20.620, speed 28.29 f/s
# 296198: done 370 games, mean reward -20.620, speed 28.73 f/s
# 296957: done 371 games, mean reward -20.630, speed 28.46 f/s
# 297717: done 372 games, mean reward -20.630, speed 28.42 f/s
# 298475: done 373 games, mean reward -20.630, speed 28.42 f/s
# 299254: done 374 games, mean reward -20.650, speed 28.63 f/s
# 300017: done 375 games, mean reward -20.650, speed 28.34 f/s
# 300850: done 376 games, mean reward -20.640, speed 28.37 f/s
# 301613: done 377 games, mean reward -20.640, speed 28.31 f/s
# 302454: done 378 games, mean reward -20.640, speed 28.53 f/s
# 303212: done 379 games, mean reward -20.640, speed 28.01 f/s
# 303999: done 380 games, mean reward -20.640, speed 28.03 f/s
# 304760: done 381 games, mean reward -20.650, speed 28.36 f/s
# 305520: done 382 games, mean reward -20.650, speed 28.54 f/s
# 306282: done 383 games, mean reward -20.660, speed 28.60 f/s
# 307068: done 384 games, mean reward -20.670, speed 28.33 f/s
# 307830: done 385 games, mean reward -20.680, speed 28.53 f/s
# 308662: done 386 games, mean reward -20.680, speed 28.26 f/s
# 309420: done 387 games, mean reward -20.690, speed 28.40 f/s
# 310179: done 388 games, mean reward -20.700, speed 28.31 f/s
# 310939: done 389 games, mean reward -20.700, speed 28.27 f/s
# 311701: done 390 games, mean reward -20.700, speed 28.54 f/s
# 312487: done 391 games, mean reward -20.700, speed 28.38 f/s
# 313246: done 392 games, mean reward -20.710, speed 28.56 f/s
# 314113: done 393 games, mean reward -20.700, speed 28.53 f/s
# 314953: done 394 games, mean reward -20.700, speed 28.36 f/s
# 315714: done 395 games, mean reward -20.710, speed 28.33 f/s
# 316476: done 396 games, mean reward -20.710, speed 28.84 f/s
# 317264: done 397 games, mean reward -20.710, speed 28.60 f/s
# 318025: done 398 games, mean reward -20.710, speed 28.19 f/s
# 318786: done 399 games, mean reward -20.710, speed 28.34 f/s
# 319547: done 400 games, mean reward -20.710, speed 28.30 f/s
# 320327: done 401 games, mean reward -20.710, speed 28.18 f/s
# 321087: done 402 games, mean reward -20.720, speed 28.17 f/s
# 321847: done 403 games, mean reward -20.720, speed 28.50 f/s
# 322627: done 404 games, mean reward -20.720, speed 28.58 f/s
# 323383: done 405 games, mean reward -20.720, speed 28.41 f/s
# 324193: done 406 games, mean reward -20.720, speed 28.44 f/s
# 324955: done 407 games, mean reward -20.720, speed 28.26 f/s
# 325790: done 408 games, mean reward -20.720, speed 28.26 f/s
# 326553: done 409 games, mean reward -20.720, speed 28.60 f/s
# 327314: done 410 games, mean reward -20.720, speed 28.30 f/s
# 328101: done 411 games, mean reward -20.720, speed 28.38 f/s
# 328860: done 412 games, mean reward -20.730, speed 28.36 f/s
# 329617: done 413 games, mean reward -20.730, speed 28.54 f/s
# 330378: done 414 games, mean reward -20.730, speed 28.43 f/s
# 331136: done 415 games, mean reward -20.730, speed 28.48 f/s
# 331893: done 416 games, mean reward -20.740, speed 28.50 f/s
# 332656: done 417 games, mean reward -20.740, speed 28.39 f/s
# 333417: done 418 games, mean reward -20.740, speed 28.37 f/s
# 334178: done 419 games, mean reward -20.750, speed 28.48 f/s
# 334940: done 420 games, mean reward -20.760, speed 28.70 f/s
# 335699: done 421 games, mean reward -20.760, speed 28.55 f/s
# 336461: done 422 games, mean reward -20.770, speed 28.46 f/s
# 337223: done 423 games, mean reward -20.770, speed 28.21 f/s
# 337981: done 424 games, mean reward -20.770, speed 28.17 f/s
# 338738: done 425 games, mean reward -20.780, speed 28.07 f/s
# 339573: done 426 games, mean reward -20.770, speed 28.24 f/s
# 340357: done 427 games, mean reward -20.780, speed 27.84 f/s
# 341115: done 428 games, mean reward -20.780, speed 26.86 f/s
# 341905: done 429 games, mean reward -20.780, speed 27.42 f/s
# 342661: done 430 games, mean reward -20.780, speed 25.80 f/s
# 343502: done 431 games, mean reward -20.780, speed 25.03 f/s
# 344262: done 432 games, mean reward -20.790, speed 24.28 f/s
# 345022: done 433 games, mean reward -20.790, speed 23.00 f/s
# 345784: done 434 games, mean reward -20.790, speed 25.85 f/s
# 346619: done 435 games, mean reward -20.780, speed 24.91 f/s
# 347457: done 436 games, mean reward -20.770, speed 26.40 f/s
# 348244: done 437 games, mean reward -20.790, speed 27.70 f/s
# 349033: done 438 games, mean reward -20.790, speed 25.84 f/s
# 349792: done 439 games, mean reward -20.800, speed 27.52 f/s
# 350548: done 440 games, mean reward -20.800, speed 27.51 f/s
# 351310: done 441 games, mean reward -20.800, speed 27.36 f/s
# 352149: done 442 games, mean reward -20.800, speed 27.30 f/s
# 352909: done 443 games, mean reward -20.800, speed 25.91 f/s
# 353665: done 444 games, mean reward -20.810, speed 27.03 f/s
# 354501: done 445 games, mean reward -20.800, speed 27.08 f/s
# 355290: done 446 games, mean reward -20.810, speed 24.28 f/s
# 356048: done 447 games, mean reward -20.810, speed 23.97 f/s
# 356886: done 448 games, mean reward -20.800, speed 26.19 f/s
# 357721: done 449 games, mean reward -20.790, speed 26.78 f/s
# 358481: done 450 games, mean reward -20.790, speed 26.73 f/s
# 359268: done 451 games, mean reward -20.790, speed 26.17 f/s
# 360106: done 452 games, mean reward -20.780, speed 26.18 f/s
# 360910: done 453 games, mean reward -20.780, speed 26.05 f/s
# 361697: done 454 games, mean reward -20.790, speed 27.02 f/s
# 362533: done 455 games, mean reward -20.790, speed 26.97 f/s
# 363369: done 456 games, mean reward -20.780, speed 28.06 f/s
# 364148: done 457 games, mean reward -20.780, speed 28.07 f/s
# 364909: done 458 games, mean reward -20.780, speed 28.17 f/s
# 365917: done 459 games, mean reward -20.750, speed 28.04 f/s
# 366676: done 460 games, mean reward -20.750, speed 28.09 f/s
# 367506: done 461 games, mean reward -20.740, speed 27.80 f/s
# 368309: done 462 games, mean reward -20.740, speed 26.97 f/s
# 369143: done 463 games, mean reward -20.730, speed 27.92 f/s
# 369978: done 464 games, mean reward -20.720, speed 27.59 f/s
# 370844: done 465 games, mean reward -20.710, speed 25.21 f/s
# 371622: done 466 games, mean reward -20.730, speed 26.33 f/s
# 372485: done 467 games, mean reward -20.730, speed 27.39 f/s
# 373311: done 468 games, mean reward -20.750, speed 27.20 f/s
# 374074: done 469 games, mean reward -20.750, speed 27.06 f/s
# 375017: done 470 games, mean reward -20.730, speed 26.66 f/s
# 375774: done 471 games, mean reward -20.730, speed 27.79 f/s
# 376531: done 472 games, mean reward -20.730, speed 27.90 f/s
# 377287: done 473 games, mean reward -20.730, speed 27.97 f/s
# 378044: done 474 games, mean reward -20.730, speed 27.29 f/s
# 378800: done 475 games, mean reward -20.730, speed 26.12 f/s
# 379559: done 476 games, mean reward -20.740, speed 26.75 f/s
# 380339: done 477 games, mean reward -20.740, speed 26.89 f/s
# 381174: done 478 games, mean reward -20.740, speed 27.26 f/s
# 381931: done 479 games, mean reward -20.740, speed 26.35 f/s
# 382691: done 480 games, mean reward -20.740, speed 26.76 f/s
# 383449: done 481 games, mean reward -20.740, speed 27.88 f/s
# 384258: done 482 games, mean reward -20.740, speed 27.96 f/s
# 385046: done 483 games, mean reward -20.740, speed 28.01 f/s
# 385956: done 484 games, mean reward -20.730, speed 27.92 f/s
# 386717: done 485 games, mean reward -20.730, speed 28.21 f/s
# 387550: done 486 games, mean reward -20.730, speed 27.99 f/s
# 388366: done 487 games, mean reward -20.730, speed 27.26 f/s
# 389277: done 488 games, mean reward -20.710, speed 28.32 f/s
# 390037: done 489 games, mean reward -20.710, speed 28.09 f/s
# 390797: done 490 games, mean reward -20.710, speed 28.23 f/s
# 391606: done 491 games, mean reward -20.710, speed 28.17 f/s
# 392392: done 492 games, mean reward -20.710, speed 28.39 f/s
# 393199: done 493 games, mean reward -20.720, speed 28.15 f/s
# 393989: done 494 games, mean reward -20.730, speed 28.33 f/s
# 394746: done 495 games, mean reward -20.730, speed 27.88 f/s
# 395508: done 496 games, mean reward -20.730, speed 24.49 f/s
# 396266: done 497 games, mean reward -20.730, speed 26.88 f/s
# 397027: done 498 games, mean reward -20.730, speed 26.26 f/s
# 397787: done 499 games, mean reward -20.730, speed 27.54 f/s
# 398549: done 500 games, mean reward -20.730, speed 24.75 f/s
# 399384: done 501 games, mean reward -20.720, speed 28.11 f/s
# 400144: done 502 games, mean reward -20.720, speed 26.85 f/s
# 400929: done 503 games, mean reward -20.720, speed 25.99 f/s
# 401768: done 504 games, mean reward -20.710, speed 24.58 f/s
# 402625: done 505 games, mean reward -20.700, speed 27.85 f/s
# 403385: done 506 games, mean reward -20.700, speed 28.04 f/s
# 404144: done 507 games, mean reward -20.700, speed 26.16 f/s
# 404932: done 508 games, mean reward -20.710, speed 26.33 f/s
# 405763: done 509 games, mean reward -20.710, speed 26.20 f/s
# 406601: done 510 games, mean reward -20.700, speed 27.23 f/s
# 407432: done 511 games, mean reward -20.690, speed 28.04 f/s
# 408212: done 512 games, mean reward -20.690, speed 26.07 f/s
# 408973: done 513 games, mean reward -20.690, speed 26.46 f/s
# 409807: done 514 games, mean reward -20.680, speed 27.03 f/s
# 410570: done 515 games, mean reward -20.680, speed 25.85 f/s
# 411332: done 516 games, mean reward -20.680, speed 24.40 f/s
# 412169: done 517 games, mean reward -20.670, speed 25.84 f/s
# 412925: done 518 games, mean reward -20.670, speed 25.28 f/s
# 413688: done 519 games, mean reward -20.670, speed 26.23 f/s
# 414448: done 520 games, mean reward -20.670, speed 27.31 f/s
# 415306: done 521 games, mean reward -20.660, speed 27.32 f/s
# 416063: done 522 games, mean reward -20.660, speed 27.32 f/s
# 416820: done 523 games, mean reward -20.660, speed 27.36 f/s
# 417577: done 524 games, mean reward -20.660, speed 24.57 f/s
# 418337: done 525 games, mean reward -20.660, speed 25.26 f/s
# 419093: done 526 games, mean reward -20.670, speed 26.77 f/s
# 419855: done 527 games, mean reward -20.670, speed 27.58 f/s
# 420630: done 528 games, mean reward -20.670, speed 27.40 f/s
# 421522: done 529 games, mean reward -20.660, speed 26.78 f/s
# 422309: done 530 games, mean reward -20.660, speed 26.50 f/s
# 423072: done 531 games, mean reward -20.670, speed 27.57 f/s
# 423861: done 532 games, mean reward -20.670, speed 27.30 f/s
# 424619: done 533 games, mean reward -20.670, speed 27.02 f/s
# 425381: done 534 games, mean reward -20.670, speed 27.62 f/s
# 426141: done 535 games, mean reward -20.680, speed 27.69 f/s
# 426898: done 536 games, mean reward -20.690, speed 27.79 f/s
# 427659: done 537 games, mean reward -20.690, speed 27.60 f/s
# 428418: done 538 games, mean reward -20.690, speed 27.87 f/s
# 429253: done 539 games, mean reward -20.680, speed 26.69 f/s
# 430031: done 540 games, mean reward -20.680, speed 25.91 f/s
# 430791: done 541 games, mean reward -20.680, speed 26.48 f/s
# 431549: done 542 games, mean reward -20.690, speed 28.03 f/s
# 432308: done 543 games, mean reward -20.690, speed 26.45 f/s
# 433143: done 544 games, mean reward -20.680, speed 27.82 f/s
# 433919: done 545 games, mean reward -20.690, speed 27.96 f/s
# 434757: done 546 games, mean reward -20.680, speed 27.37 f/s
# 435520: done 547 games, mean reward -20.680, speed 26.48 f/s
# 436350: done 548 games, mean reward -20.680, speed 25.69 f/s
# 437113: done 549 games, mean reward -20.690, speed 28.28 f/s
# 437949: done 550 games, mean reward -20.680, speed 27.91 f/s
# 438738: done 551 games, mean reward -20.680, speed 28.14 f/s
# 439496: done 552 games, mean reward -20.690, speed 26.11 f/s
# 440256: done 553 games, mean reward -20.690, speed 27.04 f/s
# 441013: done 554 games, mean reward -20.690, speed 26.59 f/s
# 441773: done 555 games, mean reward -20.700, speed 25.80 f/s
# 442535: done 556 games, mean reward -20.710, speed 28.02 f/s
# 443294: done 557 games, mean reward -20.710, speed 27.50 f/s
# 444129: done 558 games, mean reward -20.700, speed 27.54 f/s
# 444965: done 559 games, mean reward -20.720, speed 28.19 f/s
# 445740: done 560 games, mean reward -20.720, speed 27.23 f/s
# 446619: done 561 games, mean reward -20.720, speed 27.08 f/s
# 447457: done 562 games, mean reward -20.710, speed 26.57 f/s
# 448215: done 563 games, mean reward -20.720, speed 26.64 f/s
# 449023: done 564 games, mean reward -20.730, speed 26.82 f/s
# 449780: done 565 games, mean reward -20.740, speed 27.36 f/s
# 450542: done 566 games, mean reward -20.740, speed 27.79 f/s
# 451323: done 567 games, mean reward -20.750, speed 27.66 f/s
# 452158: done 568 games, mean reward -20.740, speed 28.11 f/s
# 452991: done 569 games, mean reward -20.730, speed 27.67 f/s
# 453752: done 570 games, mean reward -20.750, speed 27.27 f/s
# 454510: done 571 games, mean reward -20.750, speed 26.75 f/s
# 455349: done 572 games, mean reward -20.740, speed 26.58 f/s
# 456107: done 573 games, mean reward -20.740, speed 25.01 f/s
# 456897: done 574 games, mean reward -20.740, speed 26.75 f/s
# 457656: done 575 games, mean reward -20.740, speed 25.65 f/s
# 458493: done 576 games, mean reward -20.730, speed 26.37 f/s
# 459279: done 577 games, mean reward -20.730, speed 25.19 f/s
# 460214: done 578 games, mean reward -20.720, speed 26.11 f/s
# 461051: done 579 games, mean reward -20.710, speed 26.99 f/s
# 461902: done 580 games, mean reward -20.710, speed 27.17 f/s
# 462739: done 581 games, mean reward -20.700, speed 26.84 f/s
# 463500: done 582 games, mean reward -20.700, speed 26.72 f/s
# 464278: done 583 games, mean reward -20.700, speed 26.75 f/s
# 465038: done 584 games, mean reward -20.710, speed 26.64 f/s
# 465812: done 585 games, mean reward -20.710, speed 27.31 f/s
# 466651: done 586 games, mean reward -20.710, speed 27.40 f/s
# 467410: done 587 games, mean reward -20.710, speed 22.84 f/s
# 468172: done 588 games, mean reward -20.730, speed 24.22 f/s
# 468934: done 589 games, mean reward -20.730, speed 24.99 f/s
# 469741: done 590 games, mean reward -20.730, speed 24.74 f/s
# 470606: done 591 games, mean reward -20.720, speed 25.82 f/s
# 471442: done 592 games, mean reward -20.710, speed 26.02 f/s
# 472204: done 593 games, mean reward -20.710, speed 25.93 f/s
# 472963: done 594 games, mean reward -20.710, speed 24.93 f/s
# 473755: done 595 games, mean reward -20.710, speed 24.63 f/s
# 474514: done 596 games, mean reward -20.710, speed 25.48 f/s
# 475273: done 597 games, mean reward -20.710, speed 25.11 f/s
# 476029: done 598 games, mean reward -20.710, speed 24.04 f/s
# 476790: done 599 games, mean reward -20.710, speed 22.90 f/s
# 477565: done 600 games, mean reward -20.710, speed 24.15 f/s
# 478355: done 601 games, mean reward -20.720, speed 25.94 f/s
# 479222: done 602 games, mean reward -20.710, speed 26.92 f/s
# 479979: done 603 games, mean reward -20.710, speed 27.51 f/s
# 480865: done 604 games, mean reward -20.710, speed 26.92 f/s
# 481651: done 605 games, mean reward -20.720, speed 27.99 f/s
# 482411: done 606 games, mean reward -20.720, speed 25.87 f/s
# 483260: done 607 games, mean reward -20.710, speed 26.45 f/s
# 484235: done 608 games, mean reward -20.690, speed 26.15 f/s
# 485064: done 609 games, mean reward -20.680, speed 26.39 f/s
# 485826: done 610 games, mean reward -20.690, speed 27.43 f/s
# 486663: done 611 games, mean reward -20.690, speed 27.38 f/s
# 487572: done 612 games, mean reward -20.670, speed 27.15 f/s
# 488406: done 613 games, mean reward -20.660, speed 26.20 f/s
# 489275: done 614 games, mean reward -20.660, speed 27.41 f/s
# 490211: done 615 games, mean reward -20.640, speed 26.55 f/s
# 491198: done 616 games, mean reward -20.610, speed 26.15 f/s
# 492037: done 617 games, mean reward -20.610, speed 26.37 f/s
# 492795: done 618 games, mean reward -20.610, speed 24.74 f/s
# 493557: done 619 games, mean reward -20.610, speed 27.50 f/s
# 494473: done 620 games, mean reward -20.590, speed 27.61 f/s
# 495229: done 621 games, mean reward -20.600, speed 27.25 f/s
# 495990: done 622 games, mean reward -20.600, speed 27.66 f/s
# 496753: done 623 games, mean reward -20.600, speed 23.98 f/s
# 497617: done 624 games, mean reward -20.590, speed 25.95 f/s
# 498448: done 625 games, mean reward -20.580, speed 27.32 f/s
# 499313: done 626 games, mean reward -20.570, speed 27.03 f/s
# 500132: done 627 games, mean reward -20.570, speed 26.10 f/s
# 501000: done 628 games, mean reward -20.560, speed 24.03 f/s
# 501829: done 629 games, mean reward -20.560, speed 26.74 f/s
# 502591: done 630 games, mean reward -20.560, speed 26.59 f/s
# 503350: done 631 games, mean reward -20.560, speed 27.16 f/s
# 504180: done 632 games, mean reward -20.550, speed 27.91 f/s
# 504959: done 633 games, mean reward -20.550, speed 27.20 f/s
# 505721: done 634 games, mean reward -20.550, speed 28.17 f/s
# 506478: done 635 games, mean reward -20.550, speed 28.06 f/s
# 507236: done 636 games, mean reward -20.550, speed 28.16 f/s
# 507999: done 637 games, mean reward -20.550, speed 27.96 f/s
# 508756: done 638 games, mean reward -20.550, speed 27.23 f/s
# 509518: done 639 games, mean reward -20.560, speed 24.96 f/s
# 510302: done 640 games, mean reward -20.560, speed 25.48 f/s
# 511063: done 641 games, mean reward -20.560, speed 26.23 f/s
# 511853: done 642 games, mean reward -20.560, speed 26.87 f/s
# 512688: done 643 games, mean reward -20.550, speed 26.14 f/s
# 513447: done 644 games, mean reward -20.560, speed 27.53 f/s
# 514222: done 645 games, mean reward -20.560, speed 28.04 f/s
# 515060: done 646 games, mean reward -20.560, speed 27.38 f/s
# 515887: done 647 games, mean reward -20.560, speed 27.76 f/s
# 516646: done 648 games, mean reward -20.570, speed 26.42 f/s
# 517408: done 649 games, mean reward -20.570, speed 27.37 f/s
# 518242: done 650 games, mean reward -20.570, speed 23.90 f/s
# 519103: done 651 games, mean reward -20.560, speed 24.89 f/s
# 519912: done 652 games, mean reward -20.560, speed 24.64 f/s
# 520748: done 653 games, mean reward -20.550, speed 27.68 f/s
# 521614: done 654 games, mean reward -20.540, speed 24.81 f/s
# 522371: done 655 games, mean reward -20.540, speed 23.63 f/s
# 523128: done 656 games, mean reward -20.540, speed 26.45 f/s
# 523904: done 657 games, mean reward -20.540, speed 27.79 f/s
# 524745: done 658 games, mean reward -20.540, speed 27.44 f/s
# 525604: done 659 games, mean reward -20.540, speed 28.07 f/s
# 526444: done 660 games, mean reward -20.530, speed 28.20 f/s
# 527205: done 661 games, mean reward -20.540, speed 28.07 f/s
# 527993: done 662 games, mean reward -20.550, speed 27.74 f/s
# 528755: done 663 games, mean reward -20.550, speed 27.62 f/s
# 529513: done 664 games, mean reward -20.550, speed 28.07 f/s
# 530276: done 665 games, mean reward -20.550, speed 28.10 f/s
# 531110: done 666 games, mean reward -20.540, speed 27.46 f/s
# 531866: done 667 games, mean reward -20.540, speed 27.44 f/s
# 532806: done 668 games, mean reward -20.530, speed 24.91 f/s
# 533567: done 669 games, mean reward -20.540, speed 24.17 f/s
# 534408: done 670 games, mean reward -20.530, speed 24.03 f/s
# 535187: done 671 games, mean reward -20.530, speed 25.58 f/s
# 535965: done 672 games, mean reward -20.540, speed 26.56 f/s
# 536807: done 673 games, mean reward -20.530, speed 25.42 f/s
# 537647: done 674 games, mean reward -20.520, speed 26.18 f/s
# 538511: done 675 games, mean reward -20.520, speed 24.96 f/s
# 539347: done 676 games, mean reward -20.520, speed 25.07 f/s
# 540276: done 677 games, mean reward -20.510, speed 25.03 f/s
# 541036: done 678 games, mean reward -20.530, speed 25.05 f/s
# 541796: done 679 games, mean reward -20.540, speed 25.14 f/s
# 542709: done 680 games, mean reward -20.520, speed 24.98 f/s
# 543576: done 681 games, mean reward -20.520, speed 24.96 f/s
# 544354: done 682 games, mean reward -20.520, speed 24.19 f/s
# 545132: done 683 games, mean reward -20.520, speed 24.30 f/s
# 545890: done 684 games, mean reward -20.520, speed 25.11 f/s
# 546725: done 685 games, mean reward -20.510, speed 25.99 f/s
# 547561: done 686 games, mean reward -20.510, speed 26.17 f/s
# 548318: done 687 games, mean reward -20.510, speed 25.13 f/s
# 549076: done 688 games, mean reward -20.510, speed 26.31 f/s
# 549990: done 689 games, mean reward -20.490, speed 26.37 f/s
# 550934: done 690 games, mean reward -20.470, speed 26.34 f/s
# 551691: done 691 games, mean reward -20.480, speed 26.20 f/s
# 552452: done 692 games, mean reward -20.490, speed 26.26 f/s
# 553208: done 693 games, mean reward -20.490, speed 26.17 f/s
# 553964: done 694 games, mean reward -20.490, speed 25.31 f/s
# 554925: done 695 games, mean reward -20.470, speed 25.66 f/s
# 555681: done 696 games, mean reward -20.470, speed 26.24 f/s
# 556462: done 697 games, mean reward -20.470, speed 26.02 f/s
# 557219: done 698 games, mean reward -20.470, speed 25.34 f/s
# 557981: done 699 games, mean reward -20.470, speed 26.27 f/s
# 558738: done 700 games, mean reward -20.470, speed 25.56 f/s
# 559498: done 701 games, mean reward -20.470, speed 25.33 f/s
# 560255: done 702 games, mean reward -20.480, speed 25.70 f/s
# 561014: done 703 games, mean reward -20.480, speed 26.08 f/s
# 561823: done 704 games, mean reward -20.490, speed 26.26 f/s
# 562601: done 705 games, mean reward -20.490, speed 25.49 f/s
# 563587: done 706 games, mean reward -20.470, speed 25.67 f/s
# 564526: done 707 games, mean reward -20.470, speed 26.37 f/s
# 565361: done 708 games, mean reward -20.480, speed 26.22 f/s
# 566194: done 709 games, mean reward -20.480, speed 26.26 f/s
# 566971: done 710 games, mean reward -20.480, speed 26.07 f/s
# 567729: done 711 games, mean reward -20.490, speed 26.62 f/s
# 568515: done 712 games, mean reward -20.510, speed 26.27 f/s
# 569290: done 713 games, mean reward -20.520, speed 26.16 f/s
# 570052: done 714 games, mean reward -20.530, speed 26.44 f/s
# 570891: done 715 games, mean reward -20.540, speed 26.19 f/s
# 571799: done 716 games, mean reward -20.550, speed 26.37 f/s
# 572555: done 717 games, mean reward -20.560, speed 26.32 f/s
# 573391: done 718 games, mean reward -20.550, speed 25.55 f/s
# 574167: done 719 games, mean reward -20.550, speed 26.31 f/s
# 574989: done 720 games, mean reward -20.570, speed 26.12 f/s
# 575751: done 721 games, mean reward -20.570, speed 25.90 f/s
# 576585: done 722 games, mean reward -20.560, speed 26.19 f/s
# 577348: done 723 games, mean reward -20.560, speed 24.61 f/s
# 578124: done 724 games, mean reward -20.570, speed 24.95 f/s
# 578886: done 725 games, mean reward -20.580, speed 26.28 f/s
# 579662: done 726 games, mean reward -20.590, speed 26.13 f/s
# 580498: done 727 games, mean reward -20.580, speed 26.27 f/s
# 581338: done 728 games, mean reward -20.580, speed 26.40 f/s
# 582099: done 729 games, mean reward -20.590, speed 25.48 f/s
# 582933: done 730 games, mean reward -20.580, speed 26.15 f/s
# 583773: done 731 games, mean reward -20.570, speed 26.26 f/s
# 584536: done 732 games, mean reward -20.580, speed 25.72 f/s
# 585448: done 733 games, mean reward -20.560, speed 25.64 f/s
# 586278: done 734 games, mean reward -20.550, speed 24.93 f/s
# 587065: done 735 games, mean reward -20.550, speed 24.45 f/s
# 587844: done 736 games, mean reward -20.550, speed 22.46 f/s
# 588678: done 737 games, mean reward -20.540, speed 22.65 f/s
# 589542: done 738 games, mean reward -20.530, speed 25.20 f/s
# 590300: done 739 games, mean reward -20.530, speed 25.58 f/s
# 591086: done 740 games, mean reward -20.530, speed 22.60 f/s
# 591844: done 741 games, mean reward -20.530, speed 22.55 f/s
# 592603: done 742 games, mean reward -20.530, speed 22.54 f/s
# 593366: done 743 games, mean reward -20.540, speed 23.36 f/s
# 594234: done 744 games, mean reward -20.530, speed 26.12 f/s
# 594996: done 745 games, mean reward -20.530, speed 26.14 f/s
# 595832: done 746 games, mean reward -20.530, speed 25.75 f/s
# 596672: done 747 games, mean reward -20.520, speed 26.25 f/s
# 597448: done 748 games, mean reward -20.520, speed 26.11 f/s
# 598205: done 749 games, mean reward -20.520, speed 26.19 f/s
# 598961: done 750 games, mean reward -20.530, speed 26.14 f/s
# 599797: done 751 games, mean reward -20.530, speed 26.06 f/s
# 600556: done 752 games, mean reward -20.530, speed 26.09 f/s
# 601333: done 753 games, mean reward -20.540, speed 26.20 f/s
# 602192: done 754 games, mean reward -20.540, speed 26.58 f/s
# 603087: done 755 games, mean reward -20.530, speed 25.46 f/s
# 603864: done 756 games, mean reward -20.530, speed 28.19 f/s
# 604625: done 757 games, mean reward -20.530, speed 28.25 f/s
# 605381: done 758 games, mean reward -20.540, speed 28.39 f/s
# 606212: done 759 games, mean reward -20.540, speed 28.50 f/s
# 606988: done 760 games, mean reward -20.550, speed 28.65 f/s
# 607747: done 761 games, mean reward -20.550, speed 28.52 f/s
# 608583: done 762 games, mean reward -20.540, speed 26.84 f/s
# 609393: done 763 games, mean reward -20.540, speed 27.85 f/s
# 610196: done 764 games, mean reward -20.540, speed 28.07 f/s
# 610975: done 765 games, mean reward -20.540, speed 28.16 f/s
# 611969: done 766 games, mean reward -20.520, speed 28.10 f/s
# 612804: done 767 games, mean reward -20.510, speed 27.98 f/s
# 613565: done 768 games, mean reward -20.530, speed 28.35 f/s
# 614402: done 769 games, mean reward -20.530, speed 28.31 f/s
# 615184: done 770 games, mean reward -20.540, speed 28.02 f/s
# 615940: done 771 games, mean reward -20.540, speed 27.96 f/s
# 616716: done 772 games, mean reward -20.540, speed 28.40 f/s
# 617491: done 773 games, mean reward -20.550, speed 27.95 f/s
# 618254: done 774 games, mean reward -20.560, speed 27.76 f/s
# 619012: done 775 games, mean reward -20.560, speed 27.89 f/s
# 619843: done 776 games, mean reward -20.560, speed 28.31 f/s
# 620633: done 777 games, mean reward -20.570, speed 28.19 f/s
# 621533: done 778 games, mean reward -20.560, speed 27.89 f/s
# 622292: done 779 games, mean reward -20.560, speed 28.18 f/s
# 623053: done 780 games, mean reward -20.580, speed 28.07 f/s
# 623813: done 781 games, mean reward -20.590, speed 27.18 f/s
# 624651: done 782 games, mean reward -20.580, speed 27.74 f/s
# 625409: done 783 games, mean reward -20.580, speed 27.74 f/s
# 626188: done 784 games, mean reward -20.580, speed 28.34 f/s
# 626949: done 785 games, mean reward -20.590, speed 28.08 f/s
# 627908: done 786 games, mean reward -20.580, speed 26.45 f/s
# 628712: done 787 games, mean reward -20.580, speed 26.80 f/s
# 629487: done 788 games, mean reward -20.580, speed 24.71 f/s
# 630249: done 789 games, mean reward -20.600, speed 26.80 f/s
# 631025: done 790 games, mean reward -20.620, speed 26.00 f/s
# 631862: done 791 games, mean reward -20.610, speed 27.45 f/s
# 632623: done 792 games, mean reward -20.610, speed 27.69 f/s
# 633489: done 793 games, mean reward -20.600, speed 26.45 f/s
# 634252: done 794 games, mean reward -20.600, speed 27.39 f/s
# 635015: done 795 games, mean reward -20.620, speed 27.27 f/s
# 635791: done 796 games, mean reward -20.620, speed 27.56 f/s
# 636572: done 797 games, mean reward -20.620, speed 27.65 f/s
# 637360: done 798 games, mean reward -20.620, speed 27.39 f/s
# 638122: done 799 games, mean reward -20.620, speed 26.61 f/s
# 638880: done 800 games, mean reward -20.620, speed 26.94 f/s
# 639638: done 801 games, mean reward -20.620, speed 27.21 f/s
# 640427: done 802 games, mean reward -20.620, speed 26.87 f/s
# 641204: done 803 games, mean reward -20.620, speed 25.73 f/s
# 641982: done 804 games, mean reward -20.620, speed 25.75 f/s
# 642741: done 805 games, mean reward -20.620, speed 26.71 f/s
# 643499: done 806 games, mean reward -20.640, speed 26.29 f/s
# 644279: done 807 games, mean reward -20.650, speed 27.77 f/s
# 645120: done 808 games, mean reward -20.650, speed 27.62 f/s
# 645960: done 809 games, mean reward -20.650, speed 28.26 f/s
# 646721: done 810 games, mean reward -20.650, speed 28.05 f/s
# 647480: done 811 games, mean reward -20.650, speed 28.01 f/s
# 648288: done 812 games, mean reward -20.650, speed 27.95 f/s
# 649116: done 813 games, mean reward -20.650, speed 27.52 f/s
# 649878: done 814 games, mean reward -20.650, speed 27.87 f/s
# 650638: done 815 games, mean reward -20.660, speed 27.36 f/s
# 651473: done 816 games, mean reward -20.670, speed 28.06 f/s
# 652361: done 817 games, mean reward -20.660, speed 27.71 f/s
# 653202: done 818 games, mean reward -20.660, speed 28.22 f/s
# 653960: done 819 games, mean reward -20.660, speed 27.88 f/s
# 654737: done 820 games, mean reward -20.660, speed 27.87 f/s
# 655576: done 821 games, mean reward -20.650, speed 28.17 f/s
# 656414: done 822 games, mean reward -20.650, speed 28.27 f/s
# 657224: done 823 games, mean reward -20.650, speed 28.11 f/s
