# %%
#!/usr/bin/env python3
import gym
import ptan
import argparse
from tensorboardX import SummaryWriter

import torch
import torch.nn.utils as nn_utils
import torch.nn.functional as F
import torch.optim as optim
import torch.multiprocessing as mp

from lib import common

# %%
GAMMA = 0.99
LEARNING_RATE = 0.001
ENTROPY_BETA = 0.01

REWARD_STEPS = 4
CLIP_GRAD = 0.1

PROCESSES_COUNT = 4
NUM_ENVS = 15

#BATCH_SIZE changed to GRAD_BATCH and TRAIN_BATCH, GRAD_BATCH is the batch size for sub-process to determine gradient from
#the loss
#TRAIN_BATCH defined using how many subprocess gradient batch to combine to calculate SGD loss. Therefore, for each
#optimization step, we use TRAIN_BATCH * BATCH_SIZE samples for training. Calculating loss and back-propagation has a heavy
#workload, therefore we can use a larger GRAD_BATCH for higher efficiency, we need a smaller TRAIN_BATCH value to let the
#network keep it as on-policy.
GRAD_BATCH = 64
TRAIN_BATCH = 2
ENV_NAME = "PongNoFrameskip-v4"
NAME = 'pong'
REWARD_BOUND = 18

# %%
def make_env():
    return ptan.common.wrappers.wrap_dqn(gym.make(ENV_NAME))

#code in sub-process becomes much complicated, but main process code becomes easier. We send the code below to function:
# proc_name:  used for creating TensorBoard output environment, every subprocess will output to its own TensorBoard dataset
# net: shared neural network
# device: device for calculation(cuda / cpu)
# train_queue: a queue for transfering the calculated gradient to main process.
#The code in our sub-process is similar to the code for main progress in data parallelization version, this is because we
#put the mission into the sub-process instead of main process. But we need the optimizer to collect gradient instead of
#renewing the network, then add the gradient to the queue, other code are almost the same as before.
def grads_func(proc_name, net, device, train_queue):
    envs = [make_env() for _ in range(NUM_ENVS)]
    
    agent = ptan.agent.PolicyAgent(lambda x: net(x)[0], device=device, apply_softmax=True)
    exp_source = ptan.experience.ExperienceSourceFirstLast(envs, agent, gamma=GAMMA, steps_count=REWARD_STEPS)
    
    batch = []
    frame_idx = 0
    writer = SummaryWriter(comment=proc_name)
    
    #we collect batch transfer and get the reward when episode ends.
    with common.RewardTracker(writer, stop_reward=REWARD_BOUND) as tracker:
        with ptan.common.utils.TBMeanTracker(writer, batch_size=100) as tb_tracker:
            for exp in exp_source:
                frame_idx += 1
                new_rewards = exp_source.pop_total_rewards()
                if new_rewards and tracker.reward(new_rewards[0], frame_idx):
                    break
                    
                batch.append(exp)
                if len(batch) < GRAD_BATCH:
                    continue
                
                #we use training data to calculate loss, and do back-propagation, then we store the network parameters
                #gradient into Tensor.grad, this can done without synchronize with other workers, because our network
                #parameters are shared with each other, but gradient are set and keeping by each individual sub-process
                states_v, actions_t, vals_ref_v = \
                common.unpack_batch(batch, net, last_val_gamma=GAMMA**REWARD_STEPS, device=device)
                batch.clear()
                
                net.zero_grad()
                logits_v, value_v = net(states_v)
                loss_value_v = F.mse_loss(value_v.squeeze(-1), vals_ref_v)
                
                log_prob_v = F.log_softmax(logits_v, dim=1)
                adv_v = vals_ref_v - value_v.squeeze(-1).detach()
                log_prob_actions_v = adv_v * log_prob_v[range(GRAD_BATCH), actions_t]
                loss_policy_v = -log_prob_actions_v.mean()
                
                prob_v = F.softmax(logits_v, dim=1)
                entropy_loss_v = ENTROPY_BETA * (prob_v * log_prob_v).sum(dim=1).mean()
                loss_v = entropy_loss_v + loss_value_v + loss_policy_v
                loss_v.backward()
                
                #we send the value to TensorBoard in training.
                tb_tracker.track("advantage", adv_v.cpu().numpy(), frame_idx)
                tb_tracker.track("values", value_v.cpu().detach().numpy(), frame_idx)
                tb_tracker.track("batch_rewards", vals_ref_v.cpu().numpy(), frame_idx)
                tb_tracker.track("loss_entropy", entropy_loss_v.cpu().detach().numpy(), frame_idx)
                tb_tracker.track("loss_policy", loss_policy_v.cpu().detach().numpy(), frame_idx)
                tb_tracker.track("loss_value", loss_value_v.cpu().detach().numpy(), frame_idx)
                tb_tracker.track("loss_total", loss_v.cpu().detach().numpy(), frame_idx)
                
                #we clip gradient when loop ends, and put the gradient into a buffer to avoid the value being destroyed
                #in the next iteration.
                nn_utils.clip_grad_norm_(net.parameters(), CLIP_GRAD)
                grads = [param.grad.data.cpu().numpy() if param.grad is not None else None for param in net.parameters()]
                train_queue.put(grads)
        
        #we put None into the queue to indicate the sub-process has reached "game-solved" state, we should stop training.
        train_queue.put(None)

# %%
if __name__ == "__main__":
    #create network and share weighting in main process
    mp.set_start_method('spawn')
    parser = argparse.ArgumentParser()
    parser.add_argument("--cuda", default=True, action="store_true", help="Enable cuda")
    parser.add_argument("-n", "--name", default="final", required=False, help="Name of the run")
    args, unknown = parser.parse_known_args()
    device = "cuda" if args.cuda else "cpu"
    env = make_env()
    net = common.AtariA2C(env.observation_space.shape, env.action_space.n).to(device)
    net.share_memory()
    
    #create data transfer queue and create sub-process
    optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE, eps=1e-3)
    
    train_queue = mp.Queue(maxsize=PROCESSES_COUNT)
    data_proc_list = []
    for proc_idx in range(PROCESSES_COUNT):
        proc_name = "-a3c-grad_" + NAME + "_" + args.name + "#%d" % proc_idx
        data_proc = mp.Process(target=grads_func, args=(proc_name, net, device, train_queue))
        data_proc.start()
        data_proc_list.append(data_proc)
    
    #Main difference between data parallelization and gradient parallelization version is in the training loop, the training
    #loop here is much simplier, it is because sub-process finished all calculation for us.We need to process the situation:
    #when one sub-process reached the required mean-reward, it need to stop training, therefore, we exit the loop when
    #reaching the required reward.
    batch = []
    step_idx = 0
    grad_buffer = None
    
    try:
        while True:
            train_entry = train_queue.get()
            if train_entry is None:
                break
            
            #to balance the gradient from different sub-process, for every TRAIN_BATCH gradient, we call optimizer step()
            #function, for the step between, we add the gradient together.
            step_idx += 1
            
            if grad_buffer is None:
                grad_buffer = train_entry
            else:
                for tgt_grad, grad in zip(grad_buffer, train_entry):
                    tgt_grad += grad
            
            #if we get enough data with TRAIN_BATCH, we change the total gradient type to Pytorch FloatTensor, and change
            #the network parameter grad to this total gradient value. Then we call optimizer step(), to accumulate gradient
            #and renew network parameters
            if step_idx % TRAIN_BATCH == 0:
                for param, grad in zip(net.parameters(), grad_buffer):
                    grad_v = torch.FloatTensor(grad).to(device)
                    param.grad = grad_v
                    
                nn_utils.clip_grad_norm_(net.parameters(), CLIP_GRAD)
                optimizer.step()
                grad_buffer = None
    
    #when exiting loop, such as Ctrl + C, we need to stop all sub-process to prevent zombie process occupying our GPU
    #resources.
    finally:
        for p in data_proc_list:
            p.terminate()
            p.join()

# %% [markdown]
# # There are 4 sub-process running together, convergence should start at 800000 frames, which is at the point of total 3200000 frames. But code above won't converge even to 1600000 frames, which is total 6400000 frames.

# %%
import sys
f = open('C:/Users/Kelvin/Desktop/reinforcement learning/Chapter 11/a3c_grad_output.txt', 'r')
file_contents = f.read()
print (file_contents)
f.close()
# Out:
# (reinforcement) C:\Users\Kelvin\Desktop\reinforcement learning\Chapter 11>python .\a3c_grad.py.py --cuda -n final
# 11273: done 1 games, mean reward -21.000, speed 53.89 f/s
# 11285: done 1 games, mean reward -21.000, speed 53.96 f/s
# 11316: done 2 games, mean reward -21.000, speed 45.88 f/s
# 11543: done 1 games, mean reward -21.000, speed 53.81 f/s
# 11543: done 1 games, mean reward -21.000, speed 53.72 f/s
# 11717: done 2 games, mean reward -21.000, speed 50.63 f/s
# 11752: done 2 games, mean reward -21.000, speed 57.42 f/s
# 12193: done 3 games, mean reward -21.000, speed 53.26 f/s
# 12429: done 3 games, mean reward -20.667, speed 53.44 f/s
# 12447: done 4 games, mean reward -21.000, speed 54.20 f/s
# 12459: done 3 games, mean reward -21.000, speed 56.35 f/s
# 12460: done 2 games, mean reward -21.000, speed 53.08 f/s
# 12507: done 4 games, mean reward -20.750, speed 60.16 f/s
# 12624: done 5 games, mean reward -21.000, speed 52.46 f/s
# 12642: done 3 games, mean reward -21.000, speed 53.44 f/s
# 12852: done 4 games, mean reward -20.750, speed 55.91 f/s
# 12859: done 5 games, mean reward -20.600, speed 64.01 f/s
# 13165: done 4 games, mean reward -21.000, speed 55.34 f/s
# 13307: done 6 games, mean reward -20.833, speed 56.64 f/s
# 13330: done 6 games, mean reward -20.500, speed 51.90 f/s
# 13568: done 5 games, mean reward -21.000, speed 56.33 f/s
# 13591: done 6 games, mean reward -20.833, speed 24.54 f/s
# 13599: done 7 games, mean reward -20.429, speed 56.46 f/s
# 13621: done 5 games, mean reward -20.600, speed 55.45 f/s
# 13807: done 7 games, mean reward -20.571, speed 53.79 f/s
# 13823: done 6 games, mean reward -20.667, speed 55.98 f/s
# 13958: done 7 games, mean reward -20.714, speed 43.87 f/s
# 14163: done 7 games, mean reward -20.571, speed 54.57 f/s
# 14258: done 8 games, mean reward -20.625, speed 66.83 f/s
# 14279: done 9 games, mean reward -20.667, speed 24.01 f/s
# 14289: done 8 games, mean reward -20.625, speed 52.56 f/s
# 14399: done 9 games, mean reward -20.667, speed 74.91 f/s
# 14491: done 10 games, mean reward -20.700, speed 43.63 f/s
# 14501: done 8 games, mean reward -20.625, speed 56.34 f/s
# 14632: done 9 games, mean reward -20.444, speed 55.91 f/s
# 14675: done 8 games, mean reward -20.375, speed 54.24 f/s
# 14695: done 10 games, mean reward -20.300, speed 53.77 f/s
# 14730: done 10 games, mean reward -20.600, speed 54.99 f/s
# 14800: done 11 games, mean reward -20.273, speed 47.67 f/s
# 14828: done 9 games, mean reward -20.444, speed 60.46 f/s
# 14853: done 10 games, mean reward -20.400, speed 28.08 f/s
# 14889: done 11 games, mean reward -20.727, speed 56.12 f/s
# 15022: done 12 games, mean reward -20.250, speed 59.71 f/s
# 15027: done 11 games, mean reward -20.545, speed 59.79 f/s
# 15096: done 12 games, mean reward -20.583, speed 56.63 f/s
# 15587: done 13 games, mean reward -20.308, speed 54.14 f/s
# 15691: done 13 games, mean reward -20.615, speed 52.18 f/s
# 15699: done 11 games, mean reward -20.364, speed 55.15 f/s
# 15970: done 12 games, mean reward -20.500, speed 54.00 f/s
# 15971: done 14 games, mean reward -20.643, speed 57.82 f/s
# 16125: done 12 games, mean reward -20.167, speed 58.77 f/s
# 16222: done 13 games, mean reward -20.000, speed 44.04 f/s
# 16394: done 15 games, mean reward -20.467, speed 52.78 f/s
# 16511: done 14 games, mean reward -20.143, speed 55.64 f/s
# 16797: done 13 games, mean reward -20.385, speed 54.41 f/s
# 16884: done 14 games, mean reward -20.214, speed 59.25 f/s
# 16899: done 15 games, mean reward -20.133, speed 48.80 f/s
# 17022: done 15 games, mean reward -20.200, speed 57.74 f/s
# 17280: done 14 games, mean reward -19.857, speed 55.24 f/s
# 17516: done 15 games, mean reward -19.733, speed 51.92 f/s
# 23631: done 16 games, mean reward -20.188, speed 54.60 f/s
# 23883: done 16 games, mean reward -20.500, speed 54.48 f/s
# 24040: done 16 games, mean reward -20.250, speed 54.42 f/s
# 24234: done 17 games, mean reward -20.529, speed 57.91 f/s
# 25175: done 16 games, mean reward -19.812, speed 54.46 f/s
# 25529: done 18 games, mean reward -20.556, speed 55.01 f/s
# 25539: done 17 games, mean reward -20.118, speed 54.41 f/s
# 25865: done 18 games, mean reward -20.167, speed 55.06 f/s
# 25899: done 17 games, mean reward -19.882, speed 55.64 f/s
# 25992: done 19 games, mean reward -20.211, speed 54.56 f/s
# 26075: done 17 games, mean reward -20.235, speed 54.39 f/s
# 26094: done 18 games, mean reward -20.278, speed 101.36 f/s
# 26216: done 18 games, mean reward -19.889, speed 53.97 f/s
# 26369: done 19 games, mean reward -19.895, speed 47.09 f/s
# 26520: done 19 games, mean reward -20.316, speed 53.47 f/s
# 26529: done 20 games, mean reward -20.350, speed 64.01 f/s
# 26600: done 19 games, mean reward -20.579, speed 54.15 f/s
# 26678: done 20 games, mean reward -20.250, speed 57.03 f/s
# 26799: done 20 games, mean reward -20.600, speed 55.63 f/s
# 26815: done 21 games, mean reward -20.333, speed 59.44 f/s
# 26810: done 21 games, mean reward -20.571, speed 70.42 f/s
# 26840: done 22 games, mean reward -20.545, speed 32.55 f/s
# 26880: done 22 games, mean reward -20.364, speed 52.67 f/s
# 26889: done 23 games, mean reward -20.522, speed 46.13 f/s
# 27320: done 20 games, mean reward -19.900, speed 56.84 f/s
# 27365: done 21 games, mean reward -20.286, speed 53.83 f/s
# 27677: done 22 games, mean reward -20.318, speed 53.55 f/s
# 27774: done 23 games, mean reward -20.348, speed 68.24 f/s
# 28183: done 23 games, mean reward -20.348, speed 53.61 f/s
# 28419: done 24 games, mean reward -20.333, speed 51.87 f/s
# 28422: done 21 games, mean reward -19.905, speed 53.04 f/s
# 28463: done 24 games, mean reward -20.375, speed 57.82 f/s
# 28607: done 25 games, mean reward -20.360, speed 54.22 f/s
# 28617: done 24 games, mean reward -20.500, speed 54.41 f/s
# 28657: done 26 games, mean reward -20.385, speed 45.72 f/s
# 28653: done 25 games, mean reward -20.480, speed 109.74 f/s
# 28747: done 25 games, mean reward -20.360, speed 52.10 f/s
# 28995: done 26 games, mean reward -20.346, speed 52.40 f/s
# 29001: done 22 games, mean reward -19.909, speed 52.43 f/s
# 29071: done 26 games, mean reward -20.462, speed 50.87 f/s
# 29313: done 27 games, mean reward -20.296, speed 54.18 f/s
# 29589: done 27 games, mean reward -20.481, speed 54.87 f/s
# 29600: done 23 games, mean reward -19.870, speed 55.71 f/s
# 29729: done 24 games, mean reward -19.833, speed 55.42 f/s
# 29853: done 27 games, mean reward -20.333, speed 53.41 f/s
# 30173: done 25 games, mean reward -19.840, speed 54.14 f/s
# 30209: done 28 games, mean reward -20.321, speed 52.03 f/s
# 30492: done 29 games, mean reward -20.345, speed 58.06 f/s
# 30939: done 28 games, mean reward -20.286, speed 55.11 f/s
# 30958: done 26 games, mean reward -19.846, speed 55.47 f/s
# 31138: done 27 games, mean reward -19.889, speed 49.88 f/s
# 31587: done 29 games, mean reward -20.207, speed 54.44 f/s
# 31651: done 28 games, mean reward -19.893, speed 54.64 f/s
# 31916: done 28 games, mean reward -20.429, speed 54.75 f/s
# 32548: done 29 games, mean reward -20.379, speed 54.09 f/s
# 32591: done 30 games, mean reward -20.300, speed 42.35 f/s
# 33414: done 30 games, mean reward -20.200, speed 54.12 f/s
# 33533: done 29 games, mean reward -19.862, speed 55.16 f/s
# 33731: done 30 games, mean reward -19.867, speed 46.26 f/s
# 34077: done 30 games, mean reward -20.267, speed 54.49 f/s
# 35890: done 31 games, mean reward -20.290, speed 54.46 f/s
# 36891: done 31 games, mean reward -20.226, speed 54.50 f/s
# 37263: done 31 games, mean reward -20.323, speed 54.42 f/s
# 37359: done 32 games, mean reward -20.250, speed 56.53 f/s
# 38006: done 31 games, mean reward -19.903, speed 54.75 f/s
# 38139: done 32 games, mean reward -20.312, speed 56.36 f/s
# 38689: done 33 games, mean reward -20.333, speed 53.02 f/s
# 39005: done 33 games, mean reward -20.273, speed 54.17 f/s
# 39081: done 32 games, mean reward -20.312, speed 54.53 f/s
# 39205: done 32 games, mean reward -19.906, speed 54.13 f/s
# 39249: done 33 games, mean reward -19.879, speed 42.04 f/s
# 39749: done 34 games, mean reward -20.324, speed 53.81 f/s
# 39817: done 34 games, mean reward -20.294, speed 53.81 f/s
# 39946: done 35 games, mean reward -20.286, speed 55.31 f/s
# 40395: done 35 games, mean reward -20.314, speed 54.65 f/s
# 40466: done 33 games, mean reward -20.333, speed 54.06 f/s
# 40495: done 36 games, mean reward -20.306, speed 56.87 f/s
# 40569: done 34 games, mean reward -20.353, speed 69.41 f/s
# 40580: done 36 games, mean reward -20.333, speed 53.83 f/s
# 40831: done 35 games, mean reward -20.343, speed 56.47 f/s
# 40875: done 36 games, mean reward -20.361, speed 39.67 f/s
# 40905: done 37 games, mean reward -20.351, speed 55.19 f/s
# 40951: done 34 games, mean reward -19.912, speed 55.48 f/s
# 40973: done 38 games, mean reward -20.368, speed 49.47 f/s
# 40990: done 39 games, mean reward -20.385, speed 83.71 f/s
# 41035: done 37 games, mean reward -20.378, speed 46.77 f/s
# 41152: done 38 games, mean reward -20.395, speed 74.90 f/s
# 41170: done 35 games, mean reward -19.943, speed 47.36 f/s
# 41241: done 36 games, mean reward -19.944, speed 59.03 f/s
# 41354: done 37 games, mean reward -19.973, speed 50.23 f/s
# 41681: done 39 games, mean reward -20.359, speed 51.78 f/s
# 41685: done 37 games, mean reward -20.270, speed 53.46 f/s
# 41729: done 40 games, mean reward -20.400, speed 53.03 f/s
# 41800: done 40 games, mean reward -20.350, speed 48.83 f/s
# 42044: done 38 games, mean reward -20.000, speed 56.41 f/s
# 42209: done 38 games, mean reward -20.289, speed 54.72 f/s
# 42261: done 41 games, mean reward -20.341, speed 55.79 f/s
# 42482: done 41 games, mean reward -20.415, speed 56.98 f/s
# 42831: done 39 games, mean reward -20.308, speed 53.59 f/s
# 42833: done 39 games, mean reward -20.000, speed 52.89 f/s
# 42872: done 40 games, mean reward -20.300, speed 116.06 f/s
# 43421: done 40 games, mean reward -20.025, speed 55.39 f/s
# 43469: done 41 games, mean reward -20.293, speed 52.64 f/s
# 43558: done 42 games, mean reward -20.357, speed 54.96 f/s
# 44044: done 43 games, mean reward -20.349, speed 52.82 f/s
# 44248: done 42 games, mean reward -20.381, speed 54.10 f/s
# 44487: done 42 games, mean reward -20.262, speed 53.90 f/s
# 44784: done 41 games, mean reward -20.024, speed 54.70 f/s
# 44865: done 42 games, mean reward -20.048, speed 39.58 f/s
# 44917: done 43 games, mean reward -20.279, speed 58.69 f/s
# 45060: done 43 games, mean reward -20.070, speed 55.23 f/s
# 45086: done 43 games, mean reward -20.395, speed 54.19 f/s
# 45267: done 44 games, mean reward -20.341, speed 54.48 f/s
# 45968: done 44 games, mean reward -20.091, speed 55.10 f/s
# 47127: done 44 games, mean reward -20.273, speed 54.12 f/s
# 47517: done 45 games, mean reward -20.333, speed 54.76 f/s
# 47890: done 44 games, mean reward -20.364, speed 54.46 f/s
# 48071: done 45 games, mean reward -20.111, speed 54.43 f/s
# 50324: done 45 games, mean reward -20.244, speed 54.60 f/s
# 51920: done 46 games, mean reward -20.130, speed 54.74 f/s
# 52004: done 45 games, mean reward -20.378, speed 54.79 f/s
# 52048: done 46 games, mean reward -20.391, speed 42.04 f/s
# 52064: done 47 games, mean reward -20.362, speed 85.35 f/s
# 52212: done 47 games, mean reward -20.106, speed 57.52 f/s
# 52752: done 48 games, mean reward -20.292, speed 52.75 f/s
# 52778: done 46 games, mean reward -20.239, speed 54.51 f/s
# 52796: done 49 games, mean reward -20.286, speed 108.33 f/s
# 52853: done 50 games, mean reward -20.280, speed 53.66 f/s
# 53128: done 47 games, mean reward -20.255, speed 51.15 f/s
# 53255: done 46 games, mean reward -20.326, speed 54.32 f/s
# 53299: done 48 games, mean reward -20.250, speed 65.94 f/s
# 53350: done 51 games, mean reward -20.294, speed 54.11 f/s
# 53405: done 47 games, mean reward -20.340, speed 60.39 f/s
# 53535: done 48 games, mean reward -20.104, speed 53.67 f/s
# 53535: done 52 games, mean reward -20.308, speed 53.11 f/s
# 53666: done 49 games, mean reward -20.122, speed 54.81 f/s
# 53860: done 50 games, mean reward -20.140, speed 55.20 f/s
# 53922: done 49 games, mean reward -20.265, speed 53.75 f/s
# 54280: done 50 games, mean reward -20.280, speed 52.08 f/s
# 54329: done 48 games, mean reward -20.333, speed 55.54 f/s
# 54370: done 51 games, mean reward -20.294, speed 65.47 f/s
# 54394: done 49 games, mean reward -20.327, speed 53.35 f/s
# 54404: done 50 games, mean reward -20.320, speed 13.34 f/s
# 54452: done 51 games, mean reward -20.275, speed 113.80 f/s
# 54538: done 52 games, mean reward -20.308, speed 50.02 f/s
# 54557: done 52 games, mean reward -20.288, speed 50.16 f/s
# 54680: done 53 games, mean reward -20.321, speed 59.41 f/s
# 54720: done 53 games, mean reward -20.302, speed 62.86 f/s
# 54857: done 54 games, mean reward -20.278, speed 43.63 f/s
# 54863: done 53 games, mean reward -20.321, speed 54.18 f/s
# 54965: done 51 games, mean reward -20.157, speed 54.79 f/s
# 55332: done 55 games, mean reward -20.291, speed 55.69 f/s
# 55541: done 54 games, mean reward -20.278, speed 55.17 f/s
# 55602: done 54 games, mean reward -20.315, speed 55.52 f/s
# 56040: done 52 games, mean reward -20.135, speed 54.02 f/s
# 56051: done 55 games, mean reward -20.327, speed 54.64 f/s
# 56380: done 56 games, mean reward -20.268, speed 55.31 f/s
# 56425: done 53 games, mean reward -20.151, speed 54.65 f/s
# 56610: done 54 games, mean reward -20.130, speed 54.08 f/s
# 56765: done 55 games, mean reward -20.255, speed 54.91 f/s
# 56903: done 56 games, mean reward -20.304, speed 53.00 f/s
# 57269: done 56 games, mean reward -20.250, speed 53.95 f/s
# 57385: done 55 games, mean reward -20.127, speed 54.88 f/s
# 57403: done 56 games, mean reward -20.143, speed 104.75 f/s
# 57453: done 57 games, mean reward -20.281, speed 57.25 f/s
# 57523: done 57 games, mean reward -20.158, speed 53.72 f/s
# 57883: done 57 games, mean reward -20.263, speed 53.90 f/s
# 58480: done 57 games, mean reward -20.263, speed 54.52 f/s
# 58837: done 58 games, mean reward -20.259, speed 53.40 f/s
# 59036: done 58 games, mean reward -20.259, speed 55.08 f/s
# 59431: done 58 games, mean reward -20.155, speed 54.70 f/s
# 59504: done 59 games, mean reward -20.254, speed 55.96 f/s
# 60056: done 59 games, mean reward -20.271, speed 54.59 f/s
# 60071: done 58 games, mean reward -20.259, speed 54.73 f/s
# 60220: done 59 games, mean reward -20.271, speed 59.99 f/s
# 60533: done 59 games, mean reward -20.153, speed 55.11 f/s
# 61131: done 60 games, mean reward -20.283, speed 54.19 f/s
# 61286: done 60 games, mean reward -20.150, speed 53.98 f/s
# 63524: done 60 games, mean reward -20.267, speed 54.78 f/s
# 64280: done 61 games, mean reward -20.164, speed 54.76 f/s
# 64402: done 60 games, mean reward -20.283, speed 54.49 f/s
# 64760: done 61 games, mean reward -20.295, speed 58.91 f/s
# 65482: done 62 games, mean reward -20.306, speed 52.34 f/s
# 65555: done 63 games, mean reward -20.317, speed 57.69 f/s
# 65600: done 64 games, mean reward -20.328, speed 120.03 f/s
# 65607: done 61 games, mean reward -20.279, speed 54.16 f/s
# 65848: done 65 games, mean reward -20.338, speed 55.12 f/s
# 65847: done 62 games, mean reward -20.177, speed 55.27 f/s
# 66151: done 61 games, mean reward -20.295, speed 55.01 f/s
# 66255: done 63 games, mean reward -20.190, speed 51.41 f/s
# 66421: done 66 games, mean reward -20.333, speed 54.50 f/s
# 66686: done 62 games, mean reward -20.306, speed 56.33 f/s
# 66744: done 62 games, mean reward -20.290, speed 56.16 f/s
# 67089: done 64 games, mean reward -20.203, speed 54.76 f/s
# 67118: done 63 games, mean reward -20.317, speed 53.08 f/s
# 67159: done 63 games, mean reward -20.286, speed 51.89 f/s
# 67197: done 64 games, mean reward -20.328, speed 60.20 f/s
# 67261: done 64 games, mean reward -20.281, speed 70.21 f/s
# 67363: done 65 games, mean reward -20.277, speed 48.01 f/s
# 67388: done 67 games, mean reward -20.343, speed 54.78 f/s
# 67542: done 66 games, mean reward -20.288, speed 51.62 f/s
# 67584: done 65 games, mean reward -20.323, speed 55.30 f/s
# 68150: done 66 games, mean reward -20.333, speed 54.08 f/s
# 68320: done 67 games, mean reward -20.328, speed 50.62 f/s
# 68713: done 65 games, mean reward -20.215, speed 55.12 f/s
# 69045: done 68 games, mean reward -20.324, speed 55.52 f/s
# 69176: done 69 games, mean reward -20.333, speed 55.54 f/s
# 69327: done 66 games, mean reward -20.227, speed 53.19 f/s
# 69333: done 67 games, mean reward -20.224, speed 64.01 f/s
# 69474: done 67 games, mean reward -20.284, speed 54.85 f/s
# 69587: done 68 games, mean reward -20.338, speed 53.93 f/s
# 69609: done 69 games, mean reward -20.348, speed 100.59 f/s
# 69653: done 68 games, mean reward -20.235, speed 55.07 f/s
# 69762: done 68 games, mean reward -20.294, speed 51.07 f/s
# 69796: done 70 games, mean reward -20.357, speed 55.42 f/s
# 69869: done 69 games, mean reward -20.290, speed 74.45 f/s
# 70250: done 70 games, mean reward -20.343, speed 54.14 f/s
# 70478: done 69 games, mean reward -20.217, speed 54.33 f/s
# 70481: done 71 games, mean reward -20.352, speed 53.48 f/s
# 70498: done 70 games, mean reward -20.286, speed 53.90 f/s
# 70612: done 71 games, mean reward -20.352, speed 52.91 f/s
# 70781: done 70 games, mean reward -20.229, speed 60.43 f/s
# 71054: done 71 games, mean reward -20.239, speed 49.37 f/s
# 71135: done 71 games, mean reward -20.296, speed 54.37 f/s
# 71280: done 72 games, mean reward -20.333, speed 56.27 f/s
# 71392: done 72 games, mean reward -20.292, speed 55.02 f/s
# 71441: done 73 games, mean reward -20.342, speed 47.94 f/s
# 72100: done 72 games, mean reward -20.347, speed 55.64 f/s
# 72820: done 74 games, mean reward -20.351, speed 56.33 f/s
# 72884: done 73 games, mean reward -20.342, speed 55.33 f/s
# 72940: done 72 games, mean reward -20.236, speed 55.66 f/s
# 73198: done 73 games, mean reward -20.288, speed 55.66 f/s
# 73950: done 73 games, mean reward -20.205, speed 54.69 f/s
# 74320: done 74 games, mean reward -20.216, speed 53.35 f/s
# 74517: done 74 games, mean reward -20.270, speed 54.09 f/s
# 75035: done 74 games, mean reward -20.338, speed 54.44 f/s
# 75387: done 75 games, mean reward -20.333, speed 57.63 f/s
# 76269: done 75 games, mean reward -20.200, speed 55.43 f/s
# 76597: done 75 games, mean reward -20.360, speed 54.87 f/s
# 76908: done 76 games, mean reward -20.368, speed 55.30 f/s
# 78155: done 76 games, mean reward -20.197, speed 54.24 f/s
# 78206: done 75 games, mean reward -20.280, speed 55.25 f/s
# 79065: done 76 games, mean reward -20.250, speed 53.21 f/s
# 79107: done 77 games, mean reward -20.195, speed 54.34 f/s
# 79315: done 76 games, mean reward -20.342, speed 54.55 f/s
# 79425: done 78 games, mean reward -20.205, speed 54.14 f/s
# 79431: done 77 games, mean reward -20.351, speed 51.21 f/s
# 79627: done 77 games, mean reward -20.377, speed 54.18 f/s
# 79833: done 78 games, mean reward -20.346, speed 56.19 f/s
# 80079: done 79 games, mean reward -20.354, speed 55.65 f/s
# 80383: done 80 games, mean reward -20.363, speed 61.00 f/s
# 80564: done 77 games, mean reward -20.247, speed 55.63 f/s
# 80644: done 78 games, mean reward -20.372, speed 54.99 f/s
# 80725: done 78 games, mean reward -20.244, speed 47.94 f/s
# 80759: done 79 games, mean reward -20.367, speed 74.36 f/s
# 81055: done 79 games, mean reward -20.253, speed 56.03 f/s
# 81139: done 80 games, mean reward -20.363, speed 54.54 f/s
# 81793: done 80 games, mean reward -20.238, speed 53.26 f/s
# 81969: done 81 games, mean reward -20.370, speed 54.15 f/s
# 82030: done 81 games, mean reward -20.247, speed 61.92 f/s
# 82377: done 81 games, mean reward -20.370, speed 53.36 f/s
# 82541: done 82 games, mean reward -20.354, speed 64.81 f/s
# 82761: done 82 games, mean reward -20.366, speed 53.09 f/s
# 82763: done 82 games, mean reward -20.232, speed 53.14 f/s
# 82766: done 79 games, mean reward -20.215, speed 54.94 f/s
# 82937: done 83 games, mean reward -20.349, speed 55.59 f/s
# 83188: done 83 games, mean reward -20.229, speed 57.76 f/s
# 83216: done 80 games, mean reward -20.212, speed 54.56 f/s
# 83344: done 83 games, mean reward -20.373, speed 54.80 f/s
# 83402: done 84 games, mean reward -20.381, speed 50.17 f/s
# 83674: done 84 games, mean reward -20.238, speed 52.91 f/s
# 83720: done 81 games, mean reward -20.222, speed 54.13 f/s
# 83759: done 82 games, mean reward -20.232, speed 113.48 f/s
# 83851: done 83 games, mean reward -20.217, speed 45.30 f/s
# 84182: done 84 games, mean reward -20.345, speed 53.63 f/s
# 84490: done 85 games, mean reward -20.353, speed 53.14 f/s
# 84537: done 85 games, mean reward -20.235, speed 56.09 f/s
# 84642: done 85 games, mean reward -20.365, speed 55.43 f/s
# 84909: done 84 games, mean reward -20.214, speed 55.74 f/s
# 85073: done 86 games, mean reward -20.326, speed 55.13 f/s
# 85241: done 85 games, mean reward -20.224, speed 55.93 f/s
# 85275: done 87 games, mean reward -20.310, speed 56.47 f/s
# 85859: done 86 games, mean reward -20.244, speed 53.94 f/s
# 85976: done 88 games, mean reward -20.318, speed 54.46 f/s
# 86142: done 87 games, mean reward -20.241, speed 58.63 f/s
# 86559: done 86 games, mean reward -20.233, speed 53.98 f/s
# 86624: done 87 games, mean reward -20.241, speed 54.75 f/s
# 87132: done 86 games, mean reward -20.360, speed 54.53 f/s
# 88102: done 88 games, mean reward -20.216, speed 54.43 f/s
# 88195: done 89 games, mean reward -20.303, speed 54.53 f/s
# 88297: done 87 games, mean reward -20.356, speed 55.41 f/s
# 89097: done 89 games, mean reward -20.213, speed 53.61 f/s
# 89125: done 88 games, mean reward -20.352, speed 54.58 f/s
# 89206: done 88 games, mean reward -20.250, speed 55.17 f/s
# 89542: done 90 games, mean reward -20.300, speed 54.75 f/s
# 90348: done 91 games, mean reward -20.297, speed 57.01 f/s
# 90355: done 89 games, mean reward -20.225, speed 54.93 f/s
# 90535: done 90 games, mean reward -20.233, speed 52.38 f/s
# 90897: done 89 games, mean reward -20.326, speed 54.48 f/s
# 90926: done 90 games, mean reward -20.222, speed 55.62 f/s
# 90952: done 90 games, mean reward -20.322, speed 48.23 f/s
# 91510: done 91 games, mean reward -20.220, speed 55.68 f/s
# 91770: done 91 games, mean reward -20.231, speed 55.79 f/s
# 92391: done 91 games, mean reward -20.330, speed 56.12 f/s
# 92819: done 92 games, mean reward -20.239, speed 53.76 f/s
# 93126: done 92 games, mean reward -20.217, speed 53.98 f/s
# 93572: done 92 games, mean reward -20.326, speed 53.69 f/s
# 93762: done 93 games, mean reward -20.333, speed 54.79 f/s
# 93798: done 92 games, mean reward -20.304, speed 54.81 f/s
# 93968: done 93 games, mean reward -20.301, speed 50.62 f/s
# 94032: done 94 games, mean reward -20.319, speed 56.12 f/s
# 94383: done 94 games, mean reward -20.298, speed 57.38 f/s
# 94885: done 93 games, mean reward -20.237, speed 54.90 f/s
# 95123: done 94 games, mean reward -20.234, speed 52.00 f/s
# 95205: done 93 games, mean reward -20.204, speed 55.09 f/s
# 95289: done 95 games, mean reward -20.316, speed 55.81 f/s
# 95814: done 95 games, mean reward -20.305, speed 53.95 f/s
# 96039: done 94 games, mean reward -20.213, speed 55.21 f/s
# 96185: done 96 games, mean reward -20.323, speed 55.10 f/s
# 96461: done 95 games, mean reward -20.232, speed 54.87 f/s
# 96626: done 95 games, mean reward -20.221, speed 55.42 f/s
# 96645: done 96 games, mean reward -20.302, speed 54.79 f/s
# 96698: done 97 games, mean reward -20.309, speed 125.66 f/s
# 96704: done 96 games, mean reward -20.219, speed 63.23 f/s
# 96893: done 97 games, mean reward -20.227, speed 54.06 f/s
# 97743: done 98 games, mean reward -20.235, speed 53.40 f/s
# 97851: done 96 games, mean reward -20.229, speed 55.35 f/s
# 97869: done 97 games, mean reward -20.330, speed 54.04 f/s
# 98054: done 98 games, mean reward -20.296, speed 53.72 f/s
# 98254: done 98 games, mean reward -20.337, speed 54.53 f/s
# 98382: done 99 games, mean reward -20.303, speed 55.40 f/s
# 98720: done 100 games, mean reward -20.290, speed 56.49 f/s
# 98741: done 99 games, mean reward -20.232, speed 55.89 f/s
# 99008: done 97 games, mean reward -20.227, speed 55.11 f/s
# 99259: done 101 games, mean reward -20.270, speed 57.51 f/s
# 99355: done 98 games, mean reward -20.235, speed 51.30 f/s
# 99517: done 99 games, mean reward -20.242, speed 62.80 f/s
# 99654: done 100 games, mean reward -20.250, speed 43.85 f/s
# 99795: done 100 games, mean reward -20.240, speed 54.06 f/s
# 99903: done 101 games, mean reward -20.240, speed 63.76 f/s
# 100149: done 102 games, mean reward -20.250, speed 54.51 f/s
# 100625: done 102 games, mean reward -20.210, speed 53.19 f/s
# 100767: done 99 games, mean reward -20.323, speed 55.24 f/s
# 101267: done 100 games, mean reward -20.300, speed 53.98 f/s
# 101285: done 101 games, mean reward -20.240, speed 55.33 f/s
# 101367: done 101 games, mean reward -20.290, speed 70.35 f/s
# 101679: done 102 games, mean reward -20.280, speed 53.98 f/s
# 101817: done 102 games, mean reward -20.210, speed 56.29 f/s
# 102039: done 103 games, mean reward -20.260, speed 54.25 f/s
# 102324: done 103 games, mean reward -20.210, speed 54.18 f/s
# 102537: done 104 games, mean reward -20.200, speed 49.95 f/s
# 103272: done 104 games, mean reward -20.260, speed 55.55 f/s
# 103582: done 105 games, mean reward -20.270, speed 53.49 f/s
# 103989: done 103 games, mean reward -20.210, speed 55.13 f/s
# 104050: done 104 games, mean reward -20.210, speed 51.38 f/s
# 104208: done 105 games, mean reward -20.220, speed 48.63 f/s
# 104538: done 106 games, mean reward -20.250, speed 54.59 f/s
# 104858: done 103 games, mean reward -20.270, speed 54.51 f/s
# 105250: done 106 games, mean reward -20.220, speed 55.22 f/s
# 105327: done 105 games, mean reward -20.190, speed 55.09 f/s
# 105335: done 104 games, mean reward -20.260, speed 56.86 f/s
# 105376: done 106 games, mean reward -20.200, speed 44.18 f/s
# 105815: done 107 games, mean reward -20.190, speed 54.46 f/s
# 105848: done 105 games, mean reward -20.260, speed 54.82 f/s
# 105886: done 106 games, mean reward -20.270, speed 36.86 f/s
# 106540: done 108 games, mean reward -20.190, speed 55.52 f/s
# 106597: done 107 games, mean reward -20.280, speed 54.97 f/s
# 106983: done 107 games, mean reward -20.250, speed 54.80 f/s
# 106994: done 107 games, mean reward -20.230, speed 54.89 f/s
# 107582: done 108 games, mean reward -20.260, speed 55.72 f/s
# 107798: done 109 games, mean reward -20.190, speed 54.01 f/s
# 108086: done 110 games, mean reward -20.190, speed 58.53 f/s
# 108579: done 109 games, mean reward -20.270, speed 53.77 f/s
# 108873: done 108 games, mean reward -20.270, speed 54.24 f/s
# 108944: done 111 games, mean reward -20.190, speed 53.07 f/s
# 109252: done 108 games, mean reward -20.230, speed 53.98 f/s
# 109254: done 110 games, mean reward -20.290, speed 53.29 f/s
# 109296: done 109 games, mean reward -20.230, speed 122.46 f/s
# 109401: done 111 games, mean reward -20.300, speed 58.81 f/s
# 109783: done 109 games, mean reward -20.260, speed 55.01 f/s
# 109990: done 110 games, mean reward -20.220, speed 54.20 f/s
# 110794: done 110 games, mean reward -20.260, speed 54.72 f/s
# 111340: done 112 games, mean reward -20.310, speed 55.22 f/s
# 111407: done 112 games, mean reward -20.210, speed 55.29 f/s
# 111689: done 113 games, mean reward -20.290, speed 51.36 f/s
# 111837: done 111 games, mean reward -20.230, speed 54.79 f/s
# 112063: done 113 games, mean reward -20.210, speed 55.77 f/s
# 112151: done 114 games, mean reward -20.210, speed 41.42 f/s
# 112279: done 114 games, mean reward -20.320, speed 55.54 f/s
# 112283: done 111 games, mean reward -20.250, speed 55.03 f/s
# 112626: done 112 games, mean reward -20.250, speed 55.50 f/s
# 112841: done 112 games, mean reward -20.250, speed 53.55 f/s
# 113374: done 115 games, mean reward -20.300, speed 55.28 f/s
# 113571: done 113 games, mean reward -20.280, speed 54.60 f/s
# 113790: done 113 games, mean reward -20.260, speed 57.26 f/s
# 113959: done 115 games, mean reward -20.240, speed 55.25 f/s
# 114371: done 114 games, mean reward -20.300, speed 53.29 f/s
# 114410: done 115 games, mean reward -20.320, speed 113.48 f/s
# 114788: done 116 games, mean reward -20.300, speed 54.79 f/s
# 114816: done 114 games, mean reward -20.290, speed 54.59 f/s
# 114852: done 116 games, mean reward -20.210, speed 54.56 f/s
# 115016: done 115 games, mean reward -20.300, speed 46.62 f/s
# 115025: done 117 games, mean reward -20.300, speed 52.02 f/s
# 115028: done 117 games, mean reward -20.210, speed 51.45 f/s
# 115079: done 116 games, mean reward -20.280, speed 51.70 f/s
# 115479: done 118 games, mean reward -20.300, speed 55.15 f/s
# 116067: done 116 games, mean reward -20.310, speed 54.61 f/s
# 116587: done 117 games, mean reward -20.310, speed 55.02 f/s
# 116795: done 118 games, mean reward -20.290, speed 57.64 f/s
# 116888: done 117 games, mean reward -20.250, speed 55.02 f/s
# 117311: done 118 games, mean reward -20.250, speed 58.11 f/s
# 117343: done 118 games, mean reward -20.200, speed 54.75 f/s
# 117581: done 119 games, mean reward -20.200, speed 52.00 f/s
# 117756: done 119 games, mean reward -20.290, speed 55.14 f/s
# 117803: done 119 games, mean reward -20.290, speed 54.09 f/s
# 117994: done 119 games, mean reward -20.250, speed 53.45 f/s
# 118228: done 120 games, mean reward -20.190, speed 55.10 f/s
# 118362: done 120 games, mean reward -20.300, speed 53.60 f/s
# 118452: done 121 games, mean reward -20.310, speed 65.47 f/s
# 119228: done 121 games, mean reward -20.200, speed 56.10 f/s
# 119260: done 120 games, mean reward -20.250, speed 54.62 f/s
# 119330: done 122 games, mean reward -20.200, speed 49.47 f/s
# 119938: done 120 games, mean reward -20.270, speed 54.19 f/s
# 120832: done 121 games, mean reward -20.250, speed 55.81 f/s
# 121082: done 123 games, mean reward -20.200, speed 55.49 f/s
# 121100: done 122 games, mean reward -20.280, speed 54.49 f/s
# 121136: done 122 games, mean reward -20.250, speed 52.74 f/s
# 121173: done 121 games, mean reward -20.240, speed 55.05 f/s
# 121668: done 122 games, mean reward -20.230, speed 53.62 f/s
# 121763: done 123 games, mean reward -20.300, speed 55.87 f/s
# 121916: done 123 games, mean reward -20.240, speed 55.32 f/s
# 122048: done 123 games, mean reward -20.230, speed 61.22 f/s
# 122208: done 124 games, mean reward -20.230, speed 47.42 f/s
# 122464: done 124 games, mean reward -20.240, speed 52.54 f/s
# 122974: done 125 games, mean reward -20.250, speed 54.50 f/s
# 123113: done 124 games, mean reward -20.200, speed 54.32 f/s
# 123281: done 125 games, mean reward -20.210, speed 50.25 f/s
# 123320: done 125 games, mean reward -20.220, speed 55.40 f/s
# 123674: done 126 games, mean reward -20.220, speed 55.05 f/s
# 124112: done 127 games, mean reward -20.220, speed 54.76 f/s
# 124435: done 124 games, mean reward -20.320, speed 54.58 f/s
# 124450: done 126 games, mean reward -20.220, speed 54.43 f/s
# 125015: done 125 games, mean reward -20.320, speed 55.92 f/s
# 125215: done 127 games, mean reward -20.240, speed 55.11 f/s
# 125258: done 126 games, mean reward -20.240, speed 54.77 f/s
# 125290: done 128 games, mean reward -20.240, speed 55.87 f/s
# 125984: done 128 games, mean reward -20.240, speed 54.70 f/s
# 125993: done 129 games, mean reward -20.270, speed 82.31 f/s
# 126083: done 126 games, mean reward -20.330, speed 53.89 f/s
# 126951: done 127 games, mean reward -20.320, speed 56.82 f/s
# 127047: done 128 games, mean reward -20.300, speed 44.53 f/s
# 127068: done 129 games, mean reward -20.250, speed 54.67 f/s
# 127102: done 130 games, mean reward -20.280, speed 55.86 f/s
# 127685: done 131 games, mean reward -20.270, speed 51.55 f/s
# 127724: done 127 games, mean reward -20.240, speed 55.29 f/s
# 127735: done 129 games, mean reward -20.320, speed 57.42 f/s
# 127838: done 130 games, mean reward -20.320, speed 42.36 f/s
# 128045: done 128 games, mean reward -20.240, speed 54.55 f/s
# 128054: done 129 games, mean reward -20.230, speed 64.01 f/s
# 128825: done 132 games, mean reward -20.260, speed 56.60 f/s
# 128865: done 130 games, mean reward -20.250, speed 54.99 f/s
# 128969: done 130 games, mean reward -20.250, speed 53.77 f/s
# 129291: done 131 games, mean reward -20.320, speed 55.25 f/s
# 129412: done 131 games, mean reward -20.240, speed 55.50 f/s
# 129544: done 132 games, mean reward -20.330, speed 54.35 f/s
# 129879: done 133 games, mean reward -20.250, speed 54.04 f/s
# 130560: done 132 games, mean reward -20.230, speed 56.49 f/s
# 130596: done 133 games, mean reward -20.330, speed 55.47 f/s
# 130602: done 131 games, mean reward -20.250, speed 55.05 f/s
# 130641: done 134 games, mean reward -20.250, speed 53.72 f/s
# 131186: done 133 games, mean reward -20.220, speed 52.31 f/s
# 131288: done 132 games, mean reward -20.240, speed 52.34 f/s
# 131311: done 133 games, mean reward -20.240, speed 98.16 f/s
# 131501: done 134 games, mean reward -20.250, speed 55.88 f/s
# 131531: done 134 games, mean reward -20.330, speed 52.72 f/s
# 132266: done 135 games, mean reward -20.320, speed 56.89 f/s
# 132415: done 136 games, mean reward -20.310, speed 60.37 f/s
# 132498: done 135 games, mean reward -20.270, speed 54.24 f/s
# 132695: done 134 games, mean reward -20.220, speed 54.38 f/s
# 133168: done 135 games, mean reward -20.250, speed 55.05 f/s
# 133640: done 135 games, mean reward -20.210, speed 54.01 f/s
# 133784: done 136 games, mean reward -20.270, speed 54.74 f/s
# 133884: done 137 games, mean reward -20.280, speed 69.58 f/s
# 134432: done 136 games, mean reward -20.250, speed 54.54 f/s
# 134545: done 136 games, mean reward -20.210, speed 55.51 f/s
# 134662: done 137 games, mean reward -20.250, speed 51.30 f/s
# 134897: done 138 games, mean reward -20.250, speed 61.65 f/s
# 134967: done 137 games, mean reward -20.200, speed 57.85 f/s
# 135153: done 138 games, mean reward -20.200, speed 53.88 f/s
# 135201: done 139 games, mean reward -20.250, speed 52.22 f/s
# 135417: done 139 games, mean reward -20.210, speed 55.65 f/s
# 135634: done 140 games, mean reward -20.220, speed 48.91 f/s
# 135710: done 137 games, mean reward -20.310, speed 54.44 f/s
# 136044: done 138 games, mean reward -20.280, speed 54.65 f/s
# 136239: done 138 games, mean reward -20.310, speed 55.70 f/s
# 136344: done 139 games, mean reward -20.310, speed 47.00 f/s
# 136388: done 139 games, mean reward -20.270, speed 50.74 f/s
# 137368: done 140 games, mean reward -20.270, speed 55.81 f/s
# 137679: done 140 games, mean reward -20.250, speed 54.66 f/s
# 137945: done 141 games, mean reward -20.270, speed 54.80 f/s
# 138429: done 141 games, mean reward -20.250, speed 56.75 f/s
# 138602: done 142 games, mean reward -20.260, speed 50.80 f/s
# 138917: done 142 games, mean reward -20.280, speed 55.16 f/s
# 138929: done 143 games, mean reward -20.280, speed 76.82 f/s
# 139279: done 140 games, mean reward -20.310, speed 54.68 f/s
# 139837: done 141 games, mean reward -20.230, speed 55.08 f/s
# 140002: done 141 games, mean reward -20.320, speed 55.70 f/s
# 140090: done 142 games, mean reward -20.320, speed 64.02 f/s
# 140210: done 143 games, mean reward -20.260, speed 54.85 f/s
# 140277: done 143 games, mean reward -20.320, speed 54.25 f/s
# 140329: done 142 games, mean reward -20.230, speed 53.50 f/s
# 140439: done 144 games, mean reward -20.260, speed 52.36 f/s
# 141046: done 145 games, mean reward -20.240, speed 57.28 f/s
# 141489: done 144 games, mean reward -20.310, speed 55.43 f/s
# 141565: done 143 games, mean reward -20.240, speed 55.97 f/s
# 141687: done 145 games, mean reward -20.300, speed 54.87 f/s
# 141816: done 146 games, mean reward -20.300, speed 55.55 f/s
# 141838: done 144 games, mean reward -20.240, speed 49.14 f/s
# 142157: done 145 games, mean reward -20.250, speed 54.89 f/s
# 142280: done 146 games, mean reward -20.230, speed 53.45 f/s
# 142593: done 144 games, mean reward -20.280, speed 54.61 f/s
# 142687: done 146 games, mean reward -20.250, speed 56.64 f/s
# 143498: done 147 games, mean reward -20.250, speed 55.06 f/s
# 143845: done 145 games, mean reward -20.300, speed 55.70 f/s
# 144038: done 146 games, mean reward -20.310, speed 54.43 f/s
# 144169: done 147 games, mean reward -20.320, speed 54.59 f/s
# 144255: done 147 games, mean reward -20.250, speed 55.31 f/s
# 144593: done 147 games, mean reward -20.300, speed 53.21 f/s
# 144756: done 148 games, mean reward -20.280, speed 55.83 f/s
# 144803: done 149 games, mean reward -20.270, speed 42.98 f/s
# 144821: done 148 games, mean reward -20.260, speed 54.27 f/s
# 144858: done 148 games, mean reward -20.300, speed 56.24 f/s
# 144922: done 148 games, mean reward -20.330, speed 53.90 f/s
# 145200: done 149 games, mean reward -20.280, speed 56.57 f/s
# 145458: done 150 games, mean reward -20.280, speed 54.87 f/s
# 145513: done 150 games, mean reward -20.280, speed 54.96 f/s
# 145915: done 149 games, mean reward -20.330, speed 55.91 f/s
# 146489: done 151 games, mean reward -20.280, speed 55.05 f/s
# 146522: done 151 games, mean reward -20.280, speed 54.19 f/s
# 146562: done 150 games, mean reward -20.310, speed 51.97 f/s
# 146739: done 149 games, mean reward -20.270, speed 54.60 f/s
# 147021: done 150 games, mean reward -20.270, speed 50.05 f/s
# 147189: done 151 games, mean reward -20.290, speed 57.15 f/s
# 147646: done 152 games, mean reward -20.280, speed 55.64 f/s
# 147653: done 152 games, mean reward -20.310, speed 51.40 f/s
# 147713: done 152 games, mean reward -20.280, speed 53.04 f/s
# 147741: done 151 games, mean reward -20.300, speed 55.47 f/s
# 148037: done 152 games, mean reward -20.290, speed 51.77 f/s
# 148452: done 153 games, mean reward -20.280, speed 58.77 f/s
# 148638: done 154 games, mean reward -20.290, speed 53.39 f/s
# 148820: done 153 games, mean reward -20.260, speed 53.91 f/s
# 149113: done 155 games, mean reward -20.280, speed 56.41 f/s
# 149560: done 153 games, mean reward -20.260, speed 55.93 f/s
# 149694: done 154 games, mean reward -20.270, speed 56.29 f/s
# 150204: done 155 games, mean reward -20.260, speed 54.53 f/s
# 150336: done 153 games, mean reward -20.290, speed 55.54 f/s
# 150684: done 154 games, mean reward -20.300, speed 51.33 f/s
# 151482: done 154 games, mean reward -20.290, speed 54.63 f/s
# 151524: done 156 games, mean reward -20.270, speed 53.97 f/s
# 151549: done 155 games, mean reward -20.310, speed 56.10 f/s
# 152080: done 156 games, mean reward -20.310, speed 52.70 f/s
# 153002: done 157 games, mean reward -20.280, speed 55.46 f/s
# 153026: done 158 games, mean reward -20.290, speed 26.19 f/s
# 153142: done 156 games, mean reward -20.290, speed 54.90 f/s
# 153202: done 157 games, mean reward -20.310, speed 56.19 f/s
# 153322: done 155 games, mean reward -20.300, speed 54.93 f/s
# 153406: done 156 games, mean reward -20.310, speed 62.53 f/s
# 153696: done 158 games, mean reward -20.310, speed 54.34 f/s
# 154076: done 157 games, mean reward -20.300, speed 54.08 f/s
# 154185: done 159 games, mean reward -20.290, speed 55.22 f/s
# 154440: done 158 games, mean reward -20.310, speed 52.60 f/s
# 154540: done 159 games, mean reward -20.320, speed 55.09 f/s
# 154851: done 159 games, mean reward -20.310, speed 57.12 f/s
# 155097: done 160 games, mean reward -20.320, speed 53.38 f/s
# 155151: done 157 games, mean reward -20.280, speed 53.95 f/s
# 155457: done 160 games, mean reward -20.300, speed 52.88 f/s
# 156492: done 158 games, mean reward -20.260, speed 54.62 f/s
# 156664: done 160 games, mean reward -20.280, speed 55.52 f/s
# 156713: done 161 games, mean reward -20.280, speed 45.03 f/s
# 156890: done 159 games, mean reward -20.270, speed 57.17 f/s
# 156954: done 162 games, mean reward -20.260, speed 53.02 f/s
# 157353: done 161 games, mean reward -20.320, speed 55.13 f/s
# 157447: done 160 games, mean reward -20.260, speed 53.54 f/s
# 157477: done 161 games, mean reward -20.290, speed 55.50 f/s
# 157491: done 162 games, mean reward -20.320, speed 56.63 f/s
# 157826: done 163 games, mean reward -20.260, speed 53.11 f/s
# 157942: done 164 games, mean reward -20.260, speed 75.01 f/s
# 157940: done 161 games, mean reward -20.250, speed 56.46 f/s
# 157965: done 162 games, mean reward -20.280, speed 51.72 f/s
# 158192: done 162 games, mean reward -20.240, speed 54.32 f/s
# 158221: done 163 games, mean reward -20.240, speed 30.11 f/s
# 158430: done 164 games, mean reward -20.250, speed 58.42 f/s
# 158851: done 165 games, mean reward -20.260, speed 52.88 f/s
# 158883: done 165 games, mean reward -20.250, speed 54.85 f/s
# 158948: done 166 games, mean reward -20.260, speed 66.77 f/s
# 159109: done 163 games, mean reward -20.280, speed 54.44 f/s
# 159250: done 163 games, mean reward -20.320, speed 53.71 f/s
# 159669: done 164 games, mean reward -20.310, speed 57.81 f/s
# 159717: done 164 games, mean reward -20.260, speed 56.65 f/s
# 160264: done 167 games, mean reward -20.260, speed 54.32 f/s
# 160312: done 166 games, mean reward -20.250, speed 55.51 f/s
# 160616: done 165 games, mean reward -20.300, speed 54.52 f/s
# 160645: done 165 games, mean reward -20.260, speed 54.01 f/s
# 160695: done 167 games, mean reward -20.250, speed 54.74 f/s
# 160956: done 166 games, mean reward -20.260, speed 61.45 f/s
# 161477: done 168 games, mean reward -20.260, speed 54.58 f/s
# 161724: done 166 games, mean reward -20.300, speed 55.26 f/s
# 161933: done 167 games, mean reward -20.300, speed 47.61 f/s
# 162160: done 167 games, mean reward -20.260, speed 54.19 f/s
# 162393: done 168 games, mean reward -20.270, speed 51.61 f/s
# 162708: done 169 games, mean reward -20.270, speed 53.97 f/s
# 162894: done 169 games, mean reward -20.260, speed 54.77 f/s
# 163896: done 168 games, mean reward -20.300, speed 55.69 f/s
# 163994: done 170 games, mean reward -20.250, speed 55.18 f/s
# 164349: done 169 games, mean reward -20.310, speed 54.91 f/s
# 164645: done 170 games, mean reward -20.310, speed 52.20 f/s
# 164756: done 168 games, mean reward -20.240, speed 54.43 f/s
# 164784: done 170 games, mean reward -20.250, speed 55.52 f/s
# 165485: done 171 games, mean reward -20.300, speed 54.76 f/s
# 165666: done 169 games, mean reward -20.250, speed 55.11 f/s
# 166146: done 171 games, mean reward -20.250, speed 54.19 f/s
# 166212: done 170 games, mean reward -20.240, speed 54.70 f/s
# 166576: done 171 games, mean reward -20.240, speed 59.29 f/s
# 166723: done 171 games, mean reward -20.250, speed 54.69 f/s
# 166990: done 172 games, mean reward -20.260, speed 55.13 f/s
# 167150: done 172 games, mean reward -20.300, speed 55.34 f/s
# 167404: done 172 games, mean reward -20.250, speed 56.69 f/s
# 167649: done 173 games, mean reward -20.250, speed 52.99 f/s
# 167817: done 173 games, mean reward -20.320, speed 52.67 f/s
# 167996: done 174 games, mean reward -20.250, speed 58.05 f/s
# 168715: done 174 games, mean reward -20.300, speed 54.75 f/s
# 169099: done 175 games, mean reward -20.320, speed 54.51 f/s
# 169183: done 176 games, mean reward -20.330, speed 64.17 f/s
# 169394: done 175 games, mean reward -20.260, speed 54.24 f/s
# 169664: done 173 games, mean reward -20.240, speed 55.28 f/s
# 169673: done 174 games, mean reward -20.220, speed 11.08 f/s
# 169691: done 175 games, mean reward -20.210, speed 96.02 f/s
# 169857: done 172 games, mean reward -20.250, speed 54.08 f/s
# 169885: done 173 games, mean reward -20.240, speed 105.44 f/s
# 170183: done 176 games, mean reward -20.200, speed 53.75 f/s
# 170425: done 177 games, mean reward -20.190, speed 62.81 f/s
# 170750: done 178 games, mean reward -20.200, speed 55.33 f/s
# 170904: done 174 games, mean reward -20.260, speed 54.79 f/s
# 171195: done 179 games, mean reward -20.210, speed 54.57 f/s
# 171359: done 175 games, mean reward -20.240, speed 55.31 f/s
# 171724: done 177 games, mean reward -20.340, speed 54.38 f/s
# 171737: done 176 games, mean reward -20.270, speed 53.77 f/s
# 171788: done 178 games, mean reward -20.340, speed 53.21 f/s
# 172031: done 180 games, mean reward -20.210, speed 54.57 f/s
# 172221: done 177 games, mean reward -20.260, speed 57.59 f/s
# 172443: done 181 games, mean reward -20.210, speed 51.92 f/s
# 172531: done 178 games, mean reward -20.270, speed 53.35 f/s
# 172605: done 179 games, mean reward -20.260, speed 57.77 f/s
# 172697: done 176 games, mean reward -20.260, speed 54.51 f/s
# 172750: done 182 games, mean reward -20.230, speed 54.59 f/s
# 172871: done 180 games, mean reward -20.260, speed 50.08 f/s
# 173218: done 181 games, mean reward -20.250, speed 57.70 f/s
# 173467: done 177 games, mean reward -20.250, speed 54.77 f/s
# 173553: done 178 games, mean reward -20.250, speed 65.54 f/s
# 173710: done 179 games, mean reward -20.330, speed 54.94 f/s
# 174194: done 179 games, mean reward -20.250, speed 54.81 f/s
# 174507: done 180 games, mean reward -20.330, speed 55.82 f/s
# 174558: done 180 games, mean reward -20.220, speed 52.29 f/s
# 174624: done 181 games, mean reward -20.220, speed 57.09 f/s
# 175020: done 182 games, mean reward -20.220, speed 55.59 f/s
# 175080: done 182 games, mean reward -20.260, speed 54.69 f/s
# 175419: done 181 games, mean reward -20.320, speed 55.94 f/s
# 175667: done 183 games, mean reward -20.220, speed 55.92 f/s
# 175763: done 182 games, mean reward -20.310, speed 51.06 f/s
# 176273: done 183 games, mean reward -20.230, speed 54.80 f/s
# 176523: done 184 games, mean reward -20.220, speed 53.70 f/s
# 177219: done 185 games, mean reward -20.210, speed 55.06 f/s
# 177243: done 183 games, mean reward -20.330, speed 55.08 f/s
# 177253: done 184 games, mean reward -20.220, speed 54.62 f/s
# 177406: done 185 games, mean reward -20.190, speed 60.46 f/s
# 177607: done 184 games, mean reward -20.330, speed 52.96 f/s
# 178354: done 185 games, mean reward -20.320, speed 56.59 f/s
# 178796: done 186 games, mean reward -20.320, speed 54.31 f/s
# 178960: done 183 games, mean reward -20.270, speed 54.66 f/s
# 179458: done 186 games, mean reward -20.200, speed 53.64 f/s
# 179766: done 186 games, mean reward -20.240, speed 55.31 f/s
# 180089: done 184 games, mean reward -20.270, speed 55.94 f/s
# 180566: done 187 games, mean reward -20.320, speed 54.46 f/s
# 180595: done 187 games, mean reward -20.260, speed 55.07 f/s
# 180937: done 185 games, mean reward -20.270, speed 53.36 f/s
# 181079: done 186 games, mean reward -20.240, speed 58.02 f/s
# 181464: done 187 games, mean reward -20.200, speed 55.26 f/s
# 181521: done 187 games, mean reward -20.250, speed 54.10 f/s
# 181720: done 188 games, mean reward -20.310, speed 54.71 f/s
# 181867: done 189 games, mean reward -20.330, speed 59.94 f/s
# 182291: done 190 games, mean reward -20.330, speed 52.60 f/s
# 182338: done 188 games, mean reward -20.270, speed 54.09 f/s
# 182495: done 188 games, mean reward -20.260, speed 54.27 f/s
# 182735: done 191 games, mean reward -20.350, speed 54.20 f/s
# 182990: done 188 games, mean reward -20.190, speed 54.36 f/s
# 183204: done 189 games, mean reward -20.280, speed 55.96 f/s
# 183205: done 189 games, mean reward -20.200, speed 59.16 f/s
# 183502: done 189 games, mean reward -20.280, speed 53.91 f/s
# 183524: done 190 games, mean reward -20.290, speed 100.59 f/s
# 184109: done 190 games, mean reward -20.200, speed 54.90 f/s
# 184232: done 191 games, mean reward -20.290, speed 55.14 f/s
# 184394: done 190 games, mean reward -20.280, speed 53.80 f/s
# 184534: done 192 games, mean reward -20.280, speed 52.82 f/s
# 184599: done 193 games, mean reward -20.280, speed 54.04 f/s
# 185012: done 191 games, mean reward -20.200, speed 54.84 f/s
# 185153: done 194 games, mean reward -20.270, speed 53.49 f/s
# 185597: done 195 games, mean reward -20.270, speed 59.84 f/s
# 186425: done 191 games, mean reward -20.270, speed 55.47 f/s
# 186551: done 196 games, mean reward -20.270, speed 54.38 f/s
# 186588: done 192 games, mean reward -20.270, speed 48.38 f/s
# 187247: done 192 games, mean reward -20.200, speed 54.55 f/s
# 187600: done 197 games, mean reward -20.260, speed 53.35 f/s
# 187634: done 193 games, mean reward -20.280, speed 55.48 f/s
# 187654: done 192 games, mean reward -20.340, speed 54.57 f/s
# 187756: done 193 games, mean reward -20.190, speed 54.40 f/s
# 187886: done 194 games, mean reward -20.280, speed 53.95 f/s
# 187978: done 194 games, mean reward -20.210, speed 49.86 f/s
# 188008: done 195 games, mean reward -20.280, speed 53.49 f/s
# 188026: done 195 games, mean reward -20.220, speed 128.03 f/s
# 188426: done 196 games, mean reward -20.220, speed 51.25 f/s
# 188541: done 193 games, mean reward -20.350, speed 56.86 f/s
# 188822: done 198 games, mean reward -20.280, speed 54.79 f/s
# 188860: done 194 games, mean reward -20.330, speed 54.46 f/s
# 188895: done 197 games, mean reward -20.220, speed 56.01 f/s
# 189534: done 199 games, mean reward -20.270, speed 55.00 f/s
# 189709: done 196 games, mean reward -20.280, speed 54.03 f/s
# 189720: done 195 games, mean reward -20.320, speed 53.16 f/s
# 189836: done 196 games, mean reward -20.310, speed 50.52 f/s
# 190003: done 197 games, mean reward -20.270, speed 59.75 f/s
# 190655: done 197 games, mean reward -20.310, speed 56.93 f/s
# 190845: done 198 games, mean reward -20.310, speed 54.06 f/s
# 190990: done 199 games, mean reward -20.290, speed 45.80 f/s
# 191399: done 198 games, mean reward -20.220, speed 54.78 f/s
# 191562: done 199 games, mean reward -20.220, speed 48.38 f/s
# 192370: done 198 games, mean reward -20.260, speed 54.85 f/s
# 192636: done 199 games, mean reward -20.270, speed 57.79 f/s
# 192664: done 200 games, mean reward -20.270, speed 55.35 f/s
# 192920: done 200 games, mean reward -20.280, speed 54.87 f/s
# ...
# 1657637: done 1779 games, mean reward -20.370, speed 54.20 f/s
# 1657760: done 1780 games, mean reward -20.340, speed 52.14 f/s
# 1657900: done 1781 games, mean reward -20.330, speed 58.20 f/s
# 1659253: done 1784 games, mean reward -20.400, speed 56.45 f/s
# 1659307: done 1785 games, mean reward -20.400, speed 48.01 f/s
# 1658615: done 1779 games, mean reward -20.190, speed 54.93 f/s
# 1660179: done 1792 games, mean reward -20.320, speed 54.46 f/s
# 1659267: done 1782 games, mean reward -20.330, speed 53.65 f/s
# 1660301: done 1793 games, mean reward -20.320, speed 52.42 f/s
# 1660294: done 1786 games, mean reward -20.400, speed 53.41 f/s
# 1660510: done 1794 games, mean reward -20.320, speed 57.67 f/s
# 1659572: done 1780 games, mean reward -20.180, speed 54.50 f/s
# 1659704: done 1783 games, mean reward -20.310, speed 59.26 f/s
# 1660249: done 1781 games, mean reward -20.170, speed 53.21 f/s
# 1661535: done 1795 games, mean reward -20.320, speed 54.74 f/s
# 1661872: done 1787 games, mean reward -20.410, speed 55.58 f/s
# 1662174: done 1796 games, mean reward -20.320, speed 54.40 f/s
# 1661305: done 1784 games, mean reward -20.310, speed 54.56 f/s
# 1661791: done 1782 games, mean reward -20.160, speed 54.81 f/s
# 1663308: done 1788 games, mean reward -20.400, speed 53.79 f/s
# 1664045: done 1789 games, mean reward -20.390, speed 56.17 f/s
# 1663458: done 1785 games, mean reward -20.300, speed 54.30 f/s
# 1664679: done 1790 games, mean reward -20.380, speed 54.26 f/s
# 1664861: done 1797 games, mean reward -20.310, speed 54.66 f/s
# 1665430: done 1798 games, mean reward -20.320, speed 54.20 f/s
# 1665502: done 1799 games, mean reward -20.320, speed 57.61 f/s
# 1665522: done 1800 games, mean reward -20.330, speed 91.45 f/s
# 1664517: done 1783 games, mean reward -20.170, speed 54.31 f/s
# 1665583: done 1791 games, mean reward -20.370, speed 54.96 f/s
# 1664571: done 1784 games, mean reward -20.170, speed 119.20 f/s
# 1664762: done 1785 games, mean reward -20.180, speed 55.83 f/s
# 1665686: done 1786 games, mean reward -20.180, speed 53.34 f/s
# 1665753: done 1787 games, mean reward -20.190, speed 55.70 f/s
# 1667029: done 1792 games, mean reward -20.370, speed 54.09 f/s
# 1667401: done 1801 games, mean reward -20.320, speed 54.03 f/s
# 1666335: done 1788 games, mean reward -20.200, speed 55.09 f/s
# 1667978: done 1802 games, mean reward -20.320, speed 54.64 f/s
# 1666982: done 1789 games, mean reward -20.210, speed 54.93 f/s
# 1667305: done 1786 games, mean reward -20.300, speed 54.69 f/s
# 1667392: done 1787 games, mean reward -20.300, speed 63.29 f/s
# 1668542: done 1793 games, mean reward -20.370, speed 55.60 f/s
# 1667825: done 1790 games, mean reward -20.190, speed 55.01 f/s
# 1668142: done 1788 games, mean reward -20.310, speed 54.07 f/s
# 1669160: done 1794 games, mean reward -20.410, speed 53.25 f/s
# 1669812: done 1795 games, mean reward -20.410, speed 56.10 f/s
# 1668955: done 1789 games, mean reward -20.320, speed 54.50 f/s
# 1669954: done 1796 games, mean reward -20.420, speed 44.56 f/s
# 1669092: done 1790 games, mean reward -20.310, speed 55.86 f/s
# 1669204: done 1791 games, mean reward -20.290, speed 49.79 f/s
# 1670302: done 1797 games, mean reward -20.410, speed 57.56 f/s
# 1669410: done 1791 games, mean reward -20.180, speed 54.61 f/s
# 1670170: done 1792 games, mean reward -20.180, speed 54.30 f/s
# 1670340: done 1792 games, mean reward -20.300, speed 54.23 f/s
# 1670323: done 1793 games, mean reward -20.170, speed 60.46 f/s
# 1670602: done 1793 games, mean reward -20.310, speed 55.17 f/s
# 1671506: done 1798 games, mean reward -20.410, speed 54.32 f/s
# 1671584: done 1803 games, mean reward -20.320, speed 54.99 f/s
# 1671701: done 1804 games, mean reward -20.340, speed 51.30 f/s
# 1671825: done 1805 games, mean reward -20.360, speed 53.63 f/s
# 1671084: done 1794 games, mean reward -20.330, speed 57.46 f/s
# 1672213: done 1799 games, mean reward -20.400, speed 54.59 f/s
# 1672461: done 1800 games, mean reward -20.400, speed 53.82 f/s
# 1671650: done 1795 games, mean reward -20.330, speed 53.76 f/s
# 1673005: done 1806 games, mean reward -20.360, speed 55.54 f/s
# 1672062: done 1796 games, mean reward -20.340, speed 57.34 f/s
# 1671947: done 1794 games, mean reward -20.170, speed 53.78 f/s
# 1673213: done 1807 games, mean reward -20.370, speed 57.39 f/s
# 1673194: done 1801 games, mean reward -20.400, speed 56.06 f/s
# 1672349: done 1797 games, mean reward -20.310, speed 50.89 f/s
# 1672435: done 1798 games, mean reward -20.290, speed 64.77 f/s
# 1672686: done 1795 games, mean reward -20.180, speed 56.43 f/s
# 1673996: done 1808 games, mean reward -20.380, speed 52.52 f/s
# 1674217: done 1802 games, mean reward -20.400, speed 54.51 f/s
# 1673500: done 1799 games, mean reward -20.300, speed 53.88 f/s
# 1673610: done 1796 games, mean reward -20.180, speed 53.28 f/s
# 1674731: done 1809 games, mean reward -20.390, speed 56.21 f/s
# 1674754: done 1797 games, mean reward -20.180, speed 54.41 f/s
# 1676588: done 1810 games, mean reward -20.390, speed 54.66 f/s
# 1676896: done 1811 games, mean reward -20.390, speed 53.00 f/s
# 1677291: done 1812 games, mean reward -20.390, speed 55.57 f/s
# 1677768: done 1803 games, mean reward -20.380, speed 54.38 f/s
# 1678370: done 1804 games, mean reward -20.380, speed 56.01 f/s
# 1677588: done 1800 games, mean reward -20.300, speed 54.55 f/s
# 1677567: done 1798 games, mean reward -20.220, speed 55.44 f/s
# 1677579: done 1799 games, mean reward -20.210, speed 13.48 f/s
# 1678809: done 1805 games, mean reward -20.380, speed 53.73 f/s
# 1679046: done 1813 games, mean reward -20.400, speed 53.93 f/s
# 1679276: done 1814 games, mean reward -20.390, speed 60.59 f/s
# 1679593: done 1806 games, mean reward -20.390, speed 55.39 f/s
# 1680479: done 1815 games, mean reward -20.380, speed 54.31 f/s
# 1679640: done 1800 games, mean reward -20.210, speed 54.84 f/s
# 1679816: done 1801 games, mean reward -20.220, speed 52.16 f/s
# 1681006: done 1816 games, mean reward -20.380, speed 55.49 f/s
# 1681290: done 1807 games, mean reward -20.400, speed 53.99 f/s
# 1680396: done 1801 games, mean reward -20.310, speed 54.52 f/s
# 1681669: done 1808 games, mean reward -20.390, speed 54.52 f/s
# 1680919: done 1802 games, mean reward -20.200, speed 55.12 f/s
# 1681140: done 1803 games, mean reward -20.210, speed 59.44 f/s
# 1681421: done 1802 games, mean reward -20.310, speed 54.77 f/s
# 1681509: done 1803 games, mean reward -20.340, speed 64.75 f/s
# 1681557: done 1804 games, mean reward -20.330, speed 43.90 f/s
# 1681547: done 1804 games, mean reward -20.210, speed 51.18 f/s
# 1682918: done 1817 games, mean reward -20.380, speed 54.54 f/s
# 1683246: done 1809 games, mean reward -20.370, speed 55.49 f/s
# 1683717: done 1810 games, mean reward -20.360, speed 51.63 f/s
# 1682868: done 1805 games, mean reward -20.320, speed 55.62 f/s
# 1684210: done 1818 games, mean reward -20.370, speed 54.88 f/s
# 1683321: done 1805 games, mean reward -20.200, speed 55.53 f/s
# 1684566: done 1811 games, mean reward -20.360, speed 55.29 f/s
# 1683773: done 1806 games, mean reward -20.320, speed 54.97 f/s
# 1683863: done 1807 games, mean reward -20.330, speed 41.75 f/s
# 1684949: done 1819 games, mean reward -20.360, speed 53.39 f/s
# 1684065: done 1806 games, mean reward -20.200, speed 53.63 f/s
# 1685658: done 1812 games, mean reward -20.360, speed 54.78 f/s
# 1684752: done 1807 games, mean reward -20.200, speed 52.94 f/s
# 1684902: done 1808 games, mean reward -20.320, speed 54.67 f/s
# 1685816: done 1813 games, mean reward -20.350, speed 57.25 f/s
# 1685874: done 1814 games, mean reward -20.330, speed 44.13 f/s
# 1684969: done 1808 games, mean reward -20.200, speed 56.94 f/s
# 1685134: done 1809 games, mean reward -20.320, speed 50.13 f/s
# 1686219: done 1820 games, mean reward -20.380, speed 55.00 f/s
# Process Process-4:
# Process Process-2:
# Process Process-3:
# Process Process-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\process.py", line 258, in _bootstrap
#     self.run()
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\process.py", line 258, in _bootstrap
#     self.run()
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\process.py", line 258, in _bootstrap
#     self.run()
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Kelvin\Desktop\reinforcement learning\Chapter 11\a3c_grad.py.py", line 61, in grads_func
#     for exp in exp_source:
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Kelvin\Desktop\reinforcement learning\Chapter 11\a3c_grad.py.py", line 61, in grads_func
#     for exp in exp_source:
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\experience.py", line 173, in __iter__
#     for exp in super(ExperienceSourceFirstLast, self).__iter__():
#   File "C:\Users\Kelvin\Desktop\reinforcement learning\Chapter 11\a3c_grad.py.py", line 61, in grads_func
#     for exp in exp_source:
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\experience.py", line 173, in __iter__
#     for exp in super(ExperienceSourceFirstLast, self).__iter__():
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\experience.py", line 94, in __iter__
#     next_state, r, is_done, _ = env.step(action_n[0])
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\experience.py", line 173, in __iter__
#     for exp in super(ExperienceSourceFirstLast, self).__iter__():
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\experience.py", line 94, in __iter__
#     next_state, r, is_done, _ = env.step(action_n[0])
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 295, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\experience.py", line 94, in __iter__
#     next_state, r, is_done, _ = env.step(action_n[0])
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 295, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 196, in step
#     ob, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 295, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 196, in step
#     ob, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 282, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 196, in step
#     ob, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 282, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 282, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 282, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 282, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 47, in step
#     return self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\core.py", line 282, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 47, in step
#     return self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 112, in step
#     obs, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 47, in step
#     return self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 112, in step
#     obs, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 21, in step
#     return self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 112, in step
#     obs, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 21, in step
#     return self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 71, in step
#     obs, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 21, in step
#     return self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 71, in step
#     obs, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\wrappers\time_limit.py", line 18, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\ptan\common\wrappers.py", line 71, in step
#     obs, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\wrappers\time_limit.py", line 18, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\envs\atari\atari_env.py", line 134, in step
#     reward += self.ale.act(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\wrappers\time_limit.py", line 18, in step
#     observation, reward, done, info = self.env.step(action)
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\envs\atari\atari_env.py", line 135, in step
#     ob = self._get_obs()
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\atari_py\ale_python_interface.py", line 152, in act
#     return ale_lib.act(self.obj, int(action))
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\envs\atari\atari_env.py", line 135, in step
#     ob = self._get_obs()
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\envs\atari\atari_env.py", line 153, in _get_obs
#     img = self._get_image()
# KeyboardInterrupt
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\envs\atari\atari_env.py", line 153, in _get_obs
#     img = self._get_image()
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\gym\envs\atari\atari_env.py", line 140, in _get_image
#     return self.ale.getScreenRGB2()
#   File "C:\Users\Kelvin\reinforcement\lib\site-packages\atari_py\ale_python_interface.py", line 266, in getScreenRGB2
#     ale_lib.getScreenRGB2(self.obj, as_ctypes(screen_data[:]))
# KeyboardInterrupt
# Traceback (most recent call last):
#   File ".\a3c_grad.py.py", line 143, in <module>
#     train_entry = train_queue.get()
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\connection.py", line 318, in _recv_bytes
#     return self._get_more_data(ov, maxsize)
#   File "c:\users\kelvin\appdata\local\programs\python\python36\lib\multiprocessing\connection.py", line 344, in _get_more_data
#     f.write(ov.getbuffer())
# KeyboardInterrupt
